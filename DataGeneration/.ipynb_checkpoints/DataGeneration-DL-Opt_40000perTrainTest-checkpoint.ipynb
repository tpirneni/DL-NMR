# %% [markdown]
# # Generate data for training models for optimizing DL-NMR methods

# %% [markdown]
# ### First load some dependencies and required files for data generation

# %%
## Load dependencies and set defaults

# Import dependencies
import numpy as np
import os
import nmrglue as ng
import random
import matplotlib.pyplot as plt

# %%
## Load function for varying line-broadening

def exponential_apodization(input_array, apodization_frequency):
    length = len(v)
    time = np.arange(length)
    decay_factor = np.exp(-time * apodization_frequency * 2 * np.pi / length)
    return input_array * decay_factor

# %% [markdown]
# ## Generate training, testing, and validation datasets with 21 metabolites. Incoporating experimental variations in the form of linebroadening, noise, peakshift, and baseline shift, and incorporating random singlets and multiplets.

# %%
## Read in simulated spectra of metabolites downloaded from HMDB

# First load quantitative reference
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles")
vd, v = ng.jcampdx.read('HMDB0000176_142710_predicted_H_400.jdx') # maleic acid, our quantitative reference
v = ng.process.proc_base.cs(v, 28305)  # Shift maleic acid peak to 0 ppm to simulate a TSP peak (need to find good simulated TSP peak)

# Load spectra of simulated standards to be analytes
filenames = os.listdir('/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/21Met')  # Get a list of filenames in the directory
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/21Met")  # Switch to appropriate folders and load data

standardsSpec =[]  # initialize variable to hold spectra of standards
standardsDictionary = []  # initialize variable to hold dictionaries of spectra of standards
for i in np.arange(len(filenames)):
    dic, data = ng.jcampdx.read(filenames[i])
    standardsSpec.append(data)
    standardsDictionary.append(dic)
standardsSpec = np.array(standardsSpec)  

## Create ppm scale for plotting ppm rather than just data point numbers for x-axis
ppm_all = (np.linspace(12.5, -2.5, 65536))
ppm = ppm_all[10000:56000]

# %%
n = 0
for i in np.arange(21):
    plt.plot(ppm_all, standardsSpec[i] + n)
    n += standardsSpec[i].max()
plt.plot(ppm_all, v - 2.5)

# %%
## Define some interference signals (essentially, generic singlets, doublets, and triplets)

vXd, vX = ng.jcampdx.read('HMDB0000042_5433_predicted_H_400.jdx') # acetic acid, for adding random singlets
Singlet = vX[vX != 0]  # make variable of acetic acid without zeros


Doublet = ng.process.proc_base.cs(vX, 100)  # shift acetic acid peak, as first step in making doublet
Doublet = vX + Doublet  # combine shifted and original signals, making doublet
Doublet = Doublet[10000:56000] # keep important signal region
Doublet = Doublet[Doublet != 0]  # remove zeros


vXd, vX = ng.jcampdx.read('HMDB0000254_143210_predicted_H_400.jdx') 
Triplet = vX[vX != 0]  # make variable of acetic acid without zeros

# %%
## Generate training and testing dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 10000

# Set a seed for reproducible data generation
np.random.seed(1)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(21):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 
        
    


## Loop to generate synthetic data with 50% chance to leave out out any metabolite
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(21):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        rr3 = np.random.choice([0,1])
        scaled = rr2*rr3*shifted #scale the peak shifted spectra
        c = rr2*rr3  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata)         
        
        
        

        
## Determine max values and scale all spectra
OvMaxL = []
for i in spectra:
    OvMaxL.append(np.max(i))
OvMax = np.max(OvMaxL)
print(OvMax)

spectra = spectra/OvMax



# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset21_Spec.npy', spectra)
np.save('Dataset21_Conc.npy', conc)
np.save("OvMax_Dataset21", OvMax)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 25
#      23 for ii in np.arange(21):
#      24     rr1 = np.random.uniform(-1,1)
# ---> 25     shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
#      26     rr2 = np.random.uniform(1,50)
#      27     scaled = rr2*shifted #scale the peak shifted spectra
#
# File ~/anaconda3/lib/python3.11/site-packages/nmrglue/process/proc_base.py:399, in cs(data, pts, neg)
#     379 def cs(data, pts=0.0, neg=False):
#     380     """
#     381     Circular shift
#     382
#    (...)
#     397
#     398     """
# --> 399     return roll(data, pts, neg)
#
# File ~/anaconda3/lib/python3.11/site-packages/nmrglue/process/proc_base.py:422, in roll(data, pts, neg)
#     402 def roll(data, pts=0.0, neg=False):
#     403     """
#     404     Roll axis
#     405
#    (...)
#     420
#     421     """
# --> 422     data = np.roll(data, int(pts), axis=-1)
#     423     if neg:
#     424         if pts > 0:
#
# File <__array_function__ internals>:200, in roll(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/numeric.py:1249, in roll(a, shift, axis)
#    1247 for indices in itertools.product(*rolls):
#    1248     arr_index, res_index = zip(*indices)
# -> 1249     result[res_index] = a[arr_index]
#    1251 return result
#
# KeyboardInterrupt:

# %%
## A few parameters to report with data generation protocol

BaseShiftMax = 0.15
NoiseAmplitudeMaxSD = 0.025
MaxDMSO2Amplitude = v.max()

BaseShiftPercent = 100 * (BaseShiftMax / MaxDMSO2Amplitude)
NoiseAmplitudeSDPercent = 100 * (NoiseAmplitudeMaxSD / MaxDMSO2Amplitude)

print(BaseShiftPercent)
print(NoiseAmplitudeSDPercent)

# %%
## Generate validation dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 5000

# Set a seed for reproducible data generation
np.random.seed(2)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(21):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
    # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 


spectra = spectra/OvMax


# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset21_Val_Spec.npy', spectra)
np.save('Dataset21_Val_Conc.npy', conc)

# %% [markdown]
# #### Now generate some representative input spectra with up to 21 metabolites

# %%
OvMax = 288.43775394645036

# %%
## Function for pre-processing generated or simulated spectra for input into the MLP
def spec_proc(spectrum):
    spectrum = np.reshape(spectrum,[1,65536])+np.random.normal(0,0.3*0.05,65536)
    spectrum = spectrum[:,10000:56000]/OvMax
    return spectrum

# %%
## Create validation examples


# Create variable with the 10 trained metabolites (@1mM) and reformat/pre-process for input into the MLP
AllAq1 = 13.27*v + standardsSpec.sum(axis=0)
AllAq1 = spec_proc(AllAq1)
AllAq1_c = np.zeros(21)+1



# Create variable with the 10 trained metabolites (@25mM) and reformat/pre-process for input into the MLP
AllAq25 = 13.27*v +25*standardsSpec.sum(axis=0) 
AllAq25 = spec_proc(AllAq25)
AllAq25_c = np.zeros(21)+25


# Create variable with the 10 trained metabolites (@5mM) and reformat/pre-process for input into the MLP
AllAq5 = 13.27*v +5*standardsSpec.sum(axis=0)
AllAq5 = spec_proc(AllAq5)
AllAq5_c = np.zeros(21)+5



## Create variable with the 10 trained metabolites (@50mM) and reformat/pre-process for input into the MLP
AllAq50 = 13.27*v +50*standardsSpec.sum(axis=0)
AllAq50 = spec_proc(AllAq50)
AllAq50_c = np.zeros(21)+50




# Create variable with the 10 trained metabolites (@25mM), but shift all peaks by 1000 data points
ShiftedSpec = 13.27*v +25*standardsSpec.sum(axis=0)
ShiftedSpec = ShiftedSpec.astype(float)
ShiftedSpec = np.reshape(ShiftedSpec,[1,65536])
ShiftedSpec = (ShiftedSpec[:,9000:55000])
ShiftedSpec = ShiftedSpec/OvMax
ShiftedSpec_c = np.zeros(21)+25



## Create variable with the 10 trained metabolites (@25mM) with sinusoidal baseline
SineBase = 13.27*v  +25*standardsSpec.sum(axis=0)
SineBase = spec_proc(SineBase)
time = np.arange(0, 46000, 1) # Setting up time vector for creating sinusoid
amplitude = 0.005*np.sin(time*0.00025) # defining sinusoid parameters
SineBase = amplitude+SineBase
SineBase_c = np.zeros(21)+25



# Create a "blank"
Blank = np.zeros(46000)
Blank = Blank.astype(float)
Blank = np.reshape(Blank,[1,46000])
Blank = Blank+13.27*v[10000:56000]+np.random.normal(0,0.3*0.05,46000)
Blank = Blank/OvMax







# Create variable with the 10 trained metabolites (@25mM) plus three random singlets, and reformat/pre-process for input into the MLP
ThreeAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThreeAddedSinglets = spec_proc(ThreeAddedSinglets)

# Randomly add three singlet signals
np.random.seed(12345)
r3 = np.random.uniform(1,50)
Sig1 = Singlet*r3
Sig1List = [np.zeros(2995),Sig1]
Sig1 = Sig1List[np.random.choice([0,1])]
r4 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r4:r4+2995] = ThreeAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
r5 = np.random.uniform(1,50)
Sig2 = Singlet*r5
Sig2List = [np.zeros(2995),Sig2]
Sig2 = Sig2List[np.random.choice([0,1])]
r6 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r6:r6+2995] = ThreeAddedSinglets[0][r6:r6+2995] + Sig2/OvMax
    
r7 = np.random.uniform(1,50)
Sig3 = Singlet*r7
Sig3List = [np.zeros(2995),Sig3]
Sig3 = Sig3List[np.random.choice([0,1])]
r8 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r8:r8+2995] = ThreeAddedSinglets[0][r8:r8+2995] + Sig3/OvMax

ThreeAddedSinglets_c = np.zeros(21)+25




# Create variable with the 8 trained metabolites (@25mM) plus thirty random singlets, and reformat/pre-process for input into the MLP
ThirtyAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThirtyAddedSinglets = spec_proc(ThirtyAddedSinglets)

# Randomly add thirty singlet signals
np.random.seed(12345)
for i in np.arange(30):
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1List = [np.zeros(2995),Sig1]
    Sig1 = Sig1List[np.random.choice([0,1])]
    r4 = np.random.choice(np.arange(46000-2995))
    ThirtyAddedSinglets[0][r4:r4+2995] = ThirtyAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
ThirtyAddedSinglets_c = np.zeros(21) + 25

# %%
## Save files for the validation example spectra, ground truth concentrations, and variable names

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Make array of all spectra and all concentrations, and make list with variable names
ValSpectra = np.array([AllAq1, AllAq5, AllAq25, AllAq50, ThreeAddedSinglets, ThirtyAddedSinglets, ShiftedSpec, SineBase, Blank])
ValConc = np.array([AllAq1_c, AllAq5_c, AllAq25_c, AllAq50_c, ThreeAddedSinglets_c, ThirtyAddedSinglets_c, ShiftedSpec_c, SineBase_c, np.zeros(21)])
ValSpecNames = np.array(['AllAq1', 'AllAq5', 'AllAq25', 'AllAq50', 'ThreeAddedSinglets', 'ThirtyAddedSinglets', 'ShiftedSpec', 'SineBase', 'Blank'])

# Save each array
np.save("Dataset21_RepresentativeExamples_Spectra", ValSpectra)
np.save("Dataset21_RepresentativeExamples_Concentrations", ValConc)
np.save("Dataset21_RepresentativeExamples_VariableNames", ValSpecNames)

# %% [markdown]
# ## Generate training, testing, and validation datasets with 58 metabolites. Incoporating experimental variations in the form of linebroadening, noise, peakshift, and baseline shift, and incorporating random singlets and multiplets.

# %%
## Read in simulated spectra of metabolites downloaded from HMDB

# First load quantitative reference
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles")
vd, v = ng.jcampdx.read('HMDB0000176_142710_predicted_H_400.jdx') # maleic acid, our quantitative reference
v = ng.process.proc_base.cs(v, 28305)  # Shift maleic acid peak to 0 ppm to simulate a TSP peak (need to find good simulated TSP peak)

# Load spectra of simulated standards to be analytes
filenames = os.listdir('/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/58Met')  # Get a list of filenames in the directory
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/58Met")  # Switch to appropriate folders and load data

standardsSpec =[]  # initialize variable to hold spectra of standards
standardsDictionary = []  # initialize variable to hold dictionaries of spectra of standards
for i in np.arange(len(filenames)):
    dic, data = ng.jcampdx.read(filenames[i])
    standardsSpec.append(data)
    standardsDictionary.append(dic)
standardsSpec = np.array(standardsSpec)  

## Create ppm scale for plotting ppm rather than just data point numbers for x-axis
ppm_all = (np.linspace(12.5, -2.5, 65536))
ppm = ppm_all[10000:56000]

# %%
n = 0
for i in np.arange(58):
    plt.plot(ppm_all, standardsSpec[i] + n)
    n += standardsSpec[i].max()
plt.plot(ppm_all, v - 2.5)

# %%
## Generate training and testing dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 10000

# Set a seed for reproducible data generation
np.random.seed(1)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(58):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 
        
    


## Loop to generate synthetic data with 50% chance to leave out out any metabolite
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(58):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        rr3 = np.random.choice([0,1])
        scaled = rr2*rr3*shifted #scale the peak shifted spectra
        c = rr2*rr3  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata)         
        
        
        

        
## Determine max values and scale all spectra
OvMaxL = []
for i in spectra:
    OvMaxL.append(np.max(i))
OvMax = np.max(OvMaxL)
print(OvMax)

spectra = spectra/OvMax



# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset58_Spec.npy', spectra)
np.save('Dataset58_Conc.npy', conc)
np.save("OvMax_Dataset58", OvMax)

# %%
## A few parameters to report with data generation protocol

BaseShiftMax = 0.15
NoiseAmplitudeMaxSD = 0.025
MaxDMSO2Amplitude = v.max()

BaseShiftPercent = 100 * (BaseShiftMax / MaxDMSO2Amplitude)
NoiseAmplitudeSDPercent = 100 * (NoiseAmplitudeMaxSD / MaxDMSO2Amplitude)

print(BaseShiftPercent)
print(NoiseAmplitudeSDPercent)

# %%
## Generate validation dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 5000

# Set a seed for reproducible data generation
np.random.seed(2)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(58):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
    # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 


spectra = spectra/OvMax


# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset58_Val_Spec.npy', spectra)
np.save('Dataset58_Val_Conc.npy', conc)

# %% [markdown]
# #### Now generate some representative input spectra with up to 58 metabolites

# %%
OvMax = 590.8075951357625

# %%
## Function for pre-processing generated or simulated spectra for input into the MLP
def spec_proc(spectrum):
    spectrum = np.reshape(spectrum,[1,65536])+np.random.normal(0,0.3*0.05,65536)
    spectrum = spectrum[:,10000:56000]/OvMax
    return spectrum

# %%
## Create validation examples


# Create variable with the 10 trained metabolites (@1mM) and reformat/pre-process for input into the MLP
AllAq1 = 13.27*v + standardsSpec.sum(axis=0)
AllAq1 = spec_proc(AllAq1)
AllAq1_c = np.zeros(58)+1



# Create variable with the 10 trained metabolites (@25mM) and reformat/pre-process for input into the MLP
AllAq25 = 13.27*v +25*standardsSpec.sum(axis=0) 
AllAq25 = spec_proc(AllAq25)
AllAq25_c = np.zeros(58)+25


# Create variable with the 10 trained metabolites (@5mM) and reformat/pre-process for input into the MLP
AllAq5 = 13.27*v +5*standardsSpec.sum(axis=0)
AllAq5 = spec_proc(AllAq5)
AllAq5_c = np.zeros(58)+5



## Create variable with the 10 trained metabolites (@50mM) and reformat/pre-process for input into the MLP
AllAq50 = 13.27*v +50*standardsSpec.sum(axis=0)
AllAq50 = spec_proc(AllAq50)
AllAq50_c = np.zeros(58)+50




# Create variable with the 10 trained metabolites (@25mM), but shift all peaks by 1000 data points
ShiftedSpec = 13.27*v +25*standardsSpec.sum(axis=0)
ShiftedSpec = ShiftedSpec.astype(float)
ShiftedSpec = np.reshape(ShiftedSpec,[1,65536])
ShiftedSpec = (ShiftedSpec[:,9000:55000])
ShiftedSpec = ShiftedSpec/OvMax
ShiftedSpec_c = np.zeros(58)+25



## Create variable with the 10 trained metabolites (@25mM) with sinusoidal baseline
SineBase = 13.27*v  +25*standardsSpec.sum(axis=0)
SineBase = spec_proc(SineBase)
time = np.arange(0, 46000, 1) # Setting up time vector for creating sinusoid
amplitude = 0.005*np.sin(time*0.00025) # defining sinusoid parameters
SineBase = amplitude+SineBase
SineBase_c = np.zeros(58)+25



# Create a "blank"
Blank = np.zeros(46000)
Blank = Blank.astype(float)
Blank = np.reshape(Blank,[1,46000])
Blank = Blank+13.27*v[10000:56000]+np.random.normal(0,0.3*0.05,46000)
Blank = Blank/OvMax







# Create variable with the 10 trained metabolites (@25mM) plus three random singlets, and reformat/pre-process for input into the MLP
ThreeAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThreeAddedSinglets = spec_proc(ThreeAddedSinglets)

# Randomly add three singlet signals
np.random.seed(12345)
r3 = np.random.uniform(1,50)
Sig1 = Singlet*r3
Sig1List = [np.zeros(2995),Sig1]
Sig1 = Sig1List[np.random.choice([0,1])]
r4 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r4:r4+2995] = ThreeAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
r5 = np.random.uniform(1,50)
Sig2 = Singlet*r5
Sig2List = [np.zeros(2995),Sig2]
Sig2 = Sig2List[np.random.choice([0,1])]
r6 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r6:r6+2995] = ThreeAddedSinglets[0][r6:r6+2995] + Sig2/OvMax
    
r7 = np.random.uniform(1,50)
Sig3 = Singlet*r7
Sig3List = [np.zeros(2995),Sig3]
Sig3 = Sig3List[np.random.choice([0,1])]
r8 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r8:r8+2995] = ThreeAddedSinglets[0][r8:r8+2995] + Sig3/OvMax

ThreeAddedSinglets_c = np.zeros(58)+25




# Create variable with the 8 trained metabolites (@25mM) plus thirty random singlets, and reformat/pre-process for input into the MLP
ThirtyAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThirtyAddedSinglets = spec_proc(ThirtyAddedSinglets)

# Randomly add thirty singlet signals
np.random.seed(12345)
for i in np.arange(30):
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1List = [np.zeros(2995),Sig1]
    Sig1 = Sig1List[np.random.choice([0,1])]
    r4 = np.random.choice(np.arange(46000-2995))
    ThirtyAddedSinglets[0][r4:r4+2995] = ThirtyAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
ThirtyAddedSinglets_c = np.zeros(58) + 25

# %%
## Save files for the validation example spectra, ground truth concentrations, and variable names

# Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Make array of all spectra and all concentrations, and make list with variable names
ValSpectra = np.array([AllAq1, AllAq5, AllAq25, AllAq50, ThreeAddedSinglets, ThirtyAddedSinglets, ShiftedSpec, SineBase, Blank])
ValConc = np.array([AllAq1_c, AllAq5_c, AllAq25_c, AllAq50_c, ThreeAddedSinglets_c, ThirtyAddedSinglets_c, ShiftedSpec_c, SineBase_c, np.zeros(58)])
ValSpecNames = np.array(['AllAq1', 'AllAq5', 'AllAq25', 'AllAq50', 'ThreeAddedSinglets', 'ThirtyAddedSinglets', 'ShiftedSpec', 'SineBase', 'Blank'])

# Save each array
np.save("Dataset58_RepresentativeExamples_Spectra", ValSpectra)
np.save("Dataset58_RepresentativeExamples_Concentrations", ValConc)
np.save("Dataset58_RepresentativeExamples_VariableNames", ValSpecNames)

# %% [markdown]
# ## Generate training, testing, and validation datasets with 8 metabolites. Incoporating experimental variations in the form of linebroadening, noise, peakshift, and baseline shift, and incorporating random singlets and multiplets.

# %%
## Read in simulated spectra of metabolites downloaded from HMDB

# First load quantitative reference
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles")
vd, v = ng.jcampdx.read('HMDB0000176_142710_predicted_H_400.jdx') # maleic acid, our quantitative reference
v = ng.process.proc_base.cs(v, 28305)  # Shift maleic acid peak to 0 ppm to simulate a TSP-d4 peak (need to find good simulated TSP peak)

# Load spectra of simulated standards to be analytes
filenames = os.listdir('/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/58Met')  # Get a list of filenames in the directory
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/58Met")  # Switch to appropriate folders and load data

standardsSpec =[]  # initialize variable to hold spectra of standards
standardsDictionary = []  # initialize variable to hold dictionaries of spectra of standards
for i in np.arange(len(filenames)):
    dic, data = ng.jcampdx.read(filenames[i])
    standardsSpec.append(data)
    standardsDictionary.append(dic)
standardsSpec = np.array(standardsSpec)  

## Create ppm scale for plotting ppm rather than just data point numbers for x-axis
ppm_all = (np.linspace(12.5, -2.5, 65536))
ppm = ppm_all[10000:56000]

# %%
n = 0
for i in np.arange(8):
    plt.plot(ppm_all, standardsSpec[i] + n)
    n += standardsSpec[i].max()
plt.plot(ppm_all, v - 2.5)

# %%
## Generate training and testing dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 10000

# Set a seed for reproducible data generation
np.random.seed(1)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(8):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 
        
    


## Loop to generate synthetic data with 50% chance to leave out out any metabolite
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(8):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        rr3 = np.random.choice([0,1])
        scaled = rr2*rr3*shifted #scale the peak shifted spectra
        c = rr2*rr3  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata)         
        
        
        
        
## Determine max values and scale all spectra
OvMaxL = []
for i in spectra:
    OvMaxL.append(np.max(i))
OvMax = np.max(OvMaxL)
print(OvMax)

spectra = spectra/OvMax



# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset8_Spec.npy', spectra)
np.save('Dataset8_Conc.npy', conc)
np.save("OvMax_Dataset8", OvMax)

# %%
## A few parameters to report with data generation protocol

BaseShiftMax = 0.15
NoiseAmplitudeMaxSD = 0.025
MaxDMSO2Amplitude = v.max()

BaseShiftPercent = 100 * (BaseShiftMax / MaxDMSO2Amplitude)
NoiseAmplitudeSDPercent = 100 * (NoiseAmplitudeMaxSD / MaxDMSO2Amplitude)

print(BaseShiftPercent)
print(NoiseAmplitudeSDPercent)

# %%
## Generate validation dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 5000

# Set a seed for reproducible data generation
np.random.seed(2)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(8):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
    # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 


spectra = spectra/OvMax


# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset8_Val_Spec.npy', spectra)
np.save('Dataset8_Val_Conc.npy', conc)

# %% [markdown]
# #### Now generate some representative input spectra with up to 8 metabolites

# %%
OvMax = 443.37577527799164

# %%
## Function for pre-processing generated or simulated spectra for input into the MLP
def spec_proc(spectrum):
    spectrum = np.reshape(spectrum,[1,65536])+np.random.normal(0,0.3*0.05,65536)
    spectrum = spectrum[:,10000:56000]/OvMax
    return spectrum

# %%
## Create validation examples


# Create variable with the 10 trained metabolites (@1mM) and reformat/pre-process for input into the MLP
AllAq1 = 13.27*v + standardsSpec[:8].sum(axis=0)
AllAq1 = spec_proc(AllAq1)
AllAq1_c = np.zeros(8)+1



# Create variable with the 10 trained metabolites (@25mM) and reformat/pre-process for input into the MLP
AllAq25 = 13.27*v +25*standardsSpec[:8].sum(axis=0) 
AllAq25 = spec_proc(AllAq25)
AllAq25_c = np.zeros(8)+25


# Create variable with the 10 trained metabolites (@5mM) and reformat/pre-process for input into the MLP
AllAq5 = 13.27*v +5*standardsSpec[:8].sum(axis=0)
AllAq5 = spec_proc(AllAq5)
AllAq5_c = np.zeros(8)+5



## Create variable with the 10 trained metabolites (@50mM) and reformat/pre-process for input into the MLP
AllAq50 = 13.27*v +50*standardsSpec[:8].sum(axis=0)
AllAq50 = spec_proc(AllAq50)
AllAq50_c = np.zeros(8)+50




# Create variable with the 10 trained metabolites (@25mM), but shift all peaks by 1000 data points
ShiftedSpec = 13.27*v +25*standardsSpec[:8].sum(axis=0)
ShiftedSpec = ShiftedSpec.astype(float)
ShiftedSpec = np.reshape(ShiftedSpec,[1,65536])
ShiftedSpec = (ShiftedSpec[:,9000:55000])
ShiftedSpec = ShiftedSpec/OvMax
ShiftedSpec_c = np.zeros(8)+25



## Create variable with the 10 trained metabolites (@25mM) with sinusoidal baseline
SineBase = 13.27*v  +25*standardsSpec[:8].sum(axis=0)
SineBase = spec_proc(SineBase)
time = np.arange(0, 46000, 1) # Setting up time vector for creating sinusoid
amplitude = 0.005*np.sin(time*0.00025) # defining sinusoid parameters
SineBase = amplitude+SineBase
SineBase_c = np.zeros(8)+25



# Create a "blank"
Blank = np.zeros(46000)
Blank = Blank.astype(float)
Blank = np.reshape(Blank,[1,46000])
Blank = Blank+13.27*v[10000:56000]+np.random.normal(0,0.3*0.05,46000)
Blank = Blank/OvMax







# Create variable with the 10 trained metabolites (@25mM) plus three random singlets, and reformat/pre-process for input into the MLP
ThreeAddedSinglets = 13.27*v+ 25*standardsSpec[:8].sum(axis=0)
ThreeAddedSinglets = spec_proc(ThreeAddedSinglets)

# Randomly add three singlet signals
np.random.seed(12345)
r3 = np.random.uniform(1,50)
Sig1 = Singlet*r3
Sig1List = [np.zeros(2995),Sig1]
Sig1 = Sig1List[np.random.choice([0,1])]
r4 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r4:r4+2995] = ThreeAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
r5 = np.random.uniform(1,50)
Sig2 = Singlet*r5
Sig2List = [np.zeros(2995),Sig2]
Sig2 = Sig2List[np.random.choice([0,1])]
r6 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r6:r6+2995] = ThreeAddedSinglets[0][r6:r6+2995] + Sig2/OvMax
    
r7 = np.random.uniform(1,50)
Sig3 = Singlet*r7
Sig3List = [np.zeros(2995),Sig3]
Sig3 = Sig3List[np.random.choice([0,1])]
r8 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r8:r8+2995] = ThreeAddedSinglets[0][r8:r8+2995] + Sig3/OvMax

ThreeAddedSinglets_c = np.zeros(8)+25




# Create variable with the 8 trained metabolites (@25mM) plus thirty random singlets, and reformat/pre-process for input into the MLP
ThirtyAddedSinglets = 13.27*v+ 25*standardsSpec[:8].sum(axis=0)
ThirtyAddedSinglets = spec_proc(ThirtyAddedSinglets)

# Randomly add thirty singlet signals
np.random.seed(12345)
for i in np.arange(30):
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1List = [np.zeros(2995),Sig1]
    Sig1 = Sig1List[np.random.choice([0,1])]
    r4 = np.random.choice(np.arange(46000-2995))
    ThirtyAddedSinglets[0][r4:r4+2995] = ThirtyAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
ThirtyAddedSinglets_c = np.zeros(8) + 25

# %%
## Save files for the validation example spectra, ground truth concentrations, and variable names

# Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Make array of all spectra and all concentrations, and make list with variable names
ValSpectra = np.array([AllAq1, AllAq5, AllAq25, AllAq50, ThreeAddedSinglets, ThirtyAddedSinglets, ShiftedSpec, SineBase, Blank])
ValConc = np.array([AllAq1_c, AllAq5_c, AllAq25_c, AllAq50_c, ThreeAddedSinglets_c, ThirtyAddedSinglets_c, ShiftedSpec_c, SineBase_c, np.zeros(8)])
ValSpecNames = np.array(['AllAq1', 'AllAq5', 'AllAq25', 'AllAq50', 'ThreeAddedSinglets', 'ThirtyAddedSinglets', 'ShiftedSpec', 'SineBase', 'Blank'])

# Save each array
np.save("Dataset8_RepresentativeExamples_Spectra", ValSpectra)
np.save("Dataset8_RepresentativeExamples_Concentrations", ValConc)
np.save("Dataset8_RepresentativeExamples_VariableNames", ValSpecNames)

# %%
len(standardsSpec[0])

# %% [markdown]
# ## Generate training, testing, and validation datasets with 87 metabolites. Incoporating experimental variations in the form of linebroadening, noise, peakshift, and baseline shift, and incorporating random singlets and multiplets.

# %%
## Read in simulated spectra of metabolites downloaded from HMDB

# First load quantitative reference
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles")
vd, v = ng.jcampdx.read('HMDB0000176_142710_predicted_H_400.jdx') # maleic acid, our quantitative reference
v = ng.process.proc_base.cs(v, 28305)  # Shift maleic acid peak to 0 ppm to simulate a TSP-d4 peak (need to find good simulated TSP peak)

# Load spectra of simulated standards to be analytes
filenames = os.listdir('/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/87Met')  # Get a list of filenames in the directory
os.chdir("/home/htjhnson/Desktop/DL-NMR-Optimization/HMDBSpectraFiles/87Met")  # Switch to appropriate folders and load data

standardsSpec =[]  # initialize variable to hold spectra of standards
standardsDictionary = []  # initialize variable to hold dictionaries of spectra of standards
for i in np.arange(len(filenames)):
    dic, data = ng.jcampdx.read(filenames[i])
    standardsSpec.append(data)
    standardsDictionary.append(dic)
standardsSpec = np.array(standardsSpec)  

## Create ppm scale for plotting ppm rather than just data point numbers for x-axis
ppm_all = (np.linspace(12.5, -2.5, 65536))
ppm = ppm_all[10000:56000]

# %%
n = 0
for i in np.arange(87):
    plt.plot(ppm_all, standardsSpec[i] + n)
    n += standardsSpec[i].max()
plt.plot(ppm_all, v - 2.5)

# %%
## Generate training and testing dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 10000

# Set a seed for reproducible data generation
np.random.seed(1)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(87):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 
        
    


## Loop to generate synthetic data with 50% chance to leave out out any metabolite
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(87):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        rr3 = np.random.choice([0,1])
        scaled = rr2*rr3*shifted #scale the peak shifted spectra
        c = rr2*rr3  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
     # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata)         
        
        
        

        
## Determine max values and scale all spectra
OvMaxL = []
for i in spectra:
    OvMaxL.append(np.max(i))
OvMax = np.max(OvMaxL)
print(OvMax)

spectra = spectra/OvMax



# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset87_Spec.npy', spectra)
np.save('Dataset87_Conc.npy', conc)
np.save("OvMax_Dataset87", OvMax)

# %%
## A few parameters to report with data generation protocol

BaseShiftMax = 0.15
NoiseAmplitudeMaxSD = 0.025
MaxDMSO2Amplitude = v.max()

BaseShiftPercent = 100 * (BaseShiftMax / MaxDMSO2Amplitude)
NoiseAmplitudeSDPercent = 100 * (NoiseAmplitudeMaxSD / MaxDMSO2Amplitude)

print(BaseShiftPercent)
print(NoiseAmplitudeSDPercent)

# %%
## Generate validation dataset 
## Use linear combinations with physically inspired modifications (line-broadening, noise, baseline shift, and peak shift) 

## Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Create some empty lists to contain spectra/concentrations as they are generated, and set some variables for the data generation function
spectra = []
conc = []
max_shift = 15
iterations = 5000

# Set a seed for reproducible data generation
np.random.seed(2)

## Loop to generate synthetic data without leaving out any metabolites
for i in range(iterations):
    xdata = []
    ydata = []
    
    # Loop through and scale each standard, potentially leaving each out. Do the same for metabolite concentrations. Combine all spectra and metabolite profiles into separate lists. 
    # Sum all spectra into one synthetic mixture and add maleic acid as reference. Create random seeds and random variables throughout.
    for ii in np.arange(87):
        rr1 = np.random.uniform(-1,1) 
        shifted = ng.process.proc_base.cs(standardsSpec[ii],np.random.choice([0,rr1*max_shift]))  #shift peaks
        rr2 = np.random.uniform(1,50)
        scaled = rr2*shifted #scale the peak shifted spectra
        c = rr2  #define concentration
        xdata.append(scaled)  #add all shifted, scaled spectra to list
        ydata.append(c)  #add all concentrations to list
    xdata = np.array(xdata).sum(axis=0) + v*13.27  #sum all 10 metabolite spectra and add maleic acid as reference
    ydata = np.array(ydata)
    
    # Inverse FFT (real-valued), apply line-broadening, and FFT (real-valued)
    linebroad = np.random.uniform(0,1)
    xdata = ng.proc_base.irft(xdata)
    xdata = exponential_apodization(xdata, linebroad)
    xdata = ng.proc_base.rft(xdata)
    
    # Select signal region and add random noise
    r4 = np.random.uniform(0.1,0.5)*0.05
    xdata = xdata[10000:56000]+np.random.normal(0, r4,size = 46000)
    
    # Shift baseline up or down
    xdata = xdata + np.random.uniform(-0.15,0.15)
    
    
    
    # Randomly add three singlet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1 = random.choice([np.zeros(2995),Sig1])
    r4 = random.choice(np.arange(46000-2995))
    xdata[r4:r4+2995] = xdata[r4:r4+2995] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Singlet*r5
    Sig2 = random.choice([np.zeros(2995),Sig2])
    r6 = random.choice(np.arange(46000-2995))
    xdata[r6:r6+2995] = xdata[r6:r6+2995] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Singlet*r7
    Sig3 = random.choice([np.zeros(2995),Sig3])
    r8 = random.choice(np.arange(46000-2995))
    xdata[r8:r8+2995] = xdata[r8:r8+2995] + Sig3
    
    '''
    # Randomly add three doublet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Doublet*r3
    Sig1 = random.choice([np.zeros(3095),Sig1])
    r4 = random.choice(np.arange(46000-3095))
    xdata[r4:r4+3095] = xdata[r4:r4+3095] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Doublet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Doublet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    
    
    # Randomly add three triplet signals
    r3 = np.random.uniform(1,50)
    Sig1 = Triplet*r3
    Sig1 = random.choice([np.zeros(4231),Sig1])
    r4 = random.choice(np.arange(46000-4231))
    xdata[r4:r4+4231] = xdata[r4:r4+4231] + Sig1
    
    r5 = np.random.uniform(1,50)
    Sig2 = Triplet*r5
    Sig2 = random.choice([np.zeros(3095),Sig2])
    r6 = random.choice(np.arange(46000-3095))
    xdata[r6:r6+3095] = xdata[r6:r6+3095] + Sig2
    
    r7 = np.random.uniform(1,50)
    Sig3 = Triplet*r7
    Sig3 = random.choice([np.zeros(3095),Sig3])
    r8 = random.choice(np.arange(46000-3095))
    xdata[r8:r8+3095] = xdata[r8:r8+3095] + Sig3
    '''
    
    # Append spectrum and metabolite profile variables to list
    spectra.append(xdata)
    conc.append(ydata) 


spectra = spectra/OvMax


# Save the arrays to files, and save max value seen in training/testing datasets
np.save('Dataset87_Val_Spec.npy', spectra)
np.save('Dataset87_Val_Conc.npy', conc)

# %% [markdown]
# #### Now generate some representative input spectra with up to 58 metabolites

# %%
#OvMax = 664.9808439208982

# %%
## Function for pre-processing generated or simulated spectra for input into the MLP
def spec_proc(spectrum):
    spectrum = np.reshape(spectrum,[1,65536])+np.random.normal(0,0.3*0.05,65536)
    spectrum = spectrum[:,10000:56000]/OvMax
    return spectrum

# %%
## Create validation examples


# Create variable with the 10 trained metabolites (@1mM) and reformat/pre-process for input into the MLP
AllAq1 = 13.27*v + standardsSpec.sum(axis=0)
AllAq1 = spec_proc(AllAq1)
AllAq1_c = np.zeros(87)+1



# Create variable with the 10 trained metabolites (@25mM) and reformat/pre-process for input into the MLP
AllAq25 = 13.27*v +25*standardsSpec.sum(axis=0) 
AllAq25 = spec_proc(AllAq25)
AllAq25_c = np.zeros(87)+25


# Create variable with the 10 trained metabolites (@5mM) and reformat/pre-process for input into the MLP
AllAq5 = 13.27*v +5*standardsSpec.sum(axis=0)
AllAq5 = spec_proc(AllAq5)
AllAq5_c = np.zeros(87)+5



## Create variable with the 10 trained metabolites (@50mM) and reformat/pre-process for input into the MLP
AllAq50 = 13.27*v +50*standardsSpec.sum(axis=0)
AllAq50 = spec_proc(AllAq50)
AllAq50_c = np.zeros(87)+50




# Create variable with the 10 trained metabolites (@25mM), but shift all peaks by 1000 data points
ShiftedSpec = 13.27*v +25*standardsSpec.sum(axis=0)
ShiftedSpec = ShiftedSpec.astype(float)
ShiftedSpec = np.reshape(ShiftedSpec,[1,65536])
ShiftedSpec = (ShiftedSpec[:,9000:55000])
ShiftedSpec = ShiftedSpec/OvMax
ShiftedSpec_c = np.zeros(87)+25



## Create variable with the 10 trained metabolites (@25mM) with sinusoidal baseline
SineBase = 13.27*v  +25*standardsSpec.sum(axis=0)
SineBase = spec_proc(SineBase)
time = np.arange(0, 46000, 1) # Setting up time vector for creating sinusoid
amplitude = 0.005*np.sin(time*0.00025) # defining sinusoid parameters
SineBase = amplitude+SineBase
SineBase_c = np.zeros(87)+25



# Create a "blank"
Blank = np.zeros(46000)
Blank = Blank.astype(float)
Blank = np.reshape(Blank,[1,46000])
Blank = Blank+13.27*v[10000:56000]+np.random.normal(0,0.3*0.05,46000)
Blank = Blank/OvMax







# Create variable with the 10 trained metabolites (@25mM) plus three random singlets, and reformat/pre-process for input into the MLP
ThreeAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThreeAddedSinglets = spec_proc(ThreeAddedSinglets)

# Randomly add three singlet signals
np.random.seed(12345)
r3 = np.random.uniform(1,50)
Sig1 = Singlet*r3
Sig1List = [np.zeros(2995),Sig1]
Sig1 = Sig1List[np.random.choice([0,1])]
r4 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r4:r4+2995] = ThreeAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
r5 = np.random.uniform(1,50)
Sig2 = Singlet*r5
Sig2List = [np.zeros(2995),Sig2]
Sig2 = Sig2List[np.random.choice([0,1])]
r6 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r6:r6+2995] = ThreeAddedSinglets[0][r6:r6+2995] + Sig2/OvMax
    
r7 = np.random.uniform(1,50)
Sig3 = Singlet*r7
Sig3List = [np.zeros(2995),Sig3]
Sig3 = Sig3List[np.random.choice([0,1])]
r8 = np.random.choice(np.arange(46000-2995))
ThreeAddedSinglets[0][r8:r8+2995] = ThreeAddedSinglets[0][r8:r8+2995] + Sig3/OvMax

ThreeAddedSinglets_c = np.zeros(87)+25




# Create variable with the 8 trained metabolites (@25mM) plus thirty random singlets, and reformat/pre-process for input into the MLP
ThirtyAddedSinglets = 13.27*v+ 25*standardsSpec.sum(axis=0)
ThirtyAddedSinglets = spec_proc(ThirtyAddedSinglets)

# Randomly add thirty singlet signals
np.random.seed(12345)
for i in np.arange(30):
    r3 = np.random.uniform(1,50)
    Sig1 = Singlet*r3
    Sig1List = [np.zeros(2995),Sig1]
    Sig1 = Sig1List[np.random.choice([0,1])]
    r4 = np.random.choice(np.arange(46000-2995))
    ThirtyAddedSinglets[0][r4:r4+2995] = ThirtyAddedSinglets[0][r4:r4+2995] + Sig1/OvMax
    
ThirtyAddedSinglets_c = np.zeros(87) + 25

# %%
## Save files for the validation example spectra, ground truth concentrations, and variable names

# Switch to folder where datasets will be saved
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Make array of all spectra and all concentrations, and make list with variable names
ValSpectra = np.array([AllAq1, AllAq5, AllAq25, AllAq50, ThreeAddedSinglets, ThirtyAddedSinglets, ShiftedSpec, SineBase, Blank])
ValConc = np.array([AllAq1_c, AllAq5_c, AllAq25_c, AllAq50_c, ThreeAddedSinglets_c, ThirtyAddedSinglets_c, ShiftedSpec_c, SineBase_c, np.zeros(87)])
ValSpecNames = np.array(['AllAq1', 'AllAq5', 'AllAq25', 'AllAq50', 'ThreeAddedSinglets', 'ThirtyAddedSinglets', 'ShiftedSpec', 'SineBase', 'Blank'])

# Save each array
np.save("Dataset87_RepresentativeExamples_Spectra", ValSpectra)
np.save("Dataset87_RepresentativeExamples_Concentrations", ValConc)
np.save("Dataset87_RepresentativeExamples_VariableNames", ValSpecNames)
