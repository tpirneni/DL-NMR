# %%
## Import dependencies

import numpy as np
from os import path
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import time


# Set default plot size
plt.rcParams["figure.figsize"] = (30,20)

# Define number of epochs used later in training
num_epochs = 1000

# Identification part of the filenames
base_name = 'MimicTissueRange'

# %% [markdown]
# ## Train Transformer on dataset of 44 metabolites

# %%
# Name variable used for saving model metrics, name should reflect model used, dataset used, and other information such as # of epochs
ModelName = f"Transformer_44met_{base_name}Dist_TrainingAndValidation_ForManuscript_" + str(num_epochs) +"ep"

# Set the random seed
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/ModelPerformanceMetrics/') 
seed = 1
torch.manual_seed(seed)
np.save(ModelName + "_Seed.npy", seed)

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load training data and max value from testing and training datasets
spectra = np.load(f'Dataset44_{base_name}_ForManuscript_Spec.npy')
conc1 = np.load(f'Dataset44_{base_name}_ForManuscript_Conc.npy')

# %%
## Prepare to switch data from CPU to GPU

# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    device = torch.device("cuda")          # A CUDA device object
    print("Using GPU for training.")
else:
    device = torch.device("cpu")           # A CPU object
    print("CUDA is not available. Using CPU for training.")
# Out:
# Using GPU for training.

# %%
## Set up data for testing and training

# Split into testing and training data
X_train, X_test, y_train, y_test = train_test_split(spectra, conc1, test_size = 0.2, random_state = 1)

# Tensorize and prepare datasets
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()


# Move the input data to the GPU device
X_train = X_train.to(device)
X_test = X_test.to(device)
#spectraVal = torch.tensor(spectraVal).float().to(device)   # Confusing names, these spectra are the 5000 spectra generated like the training dataset
#ValSpectra = torch.tensor(ValSpectra).float().to(device)   # Confusing names, these spectra are the 10 representative example spectra

# Move the target data to the GPU device
y_train = y_train.to(device)
y_test = y_test.to(device)
#concVal = torch.tensor(concVal).float().to(device)
#ValConc = torch.tensor(ValConc).float().to(device)

# More data prep?
datasets = torch.utils.data.TensorDataset(X_train, y_train)
Test_datasets = torch.utils.data.TensorDataset(X_test, y_test)
train_iter = torch.utils.data.DataLoader(datasets, batch_size = 76, shuffle=True)
test_iter = torch.utils.data.DataLoader(Test_datasets, batch_size = 76, shuffle=True)

# %%
del X_train
del X_test
del y_train
del y_test
del spectra
del conc1
del datasets
del Test_datasets

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.d_model = d_model
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]

class Transformer(nn.Module):
    def __init__(self, input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout=0.1):
        super(Transformer, self).__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        self.embedding = nn.Linear(input_dim, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        self.decoder = nn.Linear(23552, 44)

    def forward(self, x):
        # Binning
        batch_size, seq_length = x.size()
        num_bins = seq_length // self.input_dim
        x = x.view(batch_size, num_bins, self.input_dim)  # (batch_size, num_bins, input_dim)
        
        # Embedding
        x = self.embedding(x)  # (batch_size, num_bins, d_model)
        
        # Add positional encoding
        x = self.positional_encoding(x)
        
        # Transformer Encoder
        x = x.permute(1, 0, 2)  # (num_bins, batch_size, d_model)
        x = self.transformer_encoder(x)  # (num_bins, batch_size, d_model)
        x = x.permute(1, 0, 2)  # (batch_size, num_bins, d_model)
        
        # Reconstruct original sequence
        x = x.reshape(batch_size, num_bins * d_model)
        
        # Decoding
        x = self.decoder(x)  # (batch_size, output_dim)
        
        return x

# Parameters
input_dim = 1000  # Size of each bin
d_model = 512     # Embedding dimension
nhead = 1         # Number of attention heads
num_encoder_layers = 1  # Number of transformer encoder layers
dim_feedforward = 2048  # Feedforward dimension
dropout = 0.0     # Dropout rate

# %%
class RelativeAbsoluteError(nn.Module):
    def __init__(self):
        super(RelativeAbsoluteError, self).__init__()

    def forward(self, y_pred, y_true):
        # Compute the mean of the true values
        y_mean = torch.mean(y_true)
        
        # Compute the absolute differences
        absolute_errors = torch.abs(y_true - y_pred)
        mean_absolute_errors = torch.abs(y_true - y_mean)
        
        # Compute RAE
        rae = torch.sum(absolute_errors) / torch.sum(mean_absolute_errors)
        return rae

# %%
def train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path):
    criterion = RelativeAbsoluteError()
    optimizer = optim.AdamW(model.parameters(), lr=0.00014656680844397094, weight_decay=0.01)
    
    
    train_losses = []
    test_losses = []
    best_test_loss = float('inf')
    epochs_no_improve = 0
    patience = 50  # Set how many epochs without improvement in validation loss constitutes early stopping

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
        train_losses.append(train_loss)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                test_loss += loss.item() * inputs.size(0)
            test_losses.append(test_loss)
            
            
        if (epoch + 1) % 1 == 0:  # The last number here denotes how often to print loss metrics in terms of epochs
            print(f'Epoch [{epoch + 1}/{num_epochs}], '
                  f'Train Loss: {train_loss:.4f}, '
                  f'Test Loss: {test_loss:.4f}')
            
    
            
        if test_loss < best_test_loss:
            best_test_loss = test_loss
            epochs_no_improve = 0
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
            }, save_path)
        else:
            epochs_no_improve += 1
            
        if epochs_no_improve >= patience:
            print(f'Early stopping at epoch {epoch + 1}')
            break



    return train_losses, test_losses


def train_or_load_model(model, train_loader, test_loader, num_epochs, save_path):
    train_losses = []
    test_losses = []
    is_model_trained = False  # Initialize flag

    if os.path.isfile(save_path):
        print("Loading pretrained model from {}".format(save_path))
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer = optim.Adam(model.parameters())  
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        
    
    else:
        print("No pretrained model found. Training from scratch.")
        #optimizer = optim.Adam(model.parameters())  
        train_losses, test_losses = train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
        is_model_trained = True  # Set flag to True after training
        # Save losses per epoch
        np.save(ModelName + "_TrainLoss.npy", train_losses)
        np.save(ModelName + "_TestLoss.npy", test_losses)
    
    return train_losses, test_losses, is_model_trained  # Return the losses and flag

# %%
## Instantiate model and train

# For timing cell run time
start_time = time.time()


# Switch to directory for saving model parameters
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Create model
model_aq = Transformer(input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout)

# Move the model to the GPU device
model_aq.to(device)

# Define the path to save and load the model parameters
save_path = ModelName + '_Params.pt'

# Call the function
train_losses, test_losses, is_model_trained = train_or_load_model(model_aq, train_iter, test_iter, num_epochs, save_path)


# Finish timing cell run time
end_time = time.time()
execution_time = end_time - start_time
if is_model_trained:
    np.save(ModelName + "_ExecutionTime.npy", execution_time)
    print("Execution time:", execution_time, "seconds")
# Out:
# /home/htjhnson/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# No pretrained model found. Training from scratch.
# Epoch [1/1000], Train Loss: 13836.4640, Test Loss: 3232.1946
# Epoch [2/1000], Train Loss: 12731.1668, Test Loss: 3182.4869
# Epoch [3/1000], Train Loss: 12542.5493, Test Loss: 3117.9344
# Epoch [4/1000], Train Loss: 12392.9384, Test Loss: 3043.4357
# Epoch [5/1000], Train Loss: 11510.6033, Test Loss: 2648.9709
# Epoch [6/1000], Train Loss: 9227.8658, Test Loss: 2071.7111
# Epoch [7/1000], Train Loss: 6465.2252, Test Loss: 1321.1304
# Epoch [8/1000], Train Loss: 4396.8285, Test Loss: 931.4767
# Epoch [9/1000], Train Loss: 3253.9212, Test Loss: 706.6391
# Epoch [10/1000], Train Loss: 2648.0299, Test Loss: 603.9884
# Epoch [11/1000], Train Loss: 2237.1674, Test Loss: 513.6633
# Epoch [12/1000], Train Loss: 1939.0038, Test Loss: 456.5478
# Epoch [13/1000], Train Loss: 1761.3367, Test Loss: 418.0207
# Epoch [14/1000], Train Loss: 1609.7947, Test Loss: 383.3949
# Epoch [15/1000], Train Loss: 1486.2968, Test Loss: 362.5640
# Epoch [16/1000], Train Loss: 1400.6910, Test Loss: 355.6557
# Epoch [17/1000], Train Loss: 1341.9554, Test Loss: 333.7017
# Epoch [18/1000], Train Loss: 1294.6842, Test Loss: 319.9915
# Epoch [19/1000], Train Loss: 1230.1434, Test Loss: 293.4301
# Epoch [20/1000], Train Loss: 1196.5074, Test Loss: 303.0084
# Epoch [21/1000], Train Loss: 1183.0213, Test Loss: 295.1572
# Epoch [22/1000], Train Loss: 1130.5438, Test Loss: 285.6254
# Epoch [23/1000], Train Loss: 1129.0471, Test Loss: 450.9074
# Epoch [24/1000], Train Loss: 1558.8045, Test Loss: 257.1473
# Epoch [25/1000], Train Loss: 1007.0226, Test Loss: 251.8738
# Epoch [26/1000], Train Loss: 994.1434, Test Loss: 250.0134
# Epoch [27/1000], Train Loss: 981.9548, Test Loss: 239.7704
# Epoch [28/1000], Train Loss: 963.4335, Test Loss: 246.6952
# Epoch [29/1000], Train Loss: 958.7000, Test Loss: 247.5792
# Epoch [30/1000], Train Loss: 944.2972, Test Loss: 240.3024
# Epoch [31/1000], Train Loss: 932.0042, Test Loss: 230.8546
# Epoch [32/1000], Train Loss: 929.0252, Test Loss: 243.9653
# Epoch [33/1000], Train Loss: 923.4391, Test Loss: 226.6913
# Epoch [34/1000], Train Loss: 912.8182, Test Loss: 238.8702
# Epoch [35/1000], Train Loss: 891.4330, Test Loss: 233.7637
# Epoch [36/1000], Train Loss: 877.0987, Test Loss: 223.3399
# Epoch [37/1000], Train Loss: 1691.1026, Test Loss: 785.3403
# Epoch [38/1000], Train Loss: 1069.8903, Test Loss: 203.3307
# Epoch [39/1000], Train Loss: 803.3984, Test Loss: 201.0652
# Epoch [40/1000], Train Loss: 788.7729, Test Loss: 200.4219
# Epoch [41/1000], Train Loss: 791.5615, Test Loss: 198.4059
# Epoch [42/1000], Train Loss: 782.3052, Test Loss: 193.0321
# Epoch [43/1000], Train Loss: 777.7208, Test Loss: 195.8691
# Epoch [44/1000], Train Loss: 774.1622, Test Loss: 196.6138
# Epoch [45/1000], Train Loss: 772.8290, Test Loss: 198.5495
# Epoch [46/1000], Train Loss: 774.0184, Test Loss: 196.6722
# Epoch [47/1000], Train Loss: 770.9543, Test Loss: 193.3452
# Epoch [48/1000], Train Loss: 763.8344, Test Loss: 195.1986
# Epoch [49/1000], Train Loss: 771.8548, Test Loss: 201.2701
# Epoch [50/1000], Train Loss: 760.4574, Test Loss: 192.6033
# Epoch [51/1000], Train Loss: 768.6924, Test Loss: 191.6161
# Epoch [52/1000], Train Loss: 753.7851, Test Loss: 196.0869
# Epoch [53/1000], Train Loss: 753.7550, Test Loss: 202.0620
# Epoch [54/1000], Train Loss: 747.5628, Test Loss: 185.6555
# Epoch [55/1000], Train Loss: 740.9948, Test Loss: 190.1871
# Epoch [56/1000], Train Loss: 1643.2489, Test Loss: 215.4452
# Epoch [57/1000], Train Loss: 699.3275, Test Loss: 171.9560
# Epoch [58/1000], Train Loss: 670.0551, Test Loss: 165.8604
# Epoch [59/1000], Train Loss: 671.5593, Test Loss: 170.4658
# Epoch [60/1000], Train Loss: 666.0876, Test Loss: 164.5145
# Epoch [61/1000], Train Loss: 662.7572, Test Loss: 168.6416
# Epoch [62/1000], Train Loss: 666.3338, Test Loss: 170.2648
# Epoch [63/1000], Train Loss: 669.5080, Test Loss: 171.1713
# Epoch [64/1000], Train Loss: 671.7259, Test Loss: 170.7881
# Epoch [65/1000], Train Loss: 668.7546, Test Loss: 170.6649
# Epoch [66/1000], Train Loss: 672.9139, Test Loss: 173.9755
# Epoch [67/1000], Train Loss: 674.3988, Test Loss: 175.0188
# Epoch [68/1000], Train Loss: 668.0815, Test Loss: 169.4384
# Epoch [69/1000], Train Loss: 664.8780, Test Loss: 178.5138
# Epoch [70/1000], Train Loss: 665.6121, Test Loss: 168.5756
# Epoch [71/1000], Train Loss: 667.9658, Test Loss: 169.7106
# Epoch [72/1000], Train Loss: 660.8419, Test Loss: 169.5321
# Epoch [73/1000], Train Loss: 656.6307, Test Loss: 165.5184
# Epoch [74/1000], Train Loss: 651.9415, Test Loss: 163.4751
# Epoch [75/1000], Train Loss: 651.0376, Test Loss: 167.0467
# Epoch [76/1000], Train Loss: 667.1563, Test Loss: 162.6893
# Epoch [77/1000], Train Loss: 640.8351, Test Loss: 163.4780
# Epoch [78/1000], Train Loss: 633.6314, Test Loss: 160.7364
# Epoch [79/1000], Train Loss: 645.4064, Test Loss: 169.1823
# Epoch [80/1000], Train Loss: 642.8622, Test Loss: 168.9381
# Epoch [81/1000], Train Loss: 631.4351, Test Loss: 158.8437
# Epoch [82/1000], Train Loss: 628.2364, Test Loss: 159.9267
# Epoch [83/1000], Train Loss: 618.7986, Test Loss: 161.9512
# Epoch [84/1000], Train Loss: 626.7995, Test Loss: 170.1157
# Epoch [85/1000], Train Loss: 627.0094, Test Loss: 157.7835
# Epoch [86/1000], Train Loss: 614.3553, Test Loss: 156.0452
# Epoch [87/1000], Train Loss: 1014.9674, Test Loss: 275.2067
# Epoch [88/1000], Train Loss: 635.3091, Test Loss: 149.8029
# Epoch [89/1000], Train Loss: 568.8641, Test Loss: 148.1851
# Epoch [90/1000], Train Loss: 568.1470, Test Loss: 147.4781
# Epoch [91/1000], Train Loss: 567.5265, Test Loss: 145.6170
# Epoch [92/1000], Train Loss: 573.7051, Test Loss: 147.1393
# Epoch [93/1000], Train Loss: 575.9235, Test Loss: 144.3799
# Epoch [94/1000], Train Loss: 578.8747, Test Loss: 159.0882
# Epoch [95/1000], Train Loss: 580.9013, Test Loss: 147.4949
# Epoch [96/1000], Train Loss: 580.2003, Test Loss: 151.4386
# Epoch [97/1000], Train Loss: 580.6755, Test Loss: 153.1986
# Epoch [98/1000], Train Loss: 581.8854, Test Loss: 155.0919
# Epoch [99/1000], Train Loss: 586.1443, Test Loss: 147.5958
# Epoch [100/1000], Train Loss: 581.3507, Test Loss: 151.1919
# Epoch [101/1000], Train Loss: 583.5264, Test Loss: 153.8348
# Epoch [102/1000], Train Loss: 581.0924, Test Loss: 151.4700
# Epoch [103/1000], Train Loss: 570.1036, Test Loss: 154.4054
# Epoch [104/1000], Train Loss: 577.2779, Test Loss: 146.6297
# Epoch [105/1000], Train Loss: 574.0767, Test Loss: 151.2923
# Epoch [106/1000], Train Loss: 563.8950, Test Loss: 152.6245
# Epoch [107/1000], Train Loss: 575.8089, Test Loss: 152.1308
# Epoch [108/1000], Train Loss: 560.8514, Test Loss: 148.2449
# Epoch [109/1000], Train Loss: 562.6495, Test Loss: 148.0831
# Epoch [110/1000], Train Loss: 558.8481, Test Loss: 142.3234
# Epoch [111/1000], Train Loss: 565.7942, Test Loss: 145.8481
# Epoch [112/1000], Train Loss: 558.4647, Test Loss: 142.2890
# Epoch [113/1000], Train Loss: 555.2996, Test Loss: 150.5061
# Epoch [114/1000], Train Loss: 555.9158, Test Loss: 149.1249
# Epoch [115/1000], Train Loss: 556.0627, Test Loss: 145.9419
# Epoch [116/1000], Train Loss: 550.7814, Test Loss: 140.7083
# Epoch [117/1000], Train Loss: 549.4068, Test Loss: 139.9207
# Epoch [118/1000], Train Loss: 539.6226, Test Loss: 141.0574
# Epoch [119/1000], Train Loss: 541.5150, Test Loss: 143.2570
# Epoch [120/1000], Train Loss: 541.2810, Test Loss: 142.1675
# Epoch [121/1000], Train Loss: 542.6729, Test Loss: 140.9511
# Epoch [122/1000], Train Loss: 538.1728, Test Loss: 141.9889
# Epoch [123/1000], Train Loss: 537.6191, Test Loss: 144.3921
# Epoch [124/1000], Train Loss: 540.5593, Test Loss: 138.1074
# Epoch [125/1000], Train Loss: 535.2089, Test Loss: 141.2361
# Epoch [126/1000], Train Loss: 529.1116, Test Loss: 137.5631
# Epoch [127/1000], Train Loss: 526.6867, Test Loss: 139.2404
# Epoch [128/1000], Train Loss: 529.0875, Test Loss: 142.6581
# Epoch [129/1000], Train Loss: 525.4249, Test Loss: 140.3182
# Epoch [130/1000], Train Loss: 544.2103, Test Loss: 140.1239
# Epoch [131/1000], Train Loss: 525.2308, Test Loss: 138.0232
# Epoch [132/1000], Train Loss: 517.0532, Test Loss: 137.4351
# Epoch [133/1000], Train Loss: 522.8537, Test Loss: 138.4959
# Epoch [134/1000], Train Loss: 519.0788, Test Loss: 135.5037
# Epoch [135/1000], Train Loss: 524.9826, Test Loss: 138.3625
# Epoch [136/1000], Train Loss: 515.4537, Test Loss: 133.7477
# Epoch [137/1000], Train Loss: 509.2421, Test Loss: 133.7633
# Epoch [138/1000], Train Loss: 509.9788, Test Loss: 132.2023
# Epoch [139/1000], Train Loss: 515.9284, Test Loss: 137.2457
# Epoch [140/1000], Train Loss: 514.6821, Test Loss: 138.1641
# Epoch [141/1000], Train Loss: 509.8636, Test Loss: 132.0860
# Epoch [142/1000], Train Loss: 502.3449, Test Loss: 131.5747
# Epoch [143/1000], Train Loss: 508.4917, Test Loss: 130.4316
# Epoch [144/1000], Train Loss: 511.9495, Test Loss: 138.0981
# Epoch [145/1000], Train Loss: 510.1927, Test Loss: 139.5447
# Epoch [146/1000], Train Loss: 501.9686, Test Loss: 131.9195
# Epoch [147/1000], Train Loss: 499.0474, Test Loss: 131.4478
# Epoch [148/1000], Train Loss: 502.6798, Test Loss: 131.3015
# Epoch [149/1000], Train Loss: 496.7619, Test Loss: 129.6077
# Epoch [150/1000], Train Loss: 496.9531, Test Loss: 132.9086
# Epoch [151/1000], Train Loss: 500.5271, Test Loss: 130.5740
# Epoch [152/1000], Train Loss: 496.5750, Test Loss: 132.6987
# Epoch [153/1000], Train Loss: 502.6896, Test Loss: 137.4241
# Epoch [154/1000], Train Loss: 493.8289, Test Loss: 130.3977
# Epoch [155/1000], Train Loss: 487.1782, Test Loss: 132.2751
# Epoch [156/1000], Train Loss: 490.8531, Test Loss: 129.4294
# Epoch [157/1000], Train Loss: 491.1419, Test Loss: 131.1352
# Epoch [158/1000], Train Loss: 484.2269, Test Loss: 131.0027
# Epoch [159/1000], Train Loss: 486.6264, Test Loss: 130.1943
# Epoch [160/1000], Train Loss: 488.8001, Test Loss: 130.0904
# Epoch [161/1000], Train Loss: 481.2817, Test Loss: 131.0407
# Epoch [162/1000], Train Loss: 480.3824, Test Loss: 131.2441
# Epoch [163/1000], Train Loss: 477.3034, Test Loss: 129.7690
# Epoch [164/1000], Train Loss: 484.4664, Test Loss: 128.8953
# Epoch [165/1000], Train Loss: 478.7858, Test Loss: 131.8837
# Epoch [166/1000], Train Loss: 475.6602, Test Loss: 125.4074
# Epoch [167/1000], Train Loss: 472.9425, Test Loss: 126.3387
# Epoch [168/1000], Train Loss: 473.9648, Test Loss: 126.8667
# Epoch [169/1000], Train Loss: 477.7293, Test Loss: 137.6342
# Epoch [170/1000], Train Loss: 476.5389, Test Loss: 124.5850
# Epoch [171/1000], Train Loss: 471.1703, Test Loss: 126.7691
# Epoch [172/1000], Train Loss: 466.3244, Test Loss: 131.2154
# Epoch [173/1000], Train Loss: 472.3403, Test Loss: 129.2049
# Epoch [174/1000], Train Loss: 468.5001, Test Loss: 123.4857
# Epoch [175/1000], Train Loss: 467.7550, Test Loss: 124.1011
# Epoch [176/1000], Train Loss: 468.9646, Test Loss: 124.9236
# Epoch [177/1000], Train Loss: 461.3885, Test Loss: 130.3415
# Epoch [178/1000], Train Loss: 463.7063, Test Loss: 126.9109
# Epoch [179/1000], Train Loss: 463.4742, Test Loss: 122.9601
# Epoch [180/1000], Train Loss: 464.9947, Test Loss: 125.0902
# Epoch [181/1000], Train Loss: 462.6509, Test Loss: 128.5493
# Epoch [182/1000], Train Loss: 458.5775, Test Loss: 125.2170
# Epoch [183/1000], Train Loss: 461.1172, Test Loss: 126.0157
# Epoch [184/1000], Train Loss: 460.0260, Test Loss: 125.2266
# Epoch [185/1000], Train Loss: 454.3034, Test Loss: 121.1678
# Epoch [186/1000], Train Loss: 449.7020, Test Loss: 121.3622
# Epoch [187/1000], Train Loss: 457.7765, Test Loss: 130.8318
# Epoch [188/1000], Train Loss: 453.9470, Test Loss: 126.6132
# Epoch [189/1000], Train Loss: 451.9744, Test Loss: 122.2612
# Epoch [190/1000], Train Loss: 452.6194, Test Loss: 121.0672
# Epoch [191/1000], Train Loss: 457.0496, Test Loss: 123.6208
# Epoch [192/1000], Train Loss: 448.0105, Test Loss: 123.0064
# Epoch [193/1000], Train Loss: 450.9931, Test Loss: 119.0901
# Epoch [194/1000], Train Loss: 446.9132, Test Loss: 122.9898
# Epoch [195/1000], Train Loss: 443.6886, Test Loss: 121.5723
# Epoch [196/1000], Train Loss: 447.0094, Test Loss: 118.0580
# Epoch [197/1000], Train Loss: 443.5613, Test Loss: 123.2959
# Epoch [198/1000], Train Loss: 444.3554, Test Loss: 119.3348
# Epoch [199/1000], Train Loss: 442.9937, Test Loss: 122.2445
# Epoch [200/1000], Train Loss: 439.0052, Test Loss: 121.6008
# Epoch [201/1000], Train Loss: 441.5181, Test Loss: 121.4310
# Epoch [202/1000], Train Loss: 438.9447, Test Loss: 119.3294
# Epoch [203/1000], Train Loss: 440.8823, Test Loss: 121.1807
# Epoch [204/1000], Train Loss: 440.2589, Test Loss: 116.9104
# Epoch [205/1000], Train Loss: 439.2265, Test Loss: 121.4741
# Epoch [206/1000], Train Loss: 437.0934, Test Loss: 117.2859
# Epoch [207/1000], Train Loss: 432.8445, Test Loss: 115.1238
# Epoch [208/1000], Train Loss: 433.8032, Test Loss: 116.8406
# Epoch [209/1000], Train Loss: 436.3684, Test Loss: 118.3653
# Epoch [210/1000], Train Loss: 439.1680, Test Loss: 115.1657
# Epoch [211/1000], Train Loss: 430.8111, Test Loss: 120.6491
# Epoch [212/1000], Train Loss: 434.5591, Test Loss: 116.2252
# Epoch [213/1000], Train Loss: 428.2753, Test Loss: 118.3826
# Epoch [214/1000], Train Loss: 427.8723, Test Loss: 113.4192
# Epoch [215/1000], Train Loss: 431.5472, Test Loss: 114.2012
# Epoch [216/1000], Train Loss: 429.8453, Test Loss: 113.5685
# Epoch [217/1000], Train Loss: 428.3248, Test Loss: 118.9107
# Epoch [218/1000], Train Loss: 430.3833, Test Loss: 118.6834
# Epoch [219/1000], Train Loss: 423.4594, Test Loss: 115.2349
# Epoch [220/1000], Train Loss: 427.5069, Test Loss: 122.2715
# Epoch [221/1000], Train Loss: 429.2362, Test Loss: 121.2594
# Epoch [222/1000], Train Loss: 425.1320, Test Loss: 117.4467
# Epoch [223/1000], Train Loss: 425.1087, Test Loss: 116.8134
# Epoch [224/1000], Train Loss: 424.4722, Test Loss: 114.8986
# Epoch [225/1000], Train Loss: 423.1129, Test Loss: 119.5207
# Epoch [226/1000], Train Loss: 420.6988, Test Loss: 114.4465
# Epoch [227/1000], Train Loss: 418.9360, Test Loss: 115.1273
# Epoch [228/1000], Train Loss: 421.4581, Test Loss: 112.1009
# Epoch [229/1000], Train Loss: 419.5205, Test Loss: 113.6320
# Epoch [230/1000], Train Loss: 422.5370, Test Loss: 116.0641
# Epoch [231/1000], Train Loss: 416.6022, Test Loss: 117.9208
# Epoch [232/1000], Train Loss: 415.2313, Test Loss: 112.3564
# Epoch [233/1000], Train Loss: 415.5858, Test Loss: 115.6094
# Epoch [234/1000], Train Loss: 414.9461, Test Loss: 112.6134
# Epoch [235/1000], Train Loss: 415.3933, Test Loss: 109.2572
# Epoch [236/1000], Train Loss: 413.7004, Test Loss: 110.5134
# Epoch [237/1000], Train Loss: 411.8312, Test Loss: 114.9312
# Epoch [238/1000], Train Loss: 412.7689, Test Loss: 110.9622
# Epoch [239/1000], Train Loss: 421.6647, Test Loss: 113.5874
# Epoch [240/1000], Train Loss: 410.7100, Test Loss: 113.1290
# Epoch [241/1000], Train Loss: 410.5872, Test Loss: 112.9791
# Epoch [242/1000], Train Loss: 409.7197, Test Loss: 117.6754
# Epoch [243/1000], Train Loss: 409.4007, Test Loss: 114.4724
# Epoch [244/1000], Train Loss: 411.3903, Test Loss: 110.0889
# Epoch [245/1000], Train Loss: 406.3167, Test Loss: 113.9160
# Epoch [246/1000], Train Loss: 413.2416, Test Loss: 114.5843
# Epoch [247/1000], Train Loss: 406.0614, Test Loss: 110.1255
# Epoch [248/1000], Train Loss: 412.2350, Test Loss: 110.9293
# Epoch [249/1000], Train Loss: 406.3422, Test Loss: 110.0340
# Epoch [250/1000], Train Loss: 408.4862, Test Loss: 114.1634
# Epoch [251/1000], Train Loss: 405.3394, Test Loss: 110.3660
# Epoch [252/1000], Train Loss: 402.6909, Test Loss: 112.2133
# Epoch [253/1000], Train Loss: 405.2008, Test Loss: 111.5210
# Epoch [254/1000], Train Loss: 403.7801, Test Loss: 112.0384
# Epoch [255/1000], Train Loss: 401.5837, Test Loss: 107.3482
# Epoch [256/1000], Train Loss: 398.7384, Test Loss: 109.3657
# Epoch [257/1000], Train Loss: 406.4968, Test Loss: 110.6843
# Epoch [258/1000], Train Loss: 399.7619, Test Loss: 109.2421
# Epoch [259/1000], Train Loss: 397.9581, Test Loss: 108.3898
# Epoch [260/1000], Train Loss: 397.4067, Test Loss: 110.9075
# Epoch [261/1000], Train Loss: 403.3217, Test Loss: 111.0261
# Epoch [262/1000], Train Loss: 398.4960, Test Loss: 112.2471
# Epoch [263/1000], Train Loss: 391.6351, Test Loss: 107.9095
# Epoch [264/1000], Train Loss: 397.4585, Test Loss: 107.9591
# Epoch [265/1000], Train Loss: 400.6918, Test Loss: 108.4781
# Epoch [266/1000], Train Loss: 395.0893, Test Loss: 105.6660
# Epoch [267/1000], Train Loss: 397.7952, Test Loss: 109.9068
# Epoch [268/1000], Train Loss: 395.6666, Test Loss: 107.0541
# Epoch [269/1000], Train Loss: 394.0252, Test Loss: 105.4508
# Epoch [270/1000], Train Loss: 394.6087, Test Loss: 105.3626
# Epoch [271/1000], Train Loss: 392.3473, Test Loss: 108.7118
# Epoch [272/1000], Train Loss: 394.0447, Test Loss: 106.8971
# Epoch [273/1000], Train Loss: 389.7856, Test Loss: 109.4213
# Epoch [274/1000], Train Loss: 386.8442, Test Loss: 109.3044
# Epoch [275/1000], Train Loss: 388.5766, Test Loss: 106.7766
# Epoch [276/1000], Train Loss: 397.8535, Test Loss: 109.6110
# Epoch [277/1000], Train Loss: 390.0503, Test Loss: 107.7326
# Epoch [278/1000], Train Loss: 388.1240, Test Loss: 104.5921
# Epoch [279/1000], Train Loss: 389.1622, Test Loss: 106.6425
# Epoch [280/1000], Train Loss: 390.2501, Test Loss: 105.2767
# Epoch [281/1000], Train Loss: 384.7438, Test Loss: 102.6991
# Epoch [282/1000], Train Loss: 388.0283, Test Loss: 104.4576
# Epoch [283/1000], Train Loss: 389.2076, Test Loss: 107.9862
# Epoch [284/1000], Train Loss: 389.3650, Test Loss: 106.1995
# Epoch [285/1000], Train Loss: 385.9729, Test Loss: 107.2766
# Epoch [286/1000], Train Loss: 384.9992, Test Loss: 105.1381
# Epoch [287/1000], Train Loss: 385.5937, Test Loss: 105.4339
# Epoch [288/1000], Train Loss: 384.5894, Test Loss: 102.9632
# Epoch [289/1000], Train Loss: 381.4131, Test Loss: 104.0429
# Epoch [290/1000], Train Loss: 383.8904, Test Loss: 106.2855
# Epoch [291/1000], Train Loss: 379.9534, Test Loss: 101.7366
# Epoch [292/1000], Train Loss: 384.0059, Test Loss: 107.6545
# Epoch [293/1000], Train Loss: 381.5627, Test Loss: 104.1481
# Epoch [294/1000], Train Loss: 380.5724, Test Loss: 105.1217
# Epoch [295/1000], Train Loss: 379.7279, Test Loss: 112.5962
# Epoch [296/1000], Train Loss: 378.2319, Test Loss: 104.9339
# Epoch [297/1000], Train Loss: 375.7205, Test Loss: 106.4609
# Epoch [298/1000], Train Loss: 379.8367, Test Loss: 103.5611
# Epoch [299/1000], Train Loss: 377.2666, Test Loss: 101.3753
# Epoch [300/1000], Train Loss: 379.3498, Test Loss: 101.1820
# Epoch [301/1000], Train Loss: 378.8209, Test Loss: 110.0040
# Epoch [302/1000], Train Loss: 382.1979, Test Loss: 100.5058
# Epoch [303/1000], Train Loss: 379.0254, Test Loss: 107.2182
# Epoch [304/1000], Train Loss: 374.4153, Test Loss: 102.2390
# Epoch [305/1000], Train Loss: 373.7034, Test Loss: 106.1285
# Epoch [306/1000], Train Loss: 376.0715, Test Loss: 101.8658
# Epoch [307/1000], Train Loss: 372.2575, Test Loss: 103.2597
# Epoch [308/1000], Train Loss: 372.9121, Test Loss: 106.2712
# Epoch [309/1000], Train Loss: 378.7293, Test Loss: 98.0594
# Epoch [310/1000], Train Loss: 367.6724, Test Loss: 102.8001
# Epoch [311/1000], Train Loss: 377.6887, Test Loss: 104.9548
# Epoch [312/1000], Train Loss: 373.5397, Test Loss: 102.0401
# Epoch [313/1000], Train Loss: 370.8064, Test Loss: 103.3995
# Epoch [314/1000], Train Loss: 370.6997, Test Loss: 101.1185
# Epoch [315/1000], Train Loss: 369.9276, Test Loss: 102.3597
# Epoch [316/1000], Train Loss: 370.1792, Test Loss: 105.1265
# Epoch [317/1000], Train Loss: 368.1533, Test Loss: 102.4938
# Epoch [318/1000], Train Loss: 370.9236, Test Loss: 101.3912
# Epoch [319/1000], Train Loss: 371.3593, Test Loss: 100.0091
# Epoch [320/1000], Train Loss: 374.2017, Test Loss: 101.1219
# Epoch [321/1000], Train Loss: 364.8514, Test Loss: 103.2490
# Epoch [322/1000], Train Loss: 368.2796, Test Loss: 99.3413
# Epoch [323/1000], Train Loss: 366.2854, Test Loss: 101.2644
# Epoch [324/1000], Train Loss: 364.1478, Test Loss: 101.7427
# Epoch [325/1000], Train Loss: 367.3176, Test Loss: 104.1954
# Epoch [326/1000], Train Loss: 364.1666, Test Loss: 102.8594
# Epoch [327/1000], Train Loss: 366.3614, Test Loss: 100.0118
# Epoch [328/1000], Train Loss: 362.4743, Test Loss: 101.4030
# Epoch [329/1000], Train Loss: 363.8065, Test Loss: 102.5012
# Epoch [330/1000], Train Loss: 360.2145, Test Loss: 99.6837
# Epoch [331/1000], Train Loss: 362.6765, Test Loss: 105.3241
# Epoch [332/1000], Train Loss: 369.1835, Test Loss: 97.8463
# Epoch [333/1000], Train Loss: 358.8671, Test Loss: 100.8251
# Epoch [334/1000], Train Loss: 361.8298, Test Loss: 99.2034
# Epoch [335/1000], Train Loss: 361.8873, Test Loss: 101.5761
# Epoch [336/1000], Train Loss: 361.7786, Test Loss: 99.9005
# Epoch [337/1000], Train Loss: 362.0960, Test Loss: 99.0965
# Epoch [338/1000], Train Loss: 361.5249, Test Loss: 104.0848
# Epoch [339/1000], Train Loss: 359.0718, Test Loss: 102.1670
# Epoch [340/1000], Train Loss: 362.7472, Test Loss: 101.4346
# Epoch [341/1000], Train Loss: 363.9970, Test Loss: 97.6534
# Epoch [342/1000], Train Loss: 359.3030, Test Loss: 102.1696
# Epoch [343/1000], Train Loss: 364.8964, Test Loss: 101.9447
# Epoch [344/1000], Train Loss: 355.8191, Test Loss: 102.0118
# Epoch [345/1000], Train Loss: 357.5961, Test Loss: 100.1283
# Epoch [346/1000], Train Loss: 352.2790, Test Loss: 100.2811
# Epoch [347/1000], Train Loss: 353.6201, Test Loss: 101.0857
# Epoch [348/1000], Train Loss: 355.0673, Test Loss: 100.9498
# Epoch [349/1000], Train Loss: 351.9732, Test Loss: 99.6145
# Epoch [350/1000], Train Loss: 357.9728, Test Loss: 98.3745
# Epoch [351/1000], Train Loss: 358.4245, Test Loss: 98.6510
# Epoch [352/1000], Train Loss: 351.6510, Test Loss: 96.0977
# Epoch [353/1000], Train Loss: 354.6783, Test Loss: 97.9806
# Epoch [354/1000], Train Loss: 354.1199, Test Loss: 97.0889
# Epoch [355/1000], Train Loss: 352.9796, Test Loss: 96.0206
# Epoch [356/1000], Train Loss: 350.5664, Test Loss: 96.1544
# Epoch [357/1000], Train Loss: 348.8163, Test Loss: 99.7527
# Epoch [358/1000], Train Loss: 354.0287, Test Loss: 99.6094
# Epoch [359/1000], Train Loss: 353.3205, Test Loss: 96.8153
# Epoch [360/1000], Train Loss: 346.9622, Test Loss: 101.1036
# Epoch [361/1000], Train Loss: 355.1195, Test Loss: 97.3346
# Epoch [362/1000], Train Loss: 355.7971, Test Loss: 100.2259
# Epoch [363/1000], Train Loss: 347.7467, Test Loss: 102.3812
# Epoch [364/1000], Train Loss: 353.2662, Test Loss: 100.0678
# Epoch [365/1000], Train Loss: 347.5336, Test Loss: 99.1727
# Epoch [366/1000], Train Loss: 346.1195, Test Loss: 96.0354
# Epoch [367/1000], Train Loss: 350.1968, Test Loss: 98.7402
# Epoch [368/1000], Train Loss: 350.1726, Test Loss: 99.6548
# Epoch [369/1000], Train Loss: 348.0642, Test Loss: 98.1172
# Epoch [370/1000], Train Loss: 348.4474, Test Loss: 96.1770
# Epoch [371/1000], Train Loss: 344.9988, Test Loss: 97.2264
# Epoch [372/1000], Train Loss: 344.0423, Test Loss: 95.4762
# Epoch [373/1000], Train Loss: 345.1234, Test Loss: 98.1653
# Epoch [374/1000], Train Loss: 346.2098, Test Loss: 94.2716
# Epoch [375/1000], Train Loss: 344.1389, Test Loss: 94.6070
# Epoch [376/1000], Train Loss: 346.8440, Test Loss: 97.8974
# Epoch [377/1000], Train Loss: 348.4191, Test Loss: 99.7272
# Epoch [378/1000], Train Loss: 344.1423, Test Loss: 94.7638
# Epoch [379/1000], Train Loss: 343.0783, Test Loss: 98.6611
# Epoch [380/1000], Train Loss: 347.6666, Test Loss: 100.1172
# Epoch [381/1000], Train Loss: 342.8594, Test Loss: 94.1299
# Epoch [382/1000], Train Loss: 344.2845, Test Loss: 95.8576
# Epoch [383/1000], Train Loss: 341.0278, Test Loss: 93.7686
# Epoch [384/1000], Train Loss: 344.3673, Test Loss: 97.5860
# Epoch [385/1000], Train Loss: 341.0245, Test Loss: 95.0375
# Epoch [386/1000], Train Loss: 337.7782, Test Loss: 97.2819
# Epoch [387/1000], Train Loss: 342.0663, Test Loss: 95.3096
# Epoch [388/1000], Train Loss: 345.9837, Test Loss: 98.8262
# Epoch [389/1000], Train Loss: 344.7750, Test Loss: 97.4253
# Epoch [390/1000], Train Loss: 337.0608, Test Loss: 93.3021
# Epoch [391/1000], Train Loss: 343.1131, Test Loss: 95.6047
# Epoch [392/1000], Train Loss: 336.9427, Test Loss: 93.3747
# Epoch [393/1000], Train Loss: 337.7106, Test Loss: 97.1434
# Epoch [394/1000], Train Loss: 335.6185, Test Loss: 95.8407
# Epoch [395/1000], Train Loss: 338.7624, Test Loss: 97.6928
# Epoch [396/1000], Train Loss: 341.1599, Test Loss: 92.6361
# Epoch [397/1000], Train Loss: 338.6266, Test Loss: 96.2694
# Epoch [398/1000], Train Loss: 339.5640, Test Loss: 95.0018
# Epoch [399/1000], Train Loss: 341.4175, Test Loss: 94.2169
# Epoch [400/1000], Train Loss: 335.7900, Test Loss: 93.3601
# Epoch [401/1000], Train Loss: 335.1002, Test Loss: 95.9747
# Epoch [402/1000], Train Loss: 339.2297, Test Loss: 101.8192
# Epoch [403/1000], Train Loss: 336.7624, Test Loss: 92.3076
# Epoch [404/1000], Train Loss: 337.3228, Test Loss: 95.6794
# Epoch [405/1000], Train Loss: 331.3729, Test Loss: 92.7660
# Epoch [406/1000], Train Loss: 332.6568, Test Loss: 92.8822
# Epoch [407/1000], Train Loss: 336.2719, Test Loss: 96.8925
# Epoch [408/1000], Train Loss: 341.2937, Test Loss: 95.7406
# Epoch [409/1000], Train Loss: 333.0845, Test Loss: 93.1301
# Epoch [410/1000], Train Loss: 333.2176, Test Loss: 90.2188
# Epoch [411/1000], Train Loss: 331.3487, Test Loss: 95.4720
# Epoch [412/1000], Train Loss: 330.5330, Test Loss: 95.4053
# Epoch [413/1000], Train Loss: 331.0202, Test Loss: 92.7855
# Epoch [414/1000], Train Loss: 336.7430, Test Loss: 91.5621
# Epoch [415/1000], Train Loss: 333.1576, Test Loss: 92.6724
# Epoch [416/1000], Train Loss: 328.0366, Test Loss: 93.0980
# Epoch [417/1000], Train Loss: 331.7569, Test Loss: 92.0454
# Epoch [418/1000], Train Loss: 330.3578, Test Loss: 98.5369
# Epoch [419/1000], Train Loss: 328.5321, Test Loss: 91.3574
# Epoch [420/1000], Train Loss: 330.0599, Test Loss: 93.7558
# Epoch [421/1000], Train Loss: 331.9176, Test Loss: 91.6887
# Epoch [422/1000], Train Loss: 326.8030, Test Loss: 92.4907
# Epoch [423/1000], Train Loss: 330.4883, Test Loss: 92.0301
# Epoch [424/1000], Train Loss: 329.7256, Test Loss: 93.3730
# Epoch [425/1000], Train Loss: 325.9574, Test Loss: 91.8800
# Epoch [426/1000], Train Loss: 329.4077, Test Loss: 93.7110
# Epoch [427/1000], Train Loss: 330.6450, Test Loss: 91.2167
# Epoch [428/1000], Train Loss: 326.7374, Test Loss: 89.6186
# Epoch [429/1000], Train Loss: 326.6930, Test Loss: 95.3517
# Epoch [430/1000], Train Loss: 326.1126, Test Loss: 90.6700
# Epoch [431/1000], Train Loss: 323.3137, Test Loss: 90.0260
# Epoch [432/1000], Train Loss: 325.7119, Test Loss: 91.6713
# Epoch [433/1000], Train Loss: 325.1926, Test Loss: 91.9057
# Epoch [434/1000], Train Loss: 324.4226, Test Loss: 94.7882
# Epoch [435/1000], Train Loss: 328.8535, Test Loss: 89.9563
# Epoch [436/1000], Train Loss: 324.5744, Test Loss: 89.9380
# Epoch [437/1000], Train Loss: 326.6141, Test Loss: 94.7766
# Epoch [438/1000], Train Loss: 337.9682, Test Loss: 93.2133
# Epoch [439/1000], Train Loss: 324.0945, Test Loss: 91.8424
# Epoch [440/1000], Train Loss: 321.7152, Test Loss: 93.0911
# Epoch [441/1000], Train Loss: 325.9368, Test Loss: 91.8768
# Epoch [442/1000], Train Loss: 332.0109, Test Loss: 90.4568
# Epoch [443/1000], Train Loss: 320.9158, Test Loss: 88.8363
# Epoch [444/1000], Train Loss: 319.9587, Test Loss: 88.8975
# Epoch [445/1000], Train Loss: 322.4269, Test Loss: 90.7129
# Epoch [446/1000], Train Loss: 322.0428, Test Loss: 90.4751
# Epoch [447/1000], Train Loss: 322.1209, Test Loss: 91.3492
# Epoch [448/1000], Train Loss: 322.5503, Test Loss: 88.5969
# Epoch [449/1000], Train Loss: 319.3839, Test Loss: 89.9937
# Epoch [450/1000], Train Loss: 318.9355, Test Loss: 89.7399
# Epoch [451/1000], Train Loss: 319.7412, Test Loss: 90.7654
# Epoch [452/1000], Train Loss: 318.9320, Test Loss: 89.3198
# Epoch [453/1000], Train Loss: 320.6665, Test Loss: 92.3369
# Epoch [454/1000], Train Loss: 318.3521, Test Loss: 91.3864
# Epoch [455/1000], Train Loss: 319.1483, Test Loss: 89.9935
# Epoch [456/1000], Train Loss: 326.1563, Test Loss: 90.1367
# Epoch [457/1000], Train Loss: 320.8619, Test Loss: 92.9346
# Epoch [458/1000], Train Loss: 316.7420, Test Loss: 89.4405
# Epoch [459/1000], Train Loss: 315.6544, Test Loss: 89.7857
# Epoch [460/1000], Train Loss: 321.0533, Test Loss: 92.5888
# Epoch [461/1000], Train Loss: 317.7749, Test Loss: 86.9598
# Epoch [462/1000], Train Loss: 316.1392, Test Loss: 87.4054
# Epoch [463/1000], Train Loss: 313.4222, Test Loss: 87.2748
# Epoch [464/1000], Train Loss: 317.6034, Test Loss: 89.7695
# Epoch [465/1000], Train Loss: 316.3183, Test Loss: 91.0632
# Epoch [466/1000], Train Loss: 319.0405, Test Loss: 86.5495
# Epoch [467/1000], Train Loss: 315.8543, Test Loss: 86.5201
# Epoch [468/1000], Train Loss: 313.9237, Test Loss: 92.2522
# Epoch [469/1000], Train Loss: 316.8184, Test Loss: 89.0617
# Epoch [470/1000], Train Loss: 313.4897, Test Loss: 92.7861
# Epoch [471/1000], Train Loss: 314.7950, Test Loss: 89.8405
# Epoch [472/1000], Train Loss: 316.2348, Test Loss: 94.0184
# Epoch [473/1000], Train Loss: 316.8322, Test Loss: 88.8183
# Epoch [474/1000], Train Loss: 310.8287, Test Loss: 87.4294
# Epoch [475/1000], Train Loss: 313.8288, Test Loss: 89.7446
# Epoch [476/1000], Train Loss: 313.0851, Test Loss: 87.8978
# Epoch [477/1000], Train Loss: 314.7505, Test Loss: 89.8563
# Epoch [478/1000], Train Loss: 314.4673, Test Loss: 87.6076
# Epoch [479/1000], Train Loss: 311.0840, Test Loss: 89.4576
# Epoch [480/1000], Train Loss: 309.8242, Test Loss: 91.9631
# Epoch [481/1000], Train Loss: 322.9461, Test Loss: 94.7811
# Epoch [482/1000], Train Loss: 312.3890, Test Loss: 87.5662
# Epoch [483/1000], Train Loss: 311.5396, Test Loss: 89.8145
# Epoch [484/1000], Train Loss: 309.7832, Test Loss: 89.3185
# Epoch [485/1000], Train Loss: 309.6574, Test Loss: 86.6736
# Epoch [486/1000], Train Loss: 314.1141, Test Loss: 91.0927
# Epoch [487/1000], Train Loss: 311.2517, Test Loss: 87.7030
# Epoch [488/1000], Train Loss: 310.1010, Test Loss: 87.7444
# Epoch [489/1000], Train Loss: 310.7091, Test Loss: 87.9167
# Epoch [490/1000], Train Loss: 309.3719, Test Loss: 87.2998
# Epoch [491/1000], Train Loss: 308.4208, Test Loss: 86.0346
# Epoch [492/1000], Train Loss: 311.5141, Test Loss: 86.8027
# Epoch [493/1000], Train Loss: 310.5967, Test Loss: 88.4026
# Epoch [494/1000], Train Loss: 310.1385, Test Loss: 87.9635
# Epoch [495/1000], Train Loss: 305.8253, Test Loss: 85.0782
# Epoch [496/1000], Train Loss: 309.6257, Test Loss: 86.5807
# Epoch [497/1000], Train Loss: 308.3931, Test Loss: 90.8746
# Epoch [498/1000], Train Loss: 307.3440, Test Loss: 87.5614
# Epoch [499/1000], Train Loss: 306.1244, Test Loss: 87.5710
# Epoch [500/1000], Train Loss: 308.1642, Test Loss: 87.5038
# Epoch [501/1000], Train Loss: 306.2280, Test Loss: 87.2367
# Epoch [502/1000], Train Loss: 304.8009, Test Loss: 88.3425
# Epoch [503/1000], Train Loss: 307.4141, Test Loss: 88.3626
# Epoch [504/1000], Train Loss: 305.4345, Test Loss: 84.2136
# Epoch [505/1000], Train Loss: 304.8123, Test Loss: 87.0054
# Epoch [506/1000], Train Loss: 306.8067, Test Loss: 85.7310
# Epoch [507/1000], Train Loss: 305.3375, Test Loss: 86.8599
# Epoch [508/1000], Train Loss: 310.1138, Test Loss: 84.1416
# Epoch [509/1000], Train Loss: 304.2709, Test Loss: 91.0736
# Epoch [510/1000], Train Loss: 305.4654, Test Loss: 88.2497
# Epoch [511/1000], Train Loss: 302.9886, Test Loss: 84.7532
# Epoch [512/1000], Train Loss: 303.6710, Test Loss: 86.2244
# Epoch [513/1000], Train Loss: 302.2674, Test Loss: 87.7865
# Epoch [514/1000], Train Loss: 309.5614, Test Loss: 87.5652
# Epoch [515/1000], Train Loss: 300.8608, Test Loss: 83.9988
# Epoch [516/1000], Train Loss: 305.5735, Test Loss: 86.1009
# Epoch [517/1000], Train Loss: 301.0497, Test Loss: 86.8161
# Epoch [518/1000], Train Loss: 305.9547, Test Loss: 87.4819
# Epoch [519/1000], Train Loss: 305.5901, Test Loss: 88.6044
# Epoch [520/1000], Train Loss: 302.8742, Test Loss: 87.2445
# Epoch [521/1000], Train Loss: 304.9999, Test Loss: 88.7560
# Epoch [522/1000], Train Loss: 305.9284, Test Loss: 85.9266
# Epoch [523/1000], Train Loss: 301.0079, Test Loss: 84.0498
# Epoch [524/1000], Train Loss: 300.7754, Test Loss: 85.4046
# Epoch [525/1000], Train Loss: 300.8803, Test Loss: 85.7994
# Epoch [526/1000], Train Loss: 301.7147, Test Loss: 90.2558
# Epoch [527/1000], Train Loss: 303.7285, Test Loss: 83.7405
# Epoch [528/1000], Train Loss: 298.8275, Test Loss: 85.4947
# Epoch [529/1000], Train Loss: 300.5687, Test Loss: 88.6886
# Epoch [530/1000], Train Loss: 302.9317, Test Loss: 85.4257
# Epoch [531/1000], Train Loss: 302.5070, Test Loss: 87.3146
# Epoch [532/1000], Train Loss: 300.3721, Test Loss: 87.3803
# Epoch [533/1000], Train Loss: 303.8542, Test Loss: 85.1127
# Epoch [534/1000], Train Loss: 297.6863, Test Loss: 88.5607
# Epoch [535/1000], Train Loss: 298.4898, Test Loss: 86.3828
# Epoch [536/1000], Train Loss: 301.0724, Test Loss: 90.7198
# Epoch [537/1000], Train Loss: 302.0825, Test Loss: 87.3965
# Epoch [538/1000], Train Loss: 298.7005, Test Loss: 84.7171
# Epoch [539/1000], Train Loss: 298.5333, Test Loss: 88.4543
# Epoch [540/1000], Train Loss: 300.7507, Test Loss: 83.0022
# Epoch [541/1000], Train Loss: 298.1983, Test Loss: 83.7286
# Epoch [542/1000], Train Loss: 295.4682, Test Loss: 84.5722
# Epoch [543/1000], Train Loss: 315.2869, Test Loss: 84.3265
# Epoch [544/1000], Train Loss: 295.5379, Test Loss: 86.9594
# Epoch [545/1000], Train Loss: 294.9844, Test Loss: 84.4136
# Epoch [546/1000], Train Loss: 296.1578, Test Loss: 84.3063
# Epoch [547/1000], Train Loss: 292.7567, Test Loss: 83.1337
# Epoch [548/1000], Train Loss: 298.7069, Test Loss: 91.9508
# Epoch [549/1000], Train Loss: 294.3962, Test Loss: 84.2867
# Epoch [550/1000], Train Loss: 293.8056, Test Loss: 83.6216
# Epoch [551/1000], Train Loss: 298.1410, Test Loss: 85.5302
# Epoch [552/1000], Train Loss: 295.2943, Test Loss: 85.6771
# Epoch [553/1000], Train Loss: 295.9494, Test Loss: 88.7717
# Epoch [554/1000], Train Loss: 292.8998, Test Loss: 85.7404
# Epoch [555/1000], Train Loss: 297.2839, Test Loss: 84.0512
# Epoch [556/1000], Train Loss: 292.4745, Test Loss: 83.0622
# Epoch [557/1000], Train Loss: 368.6809, Test Loss: 83.1892
# Epoch [558/1000], Train Loss: 295.4824, Test Loss: 82.1068
# Epoch [559/1000], Train Loss: 291.7710, Test Loss: 81.6899
# Epoch [560/1000], Train Loss: 285.0770, Test Loss: 84.0581
# Epoch [561/1000], Train Loss: 285.6394, Test Loss: 82.3943
# Epoch [562/1000], Train Loss: 289.6228, Test Loss: 85.6859
# Epoch [563/1000], Train Loss: 289.6583, Test Loss: 83.0140
# Epoch [564/1000], Train Loss: 288.2956, Test Loss: 83.4297
# Epoch [565/1000], Train Loss: 289.1333, Test Loss: 81.4023
# Epoch [566/1000], Train Loss: 288.5280, Test Loss: 82.9174
# Epoch [567/1000], Train Loss: 293.7944, Test Loss: 84.6688
# Epoch [568/1000], Train Loss: 293.9603, Test Loss: 89.8507
# Epoch [569/1000], Train Loss: 296.2031, Test Loss: 83.9535
# Epoch [570/1000], Train Loss: 292.4244, Test Loss: 84.0777
# Epoch [571/1000], Train Loss: 291.0375, Test Loss: 83.0347
# Epoch [572/1000], Train Loss: 290.0158, Test Loss: 82.5762
# Epoch [573/1000], Train Loss: 289.8219, Test Loss: 82.0160
# Epoch [574/1000], Train Loss: 290.5448, Test Loss: 84.3844
# Epoch [575/1000], Train Loss: 289.7999, Test Loss: 82.5310
# Epoch [576/1000], Train Loss: 290.2508, Test Loss: 91.0189
# Epoch [577/1000], Train Loss: 292.9927, Test Loss: 83.7477
# Epoch [578/1000], Train Loss: 291.6088, Test Loss: 83.0842
# Epoch [579/1000], Train Loss: 296.3760, Test Loss: 84.4775
# Epoch [580/1000], Train Loss: 290.9772, Test Loss: 82.2957
# Epoch [581/1000], Train Loss: 287.0566, Test Loss: 81.5156
# Epoch [582/1000], Train Loss: 287.1747, Test Loss: 81.0967
# Epoch [583/1000], Train Loss: 295.0517, Test Loss: 84.1390
# Epoch [584/1000], Train Loss: 287.5690, Test Loss: 86.4926
# Epoch [585/1000], Train Loss: 301.6904, Test Loss: 84.2146
# Epoch [586/1000], Train Loss: 287.0192, Test Loss: 82.4782
# Epoch [587/1000], Train Loss: 286.9368, Test Loss: 85.5525
# Epoch [588/1000], Train Loss: 284.5882, Test Loss: 83.6723
# Epoch [589/1000], Train Loss: 286.9774, Test Loss: 84.4709
# Epoch [590/1000], Train Loss: 290.0473, Test Loss: 82.7313
# Epoch [591/1000], Train Loss: 294.8707, Test Loss: 85.6088
# Epoch [592/1000], Train Loss: 290.4679, Test Loss: 83.4367
# Epoch [593/1000], Train Loss: 284.3808, Test Loss: 81.5307
# Epoch [594/1000], Train Loss: 290.4270, Test Loss: 83.2559
# Epoch [595/1000], Train Loss: 284.1172, Test Loss: 82.0339
# Epoch [596/1000], Train Loss: 286.8639, Test Loss: 83.3989
# Epoch [597/1000], Train Loss: 282.5433, Test Loss: 81.0398
# Epoch [598/1000], Train Loss: 288.3225, Test Loss: 83.0107
# Epoch [599/1000], Train Loss: 288.8537, Test Loss: 84.3973
# Epoch [600/1000], Train Loss: 289.0780, Test Loss: 81.9048
# Epoch [601/1000], Train Loss: 284.2238, Test Loss: 85.1556
# Epoch [602/1000], Train Loss: 285.1871, Test Loss: 81.6908
# Epoch [603/1000], Train Loss: 289.6108, Test Loss: 81.4414
# Epoch [604/1000], Train Loss: 285.9479, Test Loss: 80.0449
# Epoch [605/1000], Train Loss: 283.5393, Test Loss: 83.5415
# Epoch [606/1000], Train Loss: 284.1810, Test Loss: 82.6901
# Epoch [607/1000], Train Loss: 290.3451, Test Loss: 87.2966
# Epoch [608/1000], Train Loss: 282.4053, Test Loss: 79.8959
# Epoch [609/1000], Train Loss: 287.5122, Test Loss: 80.3865
# Epoch [610/1000], Train Loss: 281.5567, Test Loss: 80.2558
# Epoch [611/1000], Train Loss: 285.4326, Test Loss: 82.9785
# Epoch [612/1000], Train Loss: 280.3252, Test Loss: 80.7426
# Epoch [613/1000], Train Loss: 285.4700, Test Loss: 83.7095
# Epoch [614/1000], Train Loss: 282.9431, Test Loss: 81.6495
# Epoch [615/1000], Train Loss: 283.9880, Test Loss: 83.4966
# Epoch [616/1000], Train Loss: 283.4096, Test Loss: 80.5544
# Epoch [617/1000], Train Loss: 280.7151, Test Loss: 82.1802
# Epoch [618/1000], Train Loss: 281.0591, Test Loss: 82.2342
# Epoch [619/1000], Train Loss: 282.8434, Test Loss: 82.8109
# Epoch [620/1000], Train Loss: 282.8393, Test Loss: 80.9563
# Epoch [621/1000], Train Loss: 284.3361, Test Loss: 81.4889
# Epoch [622/1000], Train Loss: 281.2511, Test Loss: 83.5660
# Epoch [623/1000], Train Loss: 311.3282, Test Loss: 83.6059
# Epoch [624/1000], Train Loss: 282.6499, Test Loss: 79.1031
# Epoch [625/1000], Train Loss: 277.6582, Test Loss: 80.5259
# Epoch [626/1000], Train Loss: 276.3457, Test Loss: 80.2187
# Epoch [627/1000], Train Loss: 277.8084, Test Loss: 79.2327
# Epoch [628/1000], Train Loss: 279.4176, Test Loss: 82.8205
# Epoch [629/1000], Train Loss: 281.8715, Test Loss: 81.6490
# Epoch [630/1000], Train Loss: 278.8407, Test Loss: 84.1747
# Epoch [631/1000], Train Loss: 284.2427, Test Loss: 82.9572
# Epoch [632/1000], Train Loss: 280.9750, Test Loss: 80.5701
# Epoch [633/1000], Train Loss: 281.1421, Test Loss: 80.5143
# Epoch [634/1000], Train Loss: 287.7147, Test Loss: 81.1049
# Epoch [635/1000], Train Loss: 278.9019, Test Loss: 80.2042
# Epoch [636/1000], Train Loss: 276.5512, Test Loss: 79.6454
# Epoch [637/1000], Train Loss: 278.1826, Test Loss: 78.1365
# Epoch [638/1000], Train Loss: 278.8647, Test Loss: 80.4314
# Epoch [639/1000], Train Loss: 278.8364, Test Loss: 80.0414
# Epoch [640/1000], Train Loss: 280.2891, Test Loss: 81.4650
# Epoch [641/1000], Train Loss: 280.4055, Test Loss: 82.2393
# Epoch [642/1000], Train Loss: 276.8826, Test Loss: 78.6189
# Epoch [643/1000], Train Loss: 275.9258, Test Loss: 81.9723
# Epoch [644/1000], Train Loss: 276.0487, Test Loss: 81.0612
# Epoch [645/1000], Train Loss: 280.0611, Test Loss: 79.3000
# Epoch [646/1000], Train Loss: 277.3399, Test Loss: 80.8709
# Epoch [647/1000], Train Loss: 278.0101, Test Loss: 78.9508
# Epoch [648/1000], Train Loss: 277.1912, Test Loss: 81.0694
# Epoch [649/1000], Train Loss: 306.0781, Test Loss: 83.0717
# Epoch [650/1000], Train Loss: 274.8018, Test Loss: 80.6004
# Epoch [651/1000], Train Loss: 274.5043, Test Loss: 79.1225
# Epoch [652/1000], Train Loss: 271.7678, Test Loss: 80.8381
# Epoch [653/1000], Train Loss: 273.7349, Test Loss: 80.4263
# Epoch [654/1000], Train Loss: 281.0510, Test Loss: 78.8279
# Epoch [655/1000], Train Loss: 275.6630, Test Loss: 77.5840
# Epoch [656/1000], Train Loss: 274.2561, Test Loss: 78.9414
# Epoch [657/1000], Train Loss: 271.9269, Test Loss: 79.8441
# Epoch [658/1000], Train Loss: 274.2062, Test Loss: 78.0594
# Epoch [659/1000], Train Loss: 275.5305, Test Loss: 78.1263
# Epoch [660/1000], Train Loss: 275.3184, Test Loss: 78.8215
# Epoch [661/1000], Train Loss: 274.4195, Test Loss: 79.1232
# Epoch [662/1000], Train Loss: 275.6052, Test Loss: 80.3317
# Epoch [663/1000], Train Loss: 274.7081, Test Loss: 79.7317
# Epoch [664/1000], Train Loss: 273.0536, Test Loss: 79.0303
# Epoch [665/1000], Train Loss: 272.2948, Test Loss: 77.2083
# Epoch [666/1000], Train Loss: 272.0551, Test Loss: 78.6385
# Epoch [667/1000], Train Loss: 271.1491, Test Loss: 80.3329
# Epoch [668/1000], Train Loss: 274.4761, Test Loss: 80.0726
# Epoch [669/1000], Train Loss: 271.6703, Test Loss: 80.0534
# Epoch [670/1000], Train Loss: 276.4600, Test Loss: 78.5515
# Epoch [671/1000], Train Loss: 276.7146, Test Loss: 78.7382
# Epoch [672/1000], Train Loss: 275.6406, Test Loss: 79.2315
# Epoch [673/1000], Train Loss: 280.9274, Test Loss: 78.4715
# Epoch [674/1000], Train Loss: 274.3421, Test Loss: 79.1595
# Epoch [675/1000], Train Loss: 270.2463, Test Loss: 76.1347
# Epoch [676/1000], Train Loss: 269.7767, Test Loss: 79.9392
# Epoch [677/1000], Train Loss: 275.7987, Test Loss: 79.5384
# Epoch [678/1000], Train Loss: 272.3344, Test Loss: 79.5081
# Epoch [679/1000], Train Loss: 272.7045, Test Loss: 80.5811
# Epoch [680/1000], Train Loss: 276.3363, Test Loss: 77.2304
# Epoch [681/1000], Train Loss: 270.3832, Test Loss: 81.2776
# Epoch [682/1000], Train Loss: 274.3969, Test Loss: 80.8724
# Epoch [683/1000], Train Loss: 272.3183, Test Loss: 77.4065
# Epoch [684/1000], Train Loss: 271.7521, Test Loss: 79.8273
# Epoch [685/1000], Train Loss: 271.0398, Test Loss: 79.6843
# Epoch [686/1000], Train Loss: 267.9660, Test Loss: 79.6988
# Epoch [687/1000], Train Loss: 270.2912, Test Loss: 76.3663
# Epoch [688/1000], Train Loss: 270.6129, Test Loss: 78.5842
# Epoch [689/1000], Train Loss: 268.9136, Test Loss: 77.4065
# Epoch [690/1000], Train Loss: 277.5456, Test Loss: 118.8257
# Epoch [691/1000], Train Loss: 307.3005, Test Loss: 79.0801
# Epoch [692/1000], Train Loss: 263.8059, Test Loss: 79.9569
# Epoch [693/1000], Train Loss: 264.2235, Test Loss: 77.2703
# Epoch [694/1000], Train Loss: 265.3916, Test Loss: 77.8109
# Epoch [695/1000], Train Loss: 278.5166, Test Loss: 77.5794
# Epoch [696/1000], Train Loss: 266.2540, Test Loss: 76.9948
# Epoch [697/1000], Train Loss: 265.8578, Test Loss: 76.3568
# Epoch [698/1000], Train Loss: 267.8675, Test Loss: 79.1641
# Epoch [699/1000], Train Loss: 265.7712, Test Loss: 78.2383
# Epoch [700/1000], Train Loss: 266.5876, Test Loss: 78.6793
# Epoch [701/1000], Train Loss: 272.8744, Test Loss: 84.3433
# Epoch [702/1000], Train Loss: 270.1265, Test Loss: 77.2749
# Epoch [703/1000], Train Loss: 267.6934, Test Loss: 77.7830
# Epoch [704/1000], Train Loss: 269.4237, Test Loss: 78.3567
# Epoch [705/1000], Train Loss: 270.8575, Test Loss: 76.2839
# Epoch [706/1000], Train Loss: 266.2198, Test Loss: 77.4498
# Epoch [707/1000], Train Loss: 264.4489, Test Loss: 76.4698
# Epoch [708/1000], Train Loss: 267.6320, Test Loss: 77.0612
# Epoch [709/1000], Train Loss: 279.7395, Test Loss: 78.7288
# Epoch [710/1000], Train Loss: 270.6928, Test Loss: 76.5833
# Epoch [711/1000], Train Loss: 266.6090, Test Loss: 76.9132
# Epoch [712/1000], Train Loss: 263.0012, Test Loss: 79.2995
# Epoch [713/1000], Train Loss: 267.5663, Test Loss: 79.2070
# Epoch [714/1000], Train Loss: 264.9581, Test Loss: 75.6191
# Epoch [715/1000], Train Loss: 267.4344, Test Loss: 78.5809
# Epoch [716/1000], Train Loss: 266.6890, Test Loss: 76.8807
# Epoch [717/1000], Train Loss: 264.9002, Test Loss: 75.9263
# Epoch [718/1000], Train Loss: 271.3492, Test Loss: 77.7205
# Epoch [719/1000], Train Loss: 265.2632, Test Loss: 78.6006
# Epoch [720/1000], Train Loss: 268.7332, Test Loss: 77.7033
# Epoch [721/1000], Train Loss: 264.2927, Test Loss: 79.3237
# Epoch [722/1000], Train Loss: 266.5873, Test Loss: 76.6457
# Epoch [723/1000], Train Loss: 263.3370, Test Loss: 77.8135
# Epoch [724/1000], Train Loss: 264.0160, Test Loss: 76.0893
# Epoch [725/1000], Train Loss: 262.8535, Test Loss: 79.0184
# Epoch [726/1000], Train Loss: 266.3865, Test Loss: 76.4295
# Epoch [727/1000], Train Loss: 265.7743, Test Loss: 76.3575
# Epoch [728/1000], Train Loss: 264.3727, Test Loss: 75.4148
# Epoch [729/1000], Train Loss: 267.0247, Test Loss: 77.8458
# Epoch [730/1000], Train Loss: 268.0982, Test Loss: 82.0754
# Epoch [731/1000], Train Loss: 266.3776, Test Loss: 78.7500
# Epoch [732/1000], Train Loss: 264.0694, Test Loss: 75.6782
# Epoch [733/1000], Train Loss: 261.7166, Test Loss: 77.8732
# Epoch [734/1000], Train Loss: 261.8489, Test Loss: 75.8360
# Epoch [735/1000], Train Loss: 263.6533, Test Loss: 78.7785
# Epoch [736/1000], Train Loss: 263.9566, Test Loss: 79.3004
# Epoch [737/1000], Train Loss: 265.2051, Test Loss: 76.0274
# Epoch [738/1000], Train Loss: 263.2136, Test Loss: 75.6264
# Epoch [739/1000], Train Loss: 265.3209, Test Loss: 77.0502
# Epoch [740/1000], Train Loss: 262.1581, Test Loss: 77.7021
# Epoch [741/1000], Train Loss: 264.0388, Test Loss: 77.1682
# Epoch [742/1000], Train Loss: 264.0559, Test Loss: 73.3227
# Epoch [743/1000], Train Loss: 260.8333, Test Loss: 76.7857
# Epoch [744/1000], Train Loss: 258.9459, Test Loss: 75.5831
# Epoch [745/1000], Train Loss: 264.6441, Test Loss: 78.4865
# Epoch [746/1000], Train Loss: 263.6310, Test Loss: 78.1545
# Epoch [747/1000], Train Loss: 263.7142, Test Loss: 76.4999
# Epoch [748/1000], Train Loss: 257.9804, Test Loss: 74.9383
# Epoch [749/1000], Train Loss: 263.4050, Test Loss: 76.2030
# Epoch [750/1000], Train Loss: 260.3101, Test Loss: 76.1871
# Epoch [751/1000], Train Loss: 263.9956, Test Loss: 76.8480
# Epoch [752/1000], Train Loss: 261.7460, Test Loss: 75.7815
# Epoch [753/1000], Train Loss: 265.7039, Test Loss: 75.6095
# Epoch [754/1000], Train Loss: 260.3788, Test Loss: 76.5616
# Epoch [755/1000], Train Loss: 265.0291, Test Loss: 76.0237
# Epoch [756/1000], Train Loss: 258.9053, Test Loss: 77.2668
# Epoch [757/1000], Train Loss: 256.9159, Test Loss: 76.3002
# Epoch [758/1000], Train Loss: 260.2622, Test Loss: 75.5146
# Epoch [759/1000], Train Loss: 261.3979, Test Loss: 76.9384
# Epoch [760/1000], Train Loss: 261.8122, Test Loss: 75.3779
# Epoch [761/1000], Train Loss: 294.0883, Test Loss: 102.8833
# Epoch [762/1000], Train Loss: 284.7679, Test Loss: 77.5868
# Epoch [763/1000], Train Loss: 255.2424, Test Loss: 73.8077
# Epoch [764/1000], Train Loss: 256.1194, Test Loss: 74.5965
# Epoch [765/1000], Train Loss: 254.6784, Test Loss: 75.8023
# Epoch [766/1000], Train Loss: 251.2900, Test Loss: 74.1335
# Epoch [767/1000], Train Loss: 255.3441, Test Loss: 73.7796
# Epoch [768/1000], Train Loss: 257.3640, Test Loss: 75.4551
# Epoch [769/1000], Train Loss: 256.5792, Test Loss: 74.8222
# Epoch [770/1000], Train Loss: 257.6319, Test Loss: 74.8719
# Epoch [771/1000], Train Loss: 259.1883, Test Loss: 75.3524
# Epoch [772/1000], Train Loss: 260.1074, Test Loss: 77.9411
# Epoch [773/1000], Train Loss: 256.3735, Test Loss: 75.5178
# Epoch [774/1000], Train Loss: 264.1657, Test Loss: 77.3186
# Epoch [775/1000], Train Loss: 256.0810, Test Loss: 77.0923
# Epoch [776/1000], Train Loss: 260.1251, Test Loss: 76.0440
# Epoch [777/1000], Train Loss: 265.3690, Test Loss: 74.1226
# Epoch [778/1000], Train Loss: 254.7706, Test Loss: 75.4013
# Epoch [779/1000], Train Loss: 255.6055, Test Loss: 74.0857
# Epoch [780/1000], Train Loss: 257.0842, Test Loss: 76.1183
# Epoch [781/1000], Train Loss: 258.8612, Test Loss: 74.8535
# Epoch [782/1000], Train Loss: 255.9020, Test Loss: 75.4520
# Epoch [783/1000], Train Loss: 257.9045, Test Loss: 76.6186
# Epoch [784/1000], Train Loss: 278.2484, Test Loss: 76.8205
# Epoch [785/1000], Train Loss: 257.1883, Test Loss: 73.7252
# Epoch [786/1000], Train Loss: 256.5921, Test Loss: 73.3583
# Epoch [787/1000], Train Loss: 254.1894, Test Loss: 73.7776
# Epoch [788/1000], Train Loss: 252.6399, Test Loss: 75.1012
# Epoch [789/1000], Train Loss: 259.5759, Test Loss: 75.6038
# Epoch [790/1000], Train Loss: 254.5514, Test Loss: 75.5202
# Epoch [791/1000], Train Loss: 256.8865, Test Loss: 77.2487
# Epoch [792/1000], Train Loss: 263.0992, Test Loss: 90.2978
# Early stopping at epoch 792
# Execution time: 4343.408836603165 seconds

# %%
np.array(test_losses).min()
# Out:
# 73.32267376035452

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load validation dataset
spectraVal = np.load(f'Dataset44_{base_name}_ForManuscript_Val_Spec.npy')
concVal = np.load(f'Dataset44_{base_name}_ForManuscript_Val_Conc.npy')



# Load representative validation spectra and concentrations
# Load spectra of varied concentrations (all metabolites at X-mM from 0.005mm to 20mM)
ConcSpec = np.load(f'Concentration_44met_{base_name}_ForManuscript_Spec.npy')
ConcConc = np.load(f'Concentration_44met_{base_name}_ForManuscript_Conc.npy')  
#  Load uniform concentration distribution validation spectra
UniformSpec = np.load(f'UniformDist_44met_{base_name}_ForManuscript_Spec.npy')
UniformConc = np.load(f'UniformDist_44met_{base_name}_ForManuscript_Conc.npy')  
#  Load low concentration uniform concentration distribution validation spectra
LowUniformSpec = np.load(f'LowUniformDist_44met_{base_name}_ForManuscript_Spec.npy')
LowUniformConc = np.load(f'LowUniformDist_44met_{base_name}_ForManuscript_Conc.npy')
#  Load tissue mimicking concentration distribution validation spectra
MimicTissueRangeSpec = np.load(f'MimicTissueRange_44met_{base_name}_ForManuscript_Spec.npy')
MimicTissueRangeConc = np.load(f'MimicTissueRange_44met_{base_name}_ForManuscript_Conc.npy')
#  Load liver tissue mimicking concentration distribution (high relative glucose) validation spectra
MimicTissueRangeGlucSpec = np.load(f'MimicTissueRangeGluc_44met_{base_name}_ForManuscript_Spec.npy')
MimicTissueRangeGlucConc = np.load(f'MimicTissueRangeGluc_44met_{base_name}_ForManuscript_Conc.npy')
#  Load high dynamic range #2 validation spectra
HighDynamicRange2Spec = np.load(f'HighDynRange2_44met_{base_name}_ForManuscript_Spec.npy')
HighDynamicRange2Conc = np.load(f'HighDynRange2_44met_{base_name}_ForManuscript_Conc.npy') 
#  Load varied SNR validation spectra
SNR_Spec = np.load(f'SNR_44met_{base_name}_ForManuscript_Spec.npy')
SNR_Conc = np.load(f'SNR_44met_{base_name}_ForManuscript_Conc.npy')
#  Load random singlet validation spectra
Singlet_Spec = np.load(f'Singlet_44met_{base_name}_ForManuscript_Spec.npy')
Singlet_Conc = np.load(f'Singlet_44met_{base_name}_ForManuscript_Conc.npy')
#  Load random qref checker validation spectra
QrefSensSpec = np.load(f'QrefSensitivity_44met_{base_name}_ForManuscript_Spec.npy')
QrefSensConc = np.load(f'QrefSensitivity_44met_{base_name}_ForManuscript_Conc.npy')
#  Load other validation spectra
OtherValSpectra = np.load(f'OtherVal_44met_{base_name}_ForManuscript_Spec.npy')
OtherValConc = np.load(f'OtherVal_44met_{base_name}_ForManuscript_Conc.npy')



# Move the input data to the GPU device
spectraVal = torch.tensor(spectraVal).float().to(device)   
concVal = torch.tensor(concVal).float().to(device)
ConcSpec = torch.tensor(ConcSpec).float().to(device)   
ConcConc = torch.tensor(ConcConc).float().to(device)
UniformSpec = torch.tensor(UniformSpec).float().to(device)   
UniformConc = torch.tensor(UniformConc).float().to(device)
LowUniformSpec = torch.tensor(LowUniformSpec).float().to(device)   
LowUniformConc = torch.tensor(LowUniformConc).float().to(device)
MimicTissueRangeSpec = torch.tensor(MimicTissueRangeSpec).float().to(device)   
MimicTissueRangeConc = torch.tensor(MimicTissueRangeConc).float().to(device)
MimicTissueRangeGlucSpec = torch.tensor(MimicTissueRangeGlucSpec).float().to(device)   
MimicTissueRangeGlucConc = torch.tensor(MimicTissueRangeGlucConc).float().to(device)
HighDynamicRange2Spec = torch.tensor(HighDynamicRange2Spec).float().to(device)   
HighDynamicRange2Conc = torch.tensor(HighDynamicRange2Conc).float().to(device)
SNR_Spec = torch.tensor(SNR_Spec).float().to(device)   
SNR_Conc = torch.tensor(SNR_Conc).float().to(device)
Singlet_Spec = torch.tensor(Singlet_Spec).float().to(device)   
Singlet_Conc = torch.tensor(Singlet_Conc).float().to(device)
QrefSensSpec = torch.tensor(QrefSensSpec).float().to(device)   
QrefSensConc = torch.tensor(QrefSensConc).float().to(device)
OtherValSpectra = torch.tensor(OtherValSpectra).float().to(device)   
OtherValConc = torch.tensor(OtherValConc).float().to(device)

# %%
## Make sure best parameters are being utilized

# Switch to directory for saving model parameters
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Define the path where you saved your model parameters
save_path = ModelName + '_Params.pt'

# Load the entire dictionary from the saved file
checkpoint = torch.load(save_path)

# Instantiate the model
model_aq = Transformer(input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout)

# Load the model's state dictionary from the loaded dictionary
model_aq.load_state_dict(checkpoint['model_state_dict'])

# Move the model to the GPU 
model_aq.to(device)
# Out:
# /home/htjhnson/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Transformer(
#   (embedding): Linear(in_features=1000, out_features=512, bias=True)
#   (positional_encoding): PositionalEncoding()
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=23552, out_features=44, bias=True)
# )

# %%
Prediction = model_aq(spectraVal[0].unsqueeze(0))

Prediction
# Out:
# tensor([[2.3337, 0.9213, 0.0636, 0.3121, 0.0530, 0.6237, 0.0922, 0.4905, 1.1159,
#          0.6209, 0.4462, 0.1481, 0.7735, 0.2407, 0.6769, 0.6654, 0.0361, 0.4316,
#          0.0187, 0.2812, 0.1021, 0.7759, 0.0389, 1.1435, 0.9037, 0.1123, 0.1313,
#          0.9291, 0.4156, 0.0120, 2.3224, 0.2581, 0.9490, 0.8404, 0.0444, 0.4894,
#          0.7083, 0.1321, 1.8045, 0.1069, 5.3482, 0.0520, 2.6141, 0.0489]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
Prediction.detach().cpu().numpy()[0]
# Out:
# array([2.333733  , 0.9212808 , 0.06363979, 0.31206876, 0.05298594,
#        0.6237164 , 0.09217171, 0.4905454 , 1.1158792 , 0.6209356 ,
#        0.44618523, 0.1480578 , 0.7735436 , 0.24072139, 0.67694354,
#        0.66536504, 0.03608605, 0.43159965, 0.01867029, 0.28118742,
#        0.10209971, 0.77590173, 0.03888998, 1.143466  , 0.90365875,
#        0.11231674, 0.13134061, 0.9290956 , 0.4156268 , 0.01203237,
#        2.322426  , 0.25811413, 0.94901276, 0.84044015, 0.04440038,
#        0.48938176, 0.7083239 , 0.13206197, 1.8044686 , 0.10688232,
#        5.3482356 , 0.05198409, 2.6140697 , 0.04888411], dtype=float32)

# %%
## Compute absolute percent error statistics on validation set

APEs = []
MAPEs = []

for i in np.arange(5000):
    GroundTruth = concVal[i].cpu().numpy()  # Move GroundTruth tensor to CPU and convert to NumPy array
    model_aq.eval()
    Prediction = model_aq(spectraVal[i].unsqueeze(0))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()[0]

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ValExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ValExamples_MAPEs.npy", np.array(MAPEs))



print('Overall MAPE: ',np.array(MAPEs).mean())
# Out:
# Overall MAPE:  14.815657159146923

# %%
## Compute absolute percent error statistics on concentration varied validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = ConcConc[i]
    model_aq.eval()
    Prediction = model_aq(ConcSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ConcExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ConcExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Concentrations:",ConcConc[i][0].item())
# Out:
# Overall MAPE:  inf
# --------------------
# inf  - Concentrations: 0.0
# 65.4  - Concentrations: 0.004999999888241291
# 11.96  - Concentrations: 0.02500000037252903
# 3.09  - Concentrations: 0.10000000149011612
# 1.5  - Concentrations: 0.25
# 0.78  - Concentrations: 0.5
# 0.63  - Concentrations: 1.0
# 0.63  - Concentrations: 2.5
# 9.22  - Concentrations: 10.0
# 25.6  - Concentrations: 20.0

# %%
## Compute absolute percent error statistics on uniform distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = UniformConc[i]
    model_aq.eval()
    Prediction = model_aq(UniformSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "UniformExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "UniformExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(UniformConc[i].min().item(),4), " - Mean Value:", np.round(UniformConc[i].mean().item(),1))
# Out:
# Overall MAPE:  15.570964
# --------------------
# 11.07  - Min Value: 0.6783  - Mean Value: 9.2
# 19.53  - Min Value: 0.0096  - Mean Value: 10.3
# 32.27  - Min Value: 0.147  - Mean Value: 10.5
# 7.67  - Min Value: 0.5572  - Mean Value: 8.5
# 17.66  - Min Value: 1.3567  - Mean Value: 10.6
# 10.8  - Min Value: 0.6332  - Mean Value: 10.9
# 15.84  - Min Value: 0.7017  - Mean Value: 11.0
# 20.66  - Min Value: 0.3674  - Mean Value: 8.9
# 9.49  - Min Value: 0.8387  - Mean Value: 9.8
# 10.73  - Min Value: 1.0913  - Mean Value: 11.1

# %%
## Compute absolute percent error statistics on low concentration uniform distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = LowUniformConc[i]
    model_aq.eval()
    Prediction = model_aq(LowUniformSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "LowUniformExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "LowUniformExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(LowUniformConc[i].min().item(),4), " - Mean Value:", np.round(LowUniformConc[i].mean().item(),1))
# Out:
# Overall MAPE:  4.450469
# --------------------
# 3.22  - Min Value: 0.0111  - Mean Value: 0.1
# 4.44  - Min Value: 0.0103  - Mean Value: 0.1
# 2.65  - Min Value: 0.0153  - Mean Value: 0.1
# 5.2  - Min Value: 0.0117  - Mean Value: 0.1
# 4.86  - Min Value: 0.0089  - Mean Value: 0.1
# 4.96  - Min Value: 0.0075  - Mean Value: 0.1
# 4.13  - Min Value: 0.0117  - Mean Value: 0.1
# 4.23  - Min Value: 0.0052  - Mean Value: 0.1
# 7.44  - Min Value: 0.008  - Mean Value: 0.1
# 3.37  - Min Value: 0.0134  - Mean Value: 0.1

# %%
## Compute absolute percent error statistics on tissue mimicking distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = MimicTissueRangeConc[i]
    model_aq.eval()
    Prediction = model_aq(MimicTissueRangeSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "MimicTissueRangeExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "MimicTissueRangeExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(MimicTissueRangeConc[i].min().item(),4), " - Mean Value:", np.round(MimicTissueRangeConc[i].mean().item(),1))
# Out:
# Overall MAPE:  10.067224
# --------------------
# 25.9  - Min Value: 0.008  - Mean Value: 0.8
# 17.37  - Min Value: 0.009  - Mean Value: 0.9
# 15.87  - Min Value: 0.0138  - Mean Value: 1.5
# 3.89  - Min Value: 0.0107  - Mean Value: 0.7
# 5.35  - Min Value: 0.0191  - Mean Value: 0.7
# 7.56  - Min Value: 0.0186  - Mean Value: 0.8
# 5.08  - Min Value: 0.0175  - Mean Value: 0.8
# 5.86  - Min Value: 0.0238  - Mean Value: 1.3
# 4.82  - Min Value: 0.0168  - Mean Value: 0.7
# 8.98  - Min Value: 0.0171  - Mean Value: 0.9

# %%
## Compute absolute percent error statistics on tissue mimicking distribution validation spectra (high relative glucose concentration)

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = MimicTissueRangeGlucConc[i]
    model_aq.eval()
    Prediction = model_aq(MimicTissueRangeGlucSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "MimicTissueRangeGlucExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "MimicTissueRangeGlucExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(MimicTissueRangeGlucConc[i].min().item(),4), " - Mean Value:", np.round(MimicTissueRangeGlucConc[i].mean().item(),1))
# Out:
# Overall MAPE:  14.23889
# --------------------
# 9.94  - Min Value: 0.013  - Mean Value: 0.6
# 10.67  - Min Value: 0.0115  - Mean Value: 0.4
# 10.53  - Min Value: 0.0115  - Mean Value: 0.4
# 11.1  - Min Value: 0.0115  - Mean Value: 0.6
# 26.55  - Min Value: 0.0115  - Mean Value: 1.0
# 21.87  - Min Value: 0.0115  - Mean Value: 1.1
# 20.27  - Min Value: 0.0115  - Mean Value: 0.8
# 5.98  - Min Value: 0.0115  - Mean Value: 0.5
# 8.1  - Min Value: 0.0115  - Mean Value: 0.5
# 17.38  - Min Value: 0.0115  - Mean Value: 1.1

# %%
## Compute absolute percent error statistics on a further high dynamic range dataset

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = HighDynamicRange2Conc[i]
    model_aq.eval()
    Prediction = model_aq(HighDynamicRange2Spec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "HighDynamicRange2Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "HighDynamicRange2Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(HighDynamicRange2Conc[i].min().item(),4), " - Mean Value:", np.round(HighDynamicRange2Conc[i].mean().item(),1))
# Out:
# Overall MAPE:  226.72726
# --------------------
# 148.22  - Min Value: 0.0062  - Mean Value: 2.1
# 143.85  - Min Value: 0.006  - Mean Value: 3.7
# 200.69  - Min Value: 0.0066  - Mean Value: 4.3
# 668.0  - Min Value: 0.0094  - Mean Value: 4.3
# 160.2  - Min Value: 0.0068  - Mean Value: 4.9
# 161.31  - Min Value: 0.005  - Mean Value: 3.8
# 184.88  - Min Value: 0.0101  - Mean Value: 3.2
# 43.67  - Min Value: 0.0062  - Mean Value: 3.2
# 257.96  - Min Value: 0.0053  - Mean Value: 5.3
# 298.49  - Min Value: 0.0054  - Mean Value: 2.5

# %%
ConcConc[5]
# Out:
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000],
#        device='cuda:0')

# %%
model_aq(ConcSpec[5])
# Out:
# tensor([[0.5048, 0.5004, 0.4908, 0.4981, 0.5041, 0.5038, 0.5011, 0.5036, 0.4945,
#          0.4938, 0.5030, 0.5041, 0.5015, 0.5043, 0.5032, 0.5054, 0.5100, 0.4990,
#          0.4981, 0.4995, 0.5019, 0.5036, 0.5059, 0.5053, 0.5026, 0.5019, 0.4987,
#          0.4981, 0.4912, 0.5024, 0.5006, 0.5125, 0.5077, 0.4954, 0.5026, 0.5055,
#          0.5012, 0.4935, 0.5095, 0.5028, 0.5008, 0.4987, 0.5008, 0.5049]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
model_aq(SNR_Spec[1])
# Out:
# tensor([[0.4342, 0.4331, 0.4204, 0.4248, 0.4359, 0.4304, 0.4321, 0.4311, 0.4259,
#          0.4241, 0.4322, 0.4334, 0.4326, 0.4334, 0.4455, 0.4333, 0.4398, 0.4300,
#          0.4297, 0.4306, 0.4308, 0.4377, 0.4295, 0.4360, 0.4302, 0.4320, 0.4256,
#          0.4303, 0.4246, 0.4321, 0.4305, 0.4388, 0.4404, 0.4247, 0.4311, 0.4340,
#          0.4341, 0.4318, 0.4315, 0.4341, 0.4269, 0.4286, 0.4325, 0.4303]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
## Compute absolute percent error statistics on a examples of varying SNR

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(SNR_Spec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "SNR_Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "SNR_Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  1.3034025244178533
# --------------------
# 0.85
# 0.85
# 0.88
# 0.93
# 1.26
# 1.43
# 1.34
# 1.78
# 2.06
# 1.67

# %%
## Compute absolute percent error statistics on a dataset with singlets added at random

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(Singlet_Spec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "SingletExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "SingletExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  9.50344510738744
# --------------------
# 0.95
# 1.0
# 0.95
# 2.11
# 12.27
# 12.35
# 12.19
# 14.13
# 17.57
# 21.5

# %%
## Compute absolute percent error statistics on a examples of varying SNR

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(QrefSensSpec[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "QrefSensitivity_Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "QrefSensitivity_Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  18.488614384644126
# --------------------
# 1.9
# 6.41
# 10.44
# 13.92
# 17.48
# 20.75
# 24.18
# 27.28
# 30.21
# 32.32

# %%
Pred = model_aq(OtherValSpectra[0])
Pred[0][Pred[0] < 0] = 0
print("Sinusoidal Baseline 1")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(OtherValSpectra[1])
Pred[0][Pred[0] < 0] = 0
print("Sinusoidal Baseline 2")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(OtherValSpectra[2])
Pred[0][Pred[0] < 0] = 0
print("HD-Range 1 - 0.01s and 20s")
print(Pred[0])

Pred = model_aq(OtherValSpectra[3])
Pred[0][Pred[0] < 0] = 0
print("HD-Range 2 - 0s and 20s")
print(Pred[0])
# Out:
# Sinusoidal Baseline 1
# tensor([0.4559, 0.5460, 0.3815, 0.5380, 0.4864, 0.4588, 0.4742, 0.5381, 0.5798,
#         0.4013, 0.4210, 0.5915, 0.5148, 0.7289, 0.3608, 0.5935, 0.5451, 0.4544,
#         0.4672, 0.4064, 0.4432, 0.7241, 0.3726, 0.5065, 0.5047, 0.4725, 0.5286,
#         0.5825, 0.4927, 0.4381, 0.4490, 0.7894, 0.4607, 0.4164, 0.4677, 0.4346,
#         0.4603, 0.4022, 0.6309, 0.3826, 0.4047, 0.4669, 0.5181, 0.4620],
#        device='cuda:0', grad_fn=<SelectBackward0>)
# ___________
# ___________
# Sinusoidal Baseline 2
# tensor([0.3747, 0.4841, 0.1776, 0.5057, 0.4133, 0.4280, 0.4177, 0.2908, 0.4894,
#         0.4910, 0.4216, 0.4560, 0.7120, 0.3901, 0.6029, 0.2290, 0.6512, 0.4970,
#         0.4538, 0.3792, 0.3742, 0.4425, 0.5656, 0.5495, 0.4136, 0.4477, 0.2798,
#         0.1375, 0.5198, 0.3970, 0.4517, 0.3706, 0.3611, 0.4266, 0.5344, 0.4279,
#         0.5371, 0.6458, 0.5007, 0.3589, 0.4376, 0.6444, 0.3110, 0.2789],
#        device='cuda:0', grad_fn=<SelectBackward0>)
# ___________
# ___________
# HD-Range 1 - 0.01s and 20s
# tensor([ 0.2575, 18.1950,  0.0000, 19.0674,  0.0000, 18.6024,  0.0000, 14.9058,
#          0.0000, 17.6374,  0.0000, 19.4624,  0.0000, 21.3607,  2.3019, 19.5689,
#          0.2650, 19.5194,  0.0000, 18.7425,  0.0000, 19.4114,  0.6820, 17.5125,
#          0.0000, 18.5120,  0.0000, 19.4550,  0.0000, 16.7601,  0.4824, 18.0829,
#          0.0000, 15.1776,  0.4267, 14.7751,  0.0000, 18.0606,  0.0000, 16.1992,
#          0.0000, 19.1974,  0.0000, 17.5368], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# HD-Range 2 - 0s and 20s
# tensor([ 0.2470, 18.1952,  0.0000, 19.0709,  0.0000, 18.6010,  0.0000, 14.9061,
#          0.0000, 17.6358,  0.0000, 19.4694,  0.0000, 21.3583,  2.2936, 19.5709,
#          0.2579, 19.5181,  0.0000, 18.7420,  0.0000, 19.4150,  0.6769, 17.5136,
#          0.0000, 18.5126,  0.0000, 19.4630,  0.0000, 16.7605,  0.4733, 18.0881,
#          0.0000, 15.1781,  0.4210, 14.7742,  0.0000, 18.0635,  0.0000, 16.2019,
#          0.0000, 19.1972,  0.0000, 17.5368], device='cuda:0',
#        grad_fn=<SelectBackward0>)
