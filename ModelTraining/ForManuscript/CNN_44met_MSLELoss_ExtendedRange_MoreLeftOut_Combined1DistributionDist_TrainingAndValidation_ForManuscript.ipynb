# %%
## Import dependencies

import numpy as np
from os import path
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import time


# Set default plot size
plt.rcParams["figure.figsize"] = (30,20)

# Define number of epochs used later in training
num_epochs = 500

# Identification part of the filenames
model_base_name = 'MSLE_ExtendedRange_MoreLeftOut_Combined1Distribution'
base_name = 'ExtendedRange_MoreLeftOut_Combined1Distribution'    # This is the dataset base name
base_dir = '/path/to/base/directory'   # Set base directory

# %% [markdown]
# ## Train CNN on dataset of 44 metabolites

# %%
# Name variable used for saving model metrics, name should reflect model used, dataset used, and other information such as # of epochs
ModelName = f"CNN_44met_{model_base_name}Dist_TrainingAndValidation_ForManuscript_" + str(num_epochs) +"ep"

# Set the random seed
os.chdir(base_dir+'/DL-NMR-Optimization/ModelPerformanceMetrics/') 
seed = 1
torch.manual_seed(seed)
np.save(ModelName + "_Seed.npy", seed)

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir(base_dir+'/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load training data and max value from testing and training datasets
spectra = np.load(f'Dataset44_{base_name}_ForManuscript_Spec.npy')
conc1 = np.load(f'Dataset44_{base_name}_ForManuscript_Conc.npy')

# %%
## Prepare to switch data from CPU to GPU

# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    device = torch.device("cuda")          # A CUDA device object
    print("Using GPU for training.")
else:
    device = torch.device("cpu")           # A CPU object
    print("CUDA is not available. Using CPU for training.")
# Out:
# Using GPU for training.

# %%
## Set up data for testing and training

# Split into testing and training data
X_train, X_test, y_train, y_test = train_test_split(spectra, conc1, test_size = 0.2, random_state = 1)

# Tensorize and prepare datasets
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()


# Move the input data to the GPU device
X_train = X_train.to(device)
X_test = X_test.to(device)
#spectraVal = torch.tensor(spectraVal).float().to(device)   # Confusing names, these spectra are the 5000 spectra generated like the training dataset
#ValSpectra = torch.tensor(ValSpectra).float().to(device)   # Confusing names, these spectra are the 10 representative example spectra

# Move the target data to the GPU device
y_train = y_train.to(device)
y_test = y_test.to(device)
#concVal = torch.tensor(concVal).float().to(device)
#ValConc = torch.tensor(ValConc).float().to(device)

# More data prep?
datasets = torch.utils.data.TensorDataset(X_train, y_train)
Test_datasets = torch.utils.data.TensorDataset(X_test, y_test)
train_dataset_reshaped = [(data.unsqueeze(1), label) for data, label in datasets]
test_dataset_reshaped = [(data.unsqueeze(1), label) for data, label in Test_datasets]
train_iter = torch.utils.data.DataLoader(train_dataset_reshaped, batch_size = 64, shuffle=True)
test_iter = torch.utils.data.DataLoader(test_dataset_reshaped, batch_size = 64, shuffle=True)

# %%
del X_train
del X_test
del y_train
del y_test
del spectra
del conc1
del datasets
del Test_datasets

# %%
## Define NN model object, define some parameters, and instantiate model

# Define some model & training parameters


# Define model
class NMR_Model_Aq(nn.Module):
    def __init__(self):
        super(NMR_Model_Aq, self).__init__()
        self.conv1 = nn.Conv1d(1, 42, kernel_size=6, padding=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=2, padding=1)
        self.conv2 = nn.Conv1d(42, 42, kernel_size=6, padding=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=2, padding=1)
        self.conv3 = nn.Conv1d(42, 42, kernel_size=6, padding=1)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=2, padding=1)
        self.conv4 = nn.Conv1d(42, 42, kernel_size=6, padding=1)
        self.pool4 = nn.MaxPool1d(kernel_size=2, stride=2, padding=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(120708, 200)
        self.fc2 = nn.Linear(200, 44)

    def forward(self, x):
        x = x.permute(0, 2, 1)                  
        x = self.conv1(x)
        x = nn.functional.relu(x)
        x = self.pool1(x)
        x = self.conv2(x)
        x = nn.functional.relu(x)
        x = self.pool2(x)
        x = self.conv3(x)
        x = nn.functional.relu(x)
        x = self.pool3(x)
        x = self.conv4(x)
        x = nn.functional.relu(x)
        x = self.pool4(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = nn.functional.relu(x)
        x = self.fc2(x)
        return x

# %%
class MSLELoss(nn.Module):
    def __init__(self):
        super(MSLELoss, self).__init__()

    def forward(self, y_pred, y_true):
        # Ensure predictions and targets are non-negative
        y_pred = torch.clamp(y_pred, min=1e-6)  # Clamp to avoid log(0)
        y_true = torch.clamp(y_true, min=1e-6)
        
        # Compute the Mean Squared Logarithmic Error
        loss = torch.mean((torch.log(y_pred + 1) - torch.log(y_true + 1)) ** 2)
        return loss

# %%
def train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path):
    criterion = MSLELoss()
    optimizer = optim.AdamW(model.parameters(), lr = 5.287243368897864e-05, weight_decay=0.01)
    
    
    train_losses = []
    test_losses = []
    best_test_loss = float('inf')
    epochs_no_improve = 0
    patience = 50  # Set how many epochs without improvement in validation loss constitutes early stopping

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
        train_losses.append(train_loss)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                test_loss += loss.item() * inputs.size(0)
            test_losses.append(test_loss)
            
            
        if (epoch + 1) % 1 == 0:  # The last number here denotes how often to print loss metrics in terms of epochs
            print(f'Epoch [{epoch + 1}/{num_epochs}], '
                  f'Train Loss: {train_loss:.4f}, '
                  f'Test Loss: {test_loss:.4f}')
            
    
            
        if test_loss < best_test_loss:
            best_test_loss = test_loss
            epochs_no_improve = 0
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
            }, save_path)
        else:
            epochs_no_improve += 1
            
        if epochs_no_improve >= patience:
            print(f'Early stopping at epoch {epoch + 1}')
            break



    return train_losses, test_losses


def train_or_load_model(model, train_loader, test_loader, num_epochs, save_path):
    train_losses = []
    test_losses = []
    is_model_trained = False  # Initialize flag

    if os.path.isfile(save_path):
        print("Loading pretrained model from {}".format(save_path))
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer = optim.Adam(model.parameters())  
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        
    
    else:
        print("No pretrained model found. Training from scratch.")
        #optimizer = optim.Adam(model.parameters())  
        train_losses, test_losses = train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
        is_model_trained = True  # Set flag to True after training
        # Save losses per epoch
        np.save(ModelName + "_TrainLoss.npy", train_losses)
        np.save(ModelName + "_TestLoss.npy", test_losses)
    
    return train_losses, test_losses, is_model_trained  # Return the losses and flag

# %%
## Instantiate model and train

# For timing cell run time
start_time = time.time()


# Switch to directory for saving model parameters
os.chdir(base_dir+'/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Create model
model_aq = NMR_Model_Aq()

# Move the model to the GPU device
model_aq.to(device)

# Define the path to save and load the model parameters
save_path = ModelName + '_Params.pt'

# Call the function
train_losses, test_losses, is_model_trained = train_or_load_model(model_aq, train_iter, test_iter, num_epochs, save_path)


# Finish timing cell run time
end_time = time.time()
execution_time = end_time - start_time
if is_model_trained:
    np.save(ModelName + "_ExecutionTime.npy", execution_time)
    print("Execution time:", execution_time, "seconds")
# Out:
# No pretrained model found. Training from scratch.
# Epoch [1/500], Train Loss: 16353.8025, Test Loss: 3262.0643
# Epoch [2/500], Train Loss: 10829.5866, Test Loss: 2322.6206
# Epoch [3/500], Train Loss: 8332.8477, Test Loss: 1781.3980
# Epoch [4/500], Train Loss: 5374.3526, Test Loss: 966.2644
# Epoch [5/500], Train Loss: 3050.9014, Test Loss: 616.6058
# Epoch [6/500], Train Loss: 2100.7451, Test Loss: 463.2690
# Epoch [7/500], Train Loss: 1644.4588, Test Loss: 379.4464
# Epoch [8/500], Train Loss: 1365.8780, Test Loss: 322.4654
# Epoch [9/500], Train Loss: 1184.4921, Test Loss: 279.1698
# Epoch [10/500], Train Loss: 1045.3831, Test Loss: 253.2621
# Epoch [11/500], Train Loss: 943.5434, Test Loss: 230.3986
# Epoch [12/500], Train Loss: 869.0111, Test Loss: 215.0467
# Epoch [13/500], Train Loss: 808.3485, Test Loss: 198.5047
# Epoch [14/500], Train Loss: 758.9311, Test Loss: 186.7470
# Epoch [15/500], Train Loss: 727.2284, Test Loss: 182.4742
# Epoch [16/500], Train Loss: 707.6614, Test Loss: 175.9953
# Epoch [17/500], Train Loss: 687.3692, Test Loss: 171.2069
# Epoch [18/500], Train Loss: 673.9789, Test Loss: 168.8787
# Epoch [19/500], Train Loss: 662.1754, Test Loss: 168.3150
# Epoch [20/500], Train Loss: 652.3232, Test Loss: 163.4123
# Epoch [21/500], Train Loss: 642.9901, Test Loss: 162.1298
# Epoch [22/500], Train Loss: 639.2104, Test Loss: 160.8877
# Epoch [23/500], Train Loss: 632.8406, Test Loss: 157.0164
# Epoch [24/500], Train Loss: 627.0013, Test Loss: 160.9990
# Epoch [25/500], Train Loss: 625.1665, Test Loss: 159.4085
# Epoch [26/500], Train Loss: 619.0017, Test Loss: 157.1739
# Epoch [27/500], Train Loss: 613.1620, Test Loss: 153.6035
# Epoch [28/500], Train Loss: 610.2881, Test Loss: 154.1902
# Epoch [29/500], Train Loss: 609.2909, Test Loss: 153.9741
# Epoch [30/500], Train Loss: 601.7125, Test Loss: 152.4731
# Epoch [31/500], Train Loss: 599.2969, Test Loss: 149.7586
# Epoch [32/500], Train Loss: 595.1239, Test Loss: 152.2543
# Epoch [33/500], Train Loss: 594.9070, Test Loss: 154.1498
# Epoch [34/500], Train Loss: 598.2272, Test Loss: 149.6083
# Epoch [35/500], Train Loss: 585.6112, Test Loss: 146.3397
# Epoch [36/500], Train Loss: 587.3901, Test Loss: 149.1587
# Epoch [37/500], Train Loss: 587.7397, Test Loss: 145.9068
# Epoch [38/500], Train Loss: 586.4552, Test Loss: 146.2192
# Epoch [39/500], Train Loss: 585.5752, Test Loss: 148.9174
# Epoch [40/500], Train Loss: 584.1293, Test Loss: 153.3967
# Epoch [41/500], Train Loss: 585.3081, Test Loss: 153.3706
# Epoch [42/500], Train Loss: 578.4513, Test Loss: 147.4133
# Epoch [43/500], Train Loss: 579.6084, Test Loss: 147.2320
# Epoch [44/500], Train Loss: 577.2394, Test Loss: 149.4062
# Epoch [45/500], Train Loss: 579.3741, Test Loss: 146.3640
# Epoch [46/500], Train Loss: 578.6850, Test Loss: 147.9493
# Epoch [47/500], Train Loss: 576.0702, Test Loss: 147.9109
# Epoch [48/500], Train Loss: 574.1114, Test Loss: 147.0151
# Epoch [49/500], Train Loss: 577.1110, Test Loss: 145.1983
# Epoch [50/500], Train Loss: 569.8564, Test Loss: 147.2947
# Epoch [51/500], Train Loss: 572.4510, Test Loss: 143.9119
# Epoch [52/500], Train Loss: 573.9222, Test Loss: 146.9326
# Epoch [53/500], Train Loss: 570.8476, Test Loss: 145.8793
# Epoch [54/500], Train Loss: 572.4779, Test Loss: 146.2054
# Epoch [55/500], Train Loss: 568.9261, Test Loss: 145.6355
# Epoch [56/500], Train Loss: 568.5602, Test Loss: 145.9881
# Epoch [57/500], Train Loss: 564.7976, Test Loss: 144.7545
# Epoch [58/500], Train Loss: 566.6944, Test Loss: 145.7946
# Epoch [59/500], Train Loss: 569.4685, Test Loss: 142.4878
# Epoch [60/500], Train Loss: 564.9805, Test Loss: 145.4450
# Epoch [61/500], Train Loss: 563.2921, Test Loss: 143.4824
# Epoch [62/500], Train Loss: 564.2287, Test Loss: 148.1555
# Epoch [63/500], Train Loss: 564.7738, Test Loss: 145.4991
# Epoch [64/500], Train Loss: 570.2261, Test Loss: 141.4810
# Epoch [65/500], Train Loss: 561.6033, Test Loss: 145.0331
# Epoch [66/500], Train Loss: 560.7139, Test Loss: 142.1838
# Epoch [67/500], Train Loss: 562.6745, Test Loss: 145.9691
# Epoch [68/500], Train Loss: 562.8568, Test Loss: 142.8036
# Epoch [69/500], Train Loss: 564.2828, Test Loss: 141.9736
# Epoch [70/500], Train Loss: 558.5951, Test Loss: 142.7018
# Epoch [71/500], Train Loss: 562.3678, Test Loss: 143.6941
# Epoch [72/500], Train Loss: 555.8603, Test Loss: 141.1372
# Epoch [73/500], Train Loss: 559.2916, Test Loss: 141.9453
# Epoch [74/500], Train Loss: 558.9658, Test Loss: 141.6792
# Epoch [75/500], Train Loss: 555.3860, Test Loss: 143.1534
# Epoch [76/500], Train Loss: 557.6919, Test Loss: 143.3579
# Epoch [77/500], Train Loss: 557.6096, Test Loss: 140.8505
# Epoch [78/500], Train Loss: 554.1133, Test Loss: 141.7815
# Epoch [79/500], Train Loss: 560.8057, Test Loss: 144.3316
# Epoch [80/500], Train Loss: 558.4005, Test Loss: 141.2225
# Epoch [81/500], Train Loss: 554.2129, Test Loss: 141.2840
# Epoch [82/500], Train Loss: 551.0510, Test Loss: 141.0833
# Epoch [83/500], Train Loss: 553.1881, Test Loss: 142.9152
# Epoch [84/500], Train Loss: 554.4976, Test Loss: 142.1587
# Epoch [85/500], Train Loss: 553.3444, Test Loss: 141.4071
# Epoch [86/500], Train Loss: 554.2867, Test Loss: 142.7682
# Epoch [87/500], Train Loss: 549.9601, Test Loss: 142.0805
# Epoch [88/500], Train Loss: 550.0911, Test Loss: 140.8030
# Epoch [89/500], Train Loss: 552.5871, Test Loss: 143.2379
# Epoch [90/500], Train Loss: 552.8733, Test Loss: 140.5982
# Epoch [91/500], Train Loss: 549.6507, Test Loss: 143.9993
# Epoch [92/500], Train Loss: 552.3259, Test Loss: 141.8224
# Epoch [93/500], Train Loss: 553.4673, Test Loss: 141.5974
# Epoch [94/500], Train Loss: 552.9826, Test Loss: 140.6456
# Epoch [95/500], Train Loss: 549.2478, Test Loss: 140.8752
# Epoch [96/500], Train Loss: 545.9000, Test Loss: 141.4021
# Epoch [97/500], Train Loss: 547.0232, Test Loss: 140.4836
# Epoch [98/500], Train Loss: 547.7807, Test Loss: 140.4812
# Epoch [99/500], Train Loss: 547.9374, Test Loss: 143.8777
# Epoch [100/500], Train Loss: 551.3375, Test Loss: 140.2264
# Epoch [101/500], Train Loss: 544.3455, Test Loss: 140.3545
# Epoch [102/500], Train Loss: 543.0068, Test Loss: 139.6215
# Epoch [103/500], Train Loss: 549.5586, Test Loss: 141.1734
# Epoch [104/500], Train Loss: 543.2605, Test Loss: 140.7801
# Epoch [105/500], Train Loss: 546.8022, Test Loss: 142.2181
# Epoch [106/500], Train Loss: 550.1922, Test Loss: 140.4573
# Epoch [107/500], Train Loss: 542.2305, Test Loss: 141.2642
# Epoch [108/500], Train Loss: 545.4205, Test Loss: 139.3025
# Epoch [109/500], Train Loss: 542.8853, Test Loss: 139.6810
# Epoch [110/500], Train Loss: 543.6551, Test Loss: 138.1007
# Epoch [111/500], Train Loss: 542.0551, Test Loss: 138.7023
# Epoch [112/500], Train Loss: 542.1780, Test Loss: 141.7124
# Epoch [113/500], Train Loss: 543.0247, Test Loss: 141.1244
# Epoch [114/500], Train Loss: 542.7733, Test Loss: 137.2081
# Epoch [115/500], Train Loss: 542.0342, Test Loss: 144.1568
# Epoch [116/500], Train Loss: 541.2537, Test Loss: 138.3899
# Epoch [117/500], Train Loss: 538.3376, Test Loss: 140.4380
# Epoch [118/500], Train Loss: 539.7536, Test Loss: 141.3535
# Epoch [119/500], Train Loss: 543.6523, Test Loss: 143.5089
# Epoch [120/500], Train Loss: 539.1430, Test Loss: 138.8153
# Epoch [121/500], Train Loss: 541.8883, Test Loss: 138.3550
# Epoch [122/500], Train Loss: 534.6197, Test Loss: 138.7864
# Epoch [123/500], Train Loss: 537.2401, Test Loss: 138.1332
# Epoch [124/500], Train Loss: 535.3136, Test Loss: 139.0270
# Epoch [125/500], Train Loss: 539.1457, Test Loss: 142.8108
# Epoch [126/500], Train Loss: 538.5947, Test Loss: 139.9048
# Epoch [127/500], Train Loss: 536.0846, Test Loss: 140.0170
# Epoch [128/500], Train Loss: 533.9456, Test Loss: 140.1615
# Epoch [129/500], Train Loss: 536.1169, Test Loss: 139.9625
# Epoch [130/500], Train Loss: 534.2865, Test Loss: 138.6563
# Epoch [131/500], Train Loss: 536.3847, Test Loss: 140.4613
# Epoch [132/500], Train Loss: 538.0010, Test Loss: 139.6776
# Epoch [133/500], Train Loss: 534.7251, Test Loss: 141.5458
# Epoch [134/500], Train Loss: 534.1561, Test Loss: 137.4272
# Epoch [135/500], Train Loss: 532.9149, Test Loss: 139.6077
# Epoch [136/500], Train Loss: 535.0005, Test Loss: 140.5753
# Epoch [137/500], Train Loss: 535.4692, Test Loss: 138.4009
# Epoch [138/500], Train Loss: 533.6108, Test Loss: 138.3853
# Epoch [139/500], Train Loss: 532.1568, Test Loss: 138.4533
# Epoch [140/500], Train Loss: 532.5862, Test Loss: 138.6155
# Epoch [141/500], Train Loss: 532.2728, Test Loss: 137.8045
# Epoch [142/500], Train Loss: 532.5573, Test Loss: 137.0773
# Epoch [143/500], Train Loss: 533.3509, Test Loss: 138.5710
# Epoch [144/500], Train Loss: 530.8453, Test Loss: 138.3493
# Epoch [145/500], Train Loss: 527.7425, Test Loss: 137.5597
# Epoch [146/500], Train Loss: 529.6071, Test Loss: 138.9675
# Epoch [147/500], Train Loss: 530.9313, Test Loss: 137.8409
# Epoch [148/500], Train Loss: 527.8538, Test Loss: 136.8240
# Epoch [149/500], Train Loss: 526.5986, Test Loss: 137.8650
# Epoch [150/500], Train Loss: 529.1911, Test Loss: 137.4053
# Epoch [151/500], Train Loss: 526.4699, Test Loss: 135.8015
# Epoch [152/500], Train Loss: 530.7432, Test Loss: 138.8785
# Epoch [153/500], Train Loss: 527.6288, Test Loss: 135.8577
# Epoch [154/500], Train Loss: 528.1162, Test Loss: 135.8556
# Epoch [155/500], Train Loss: 527.6875, Test Loss: 135.5096
# Epoch [156/500], Train Loss: 525.7649, Test Loss: 137.5395
# Epoch [157/500], Train Loss: 526.0297, Test Loss: 136.1828
# Epoch [158/500], Train Loss: 525.7520, Test Loss: 137.2214
# Epoch [159/500], Train Loss: 525.3990, Test Loss: 134.9127
# Epoch [160/500], Train Loss: 527.6242, Test Loss: 136.3858
# Epoch [161/500], Train Loss: 525.8675, Test Loss: 135.4132
# Epoch [162/500], Train Loss: 523.5275, Test Loss: 136.3912
# Epoch [163/500], Train Loss: 526.4318, Test Loss: 136.0708
# Epoch [164/500], Train Loss: 523.0375, Test Loss: 137.6819
# Epoch [165/500], Train Loss: 522.3896, Test Loss: 136.8047
# Epoch [166/500], Train Loss: 525.4333, Test Loss: 136.8088
# Epoch [167/500], Train Loss: 523.0224, Test Loss: 135.0889
# Epoch [168/500], Train Loss: 523.3578, Test Loss: 135.9868
# Epoch [169/500], Train Loss: 522.7235, Test Loss: 136.2921
# Epoch [170/500], Train Loss: 520.8687, Test Loss: 135.0385
# Epoch [171/500], Train Loss: 521.0767, Test Loss: 135.1762
# Epoch [172/500], Train Loss: 521.3982, Test Loss: 135.2209
# Epoch [173/500], Train Loss: 520.6333, Test Loss: 135.5648
# Epoch [174/500], Train Loss: 520.9727, Test Loss: 136.0184
# Epoch [175/500], Train Loss: 521.7868, Test Loss: 138.5460
# Epoch [176/500], Train Loss: 523.9815, Test Loss: 135.2449
# Epoch [177/500], Train Loss: 519.5726, Test Loss: 135.2019
# Epoch [178/500], Train Loss: 517.8490, Test Loss: 134.8440
# Epoch [179/500], Train Loss: 522.0116, Test Loss: 135.4711
# Epoch [180/500], Train Loss: 518.6524, Test Loss: 136.1180
# Epoch [181/500], Train Loss: 520.4239, Test Loss: 135.2462
# Epoch [182/500], Train Loss: 520.1265, Test Loss: 136.3906
# Epoch [183/500], Train Loss: 518.0276, Test Loss: 133.9934
# Epoch [184/500], Train Loss: 518.1533, Test Loss: 134.9161
# Epoch [185/500], Train Loss: 518.9631, Test Loss: 133.8723
# Epoch [186/500], Train Loss: 515.4718, Test Loss: 134.4555
# Epoch [187/500], Train Loss: 519.9145, Test Loss: 136.4044
# Epoch [188/500], Train Loss: 520.0261, Test Loss: 134.2508
# Epoch [189/500], Train Loss: 516.5231, Test Loss: 133.7520
# Epoch [190/500], Train Loss: 516.4562, Test Loss: 135.3313
# Epoch [191/500], Train Loss: 516.5999, Test Loss: 135.3437
# Epoch [192/500], Train Loss: 515.5539, Test Loss: 134.0798
# Epoch [193/500], Train Loss: 516.0129, Test Loss: 135.5646
# Epoch [194/500], Train Loss: 517.4629, Test Loss: 136.4198
# Epoch [195/500], Train Loss: 516.4821, Test Loss: 136.6424
# Epoch [196/500], Train Loss: 516.1479, Test Loss: 135.3888
# Epoch [197/500], Train Loss: 515.5123, Test Loss: 133.3904
# Epoch [198/500], Train Loss: 515.7845, Test Loss: 133.7022
# Epoch [199/500], Train Loss: 515.2679, Test Loss: 134.2394
# Epoch [200/500], Train Loss: 513.7633, Test Loss: 134.1343
# Epoch [201/500], Train Loss: 513.5926, Test Loss: 135.0911
# Epoch [202/500], Train Loss: 515.5631, Test Loss: 133.6944
# Epoch [203/500], Train Loss: 514.4811, Test Loss: 134.3056
# Epoch [204/500], Train Loss: 513.0514, Test Loss: 136.0245
# Epoch [205/500], Train Loss: 515.6301, Test Loss: 133.8867
# Epoch [206/500], Train Loss: 513.9853, Test Loss: 134.3642
# Epoch [207/500], Train Loss: 513.7655, Test Loss: 133.7401
# Epoch [208/500], Train Loss: 513.1635, Test Loss: 135.4082
# Epoch [209/500], Train Loss: 513.5313, Test Loss: 134.5155
# Epoch [210/500], Train Loss: 511.3279, Test Loss: 134.0903
# Epoch [211/500], Train Loss: 512.2072, Test Loss: 134.5327
# Epoch [212/500], Train Loss: 512.9651, Test Loss: 135.5924
# Epoch [213/500], Train Loss: 513.8536, Test Loss: 133.1868
# Epoch [214/500], Train Loss: 511.1711, Test Loss: 133.9907
# Epoch [215/500], Train Loss: 511.4015, Test Loss: 132.6610
# Epoch [216/500], Train Loss: 509.1797, Test Loss: 133.6061
# Epoch [217/500], Train Loss: 512.1695, Test Loss: 133.1424
# Epoch [218/500], Train Loss: 511.7365, Test Loss: 132.9994
# Epoch [219/500], Train Loss: 509.7909, Test Loss: 133.8970
# Epoch [220/500], Train Loss: 511.4404, Test Loss: 132.5997
# Epoch [221/500], Train Loss: 509.0328, Test Loss: 132.3467
# Epoch [222/500], Train Loss: 510.0058, Test Loss: 133.6714
# Epoch [223/500], Train Loss: 507.2510, Test Loss: 133.1830
# Epoch [224/500], Train Loss: 509.4285, Test Loss: 131.9863
# Epoch [225/500], Train Loss: 512.1330, Test Loss: 133.6464
# Epoch [226/500], Train Loss: 509.9130, Test Loss: 133.1115
# Epoch [227/500], Train Loss: 513.3657, Test Loss: 133.8359
# Epoch [228/500], Train Loss: 509.0715, Test Loss: 132.2943
# Epoch [229/500], Train Loss: 506.4772, Test Loss: 132.7825
# Epoch [230/500], Train Loss: 506.7594, Test Loss: 131.4321
# Epoch [231/500], Train Loss: 506.8117, Test Loss: 134.0648
# Epoch [232/500], Train Loss: 511.7289, Test Loss: 133.9851
# Epoch [233/500], Train Loss: 507.4365, Test Loss: 134.1026
# Epoch [234/500], Train Loss: 513.0387, Test Loss: 132.0527
# Epoch [235/500], Train Loss: 506.7094, Test Loss: 133.2859
# Epoch [236/500], Train Loss: 507.7999, Test Loss: 133.8243
# Epoch [237/500], Train Loss: 505.5728, Test Loss: 132.5610
# Epoch [238/500], Train Loss: 507.7741, Test Loss: 132.9815
# Epoch [239/500], Train Loss: 507.9300, Test Loss: 132.1133
# Epoch [240/500], Train Loss: 507.1178, Test Loss: 134.0688
# Epoch [241/500], Train Loss: 507.4792, Test Loss: 131.7801
# Epoch [242/500], Train Loss: 507.1700, Test Loss: 131.5979
# Epoch [243/500], Train Loss: 507.4376, Test Loss: 132.2750
# Epoch [244/500], Train Loss: 505.5116, Test Loss: 132.1026
# Epoch [245/500], Train Loss: 504.7005, Test Loss: 133.3042
# Epoch [246/500], Train Loss: 507.0238, Test Loss: 132.1182
# Epoch [247/500], Train Loss: 505.9934, Test Loss: 133.7140
# Epoch [248/500], Train Loss: 506.8599, Test Loss: 132.9535
# Epoch [249/500], Train Loss: 505.8895, Test Loss: 131.3193
# Epoch [250/500], Train Loss: 504.4137, Test Loss: 132.4303
# Epoch [251/500], Train Loss: 506.6400, Test Loss: 133.0649
# Epoch [252/500], Train Loss: 505.2524, Test Loss: 131.5903
# Epoch [253/500], Train Loss: 503.3141, Test Loss: 131.9839
# Epoch [254/500], Train Loss: 506.3077, Test Loss: 134.0956
# Epoch [255/500], Train Loss: 505.5068, Test Loss: 131.6737
# Epoch [256/500], Train Loss: 503.9100, Test Loss: 133.1229
# Epoch [257/500], Train Loss: 505.7039, Test Loss: 132.4653
# Epoch [258/500], Train Loss: 503.6857, Test Loss: 133.8514
# Epoch [259/500], Train Loss: 504.1801, Test Loss: 131.2707
# Epoch [260/500], Train Loss: 505.4160, Test Loss: 133.7525
# Epoch [261/500], Train Loss: 502.7471, Test Loss: 132.3519
# Epoch [262/500], Train Loss: 505.6312, Test Loss: 131.1457
# Epoch [263/500], Train Loss: 501.8635, Test Loss: 132.9451
# Epoch [264/500], Train Loss: 505.1794, Test Loss: 131.8303
# Epoch [265/500], Train Loss: 504.2492, Test Loss: 132.7717
# Epoch [266/500], Train Loss: 501.4901, Test Loss: 132.2796
# Epoch [267/500], Train Loss: 501.8913, Test Loss: 133.5038
# Epoch [268/500], Train Loss: 502.8710, Test Loss: 133.7627
# Epoch [269/500], Train Loss: 504.8290, Test Loss: 131.1180
# Epoch [270/500], Train Loss: 501.8514, Test Loss: 132.5797
# Epoch [271/500], Train Loss: 503.7852, Test Loss: 131.1012
# Epoch [272/500], Train Loss: 503.4361, Test Loss: 134.1073
# Epoch [273/500], Train Loss: 501.9595, Test Loss: 131.4100
# Epoch [274/500], Train Loss: 503.5788, Test Loss: 132.5745
# Epoch [275/500], Train Loss: 501.3337, Test Loss: 132.2170
# Epoch [276/500], Train Loss: 502.0382, Test Loss: 131.7058
# Epoch [277/500], Train Loss: 504.5705, Test Loss: 131.7126
# Epoch [278/500], Train Loss: 501.7191, Test Loss: 132.0826
# Epoch [279/500], Train Loss: 500.6673, Test Loss: 131.5873
# Epoch [280/500], Train Loss: 501.8218, Test Loss: 131.3926
# Epoch [281/500], Train Loss: 499.5787, Test Loss: 131.5887
# Epoch [282/500], Train Loss: 500.7388, Test Loss: 131.5383
# Epoch [283/500], Train Loss: 499.6890, Test Loss: 131.5623
# Epoch [284/500], Train Loss: 499.9157, Test Loss: 131.4661
# Epoch [285/500], Train Loss: 500.3169, Test Loss: 130.5451
# Epoch [286/500], Train Loss: 503.7202, Test Loss: 131.9362
# Epoch [287/500], Train Loss: 501.6382, Test Loss: 132.8762
# Epoch [288/500], Train Loss: 502.8856, Test Loss: 132.3480
# Epoch [289/500], Train Loss: 499.8750, Test Loss: 131.6795
# Epoch [290/500], Train Loss: 500.7787, Test Loss: 131.3556
# Epoch [291/500], Train Loss: 501.4405, Test Loss: 133.5447
# Epoch [292/500], Train Loss: 500.4763, Test Loss: 132.7019
# Epoch [293/500], Train Loss: 497.7551, Test Loss: 130.6290
# Epoch [294/500], Train Loss: 499.7402, Test Loss: 132.1260
# Epoch [295/500], Train Loss: 500.5388, Test Loss: 131.9257
# Epoch [296/500], Train Loss: 499.7440, Test Loss: 132.4317
# Epoch [297/500], Train Loss: 501.8130, Test Loss: 130.6075
# Epoch [298/500], Train Loss: 498.1721, Test Loss: 131.8521
# Epoch [299/500], Train Loss: 499.0368, Test Loss: 130.7443
# Epoch [300/500], Train Loss: 498.2780, Test Loss: 132.4100
# Epoch [301/500], Train Loss: 498.9083, Test Loss: 130.5529
# Epoch [302/500], Train Loss: 499.3314, Test Loss: 131.7402
# Epoch [303/500], Train Loss: 501.5105, Test Loss: 130.9090
# Epoch [304/500], Train Loss: 498.3430, Test Loss: 130.7276
# Epoch [305/500], Train Loss: 497.9150, Test Loss: 132.1247
# Epoch [306/500], Train Loss: 497.6245, Test Loss: 131.2908
# Epoch [307/500], Train Loss: 504.3116, Test Loss: 132.4695
# Epoch [308/500], Train Loss: 501.4855, Test Loss: 135.7326
# Epoch [309/500], Train Loss: 498.9758, Test Loss: 130.8996
# Epoch [310/500], Train Loss: 495.8865, Test Loss: 131.4450
# Epoch [311/500], Train Loss: 498.8046, Test Loss: 130.8634
# Epoch [312/500], Train Loss: 498.5139, Test Loss: 133.6082
# Epoch [313/500], Train Loss: 498.2769, Test Loss: 130.6840
# Epoch [314/500], Train Loss: 499.6856, Test Loss: 129.9106
# Epoch [315/500], Train Loss: 496.7320, Test Loss: 131.1091
# Epoch [316/500], Train Loss: 495.7878, Test Loss: 130.0669
# Epoch [317/500], Train Loss: 497.2770, Test Loss: 132.1281
# Epoch [318/500], Train Loss: 497.0348, Test Loss: 131.3401
# Epoch [319/500], Train Loss: 499.0785, Test Loss: 131.5076
# Epoch [320/500], Train Loss: 497.4859, Test Loss: 130.8539
# Epoch [321/500], Train Loss: 499.0018, Test Loss: 131.2339
# Epoch [322/500], Train Loss: 495.9083, Test Loss: 130.4664
# Epoch [323/500], Train Loss: 497.8495, Test Loss: 131.4623
# Epoch [324/500], Train Loss: 501.5209, Test Loss: 133.6567
# Epoch [325/500], Train Loss: 495.7531, Test Loss: 130.4586
# Epoch [326/500], Train Loss: 495.6848, Test Loss: 130.2557
# Epoch [327/500], Train Loss: 494.6149, Test Loss: 130.2150
# Epoch [328/500], Train Loss: 496.8335, Test Loss: 130.3772
# Epoch [329/500], Train Loss: 495.1048, Test Loss: 131.1882
# Epoch [330/500], Train Loss: 497.2789, Test Loss: 132.5542
# Epoch [331/500], Train Loss: 498.8041, Test Loss: 132.8268
# Epoch [332/500], Train Loss: 495.8680, Test Loss: 130.4134
# Epoch [333/500], Train Loss: 495.7285, Test Loss: 131.2916
# Epoch [334/500], Train Loss: 497.5050, Test Loss: 131.2918
# Epoch [335/500], Train Loss: 495.1377, Test Loss: 130.7469
# Epoch [336/500], Train Loss: 495.5344, Test Loss: 130.6448
# Epoch [337/500], Train Loss: 497.1465, Test Loss: 130.4118
# Epoch [338/500], Train Loss: 495.3706, Test Loss: 130.4932
# Epoch [339/500], Train Loss: 494.1206, Test Loss: 132.0621
# Epoch [340/500], Train Loss: 496.1000, Test Loss: 131.8386
# Epoch [341/500], Train Loss: 495.7314, Test Loss: 130.3489
# Epoch [342/500], Train Loss: 494.0905, Test Loss: 130.3353
# Epoch [343/500], Train Loss: 496.1342, Test Loss: 130.4811
# Epoch [344/500], Train Loss: 495.1951, Test Loss: 130.2257
# Epoch [345/500], Train Loss: 494.3962, Test Loss: 131.0484
# Epoch [346/500], Train Loss: 493.4850, Test Loss: 131.3155
# Epoch [347/500], Train Loss: 497.6322, Test Loss: 132.1113
# Epoch [348/500], Train Loss: 495.6072, Test Loss: 131.5377
# Epoch [349/500], Train Loss: 496.7954, Test Loss: 131.7571
# Epoch [350/500], Train Loss: 493.9684, Test Loss: 130.8021
# Epoch [351/500], Train Loss: 493.2888, Test Loss: 129.9348
# Epoch [352/500], Train Loss: 493.6467, Test Loss: 130.6112
# Epoch [353/500], Train Loss: 495.8943, Test Loss: 130.5102
# Epoch [354/500], Train Loss: 492.4707, Test Loss: 131.2161
# Epoch [355/500], Train Loss: 494.9418, Test Loss: 131.7434
# Epoch [356/500], Train Loss: 496.3569, Test Loss: 130.8588
# Epoch [357/500], Train Loss: 494.5709, Test Loss: 132.9968
# Epoch [358/500], Train Loss: 493.4590, Test Loss: 131.6385
# Epoch [359/500], Train Loss: 494.0880, Test Loss: 131.0785
# Epoch [360/500], Train Loss: 496.7716, Test Loss: 130.4385
# Epoch [361/500], Train Loss: 492.6099, Test Loss: 130.2234
# Epoch [362/500], Train Loss: 492.2772, Test Loss: 131.1416
# Epoch [363/500], Train Loss: 493.1247, Test Loss: 130.4888
# Epoch [364/500], Train Loss: 495.5075, Test Loss: 130.5362
# Early stopping at epoch 364
# Execution time: 18840.383643865585 seconds

# %%
np.array(test_losses).min()
# Out:
# 129.91064705699682

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir(base_dir+'/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load validation dataset
spectraVal = np.load(f'Dataset44_{base_name}_ForManuscript_Val_Spec.npy')
concVal = np.load(f'Dataset44_{base_name}_ForManuscript_Val_Conc.npy')



# Load representative validation spectra and concentrations
# Load spectra of varied concentrations (all metabolites at X-mM from 0.005mm to 20mM)
ConcSpec = np.load(f'Concentration_44met_{base_name}_ForManuscript_Spec.npy')
ConcConc = np.load(f'Concentration_44met_{base_name}_ForManuscript_Conc.npy')  
#  Load uniform concentration distribution validation spectra
UniformSpec = np.load(f'UniformDist_44met_{base_name}_ForManuscript_Spec.npy')
UniformConc = np.load(f'UniformDist_44met_{base_name}_ForManuscript_Conc.npy')  
#  Load low concentration uniform concentration distribution validation spectra
LowUniformSpec = np.load(f'LowUniformDist_44met_{base_name}_ForManuscript_Spec.npy')
LowUniformConc = np.load(f'LowUniformDist_44met_{base_name}_ForManuscript_Conc.npy')
#  Load tissue mimicking concentration distribution validation spectra
MimicTissueRangeSpec = np.load(f'MimicTissueRange_44met_{base_name}_ForManuscript_Spec.npy')
MimicTissueRangeConc = np.load(f'MimicTissueRange_44met_{base_name}_ForManuscript_Conc.npy')
#  Load liver tissue mimicking concentration distribution (high relative glucose) validation spectra
MimicTissueRangeGlucSpec = np.load(f'MimicTissueRangeGluc_44met_{base_name}_ForManuscript_Spec.npy')
MimicTissueRangeGlucConc = np.load(f'MimicTissueRangeGluc_44met_{base_name}_ForManuscript_Conc.npy')
#  Load high dynamic range #2 validation spectra
HighDynamicRange2Spec = np.load(f'HighDynRange2_44met_{base_name}_ForManuscript_Spec.npy')
HighDynamicRange2Conc = np.load(f'HighDynRange2_44met_{base_name}_ForManuscript_Conc.npy') 
#  Load varied SNR validation spectra
SNR_Spec = np.load(f'SNR_44met_{base_name}_ForManuscript_Spec.npy')
SNR_Conc = np.load(f'SNR_44met_{base_name}_ForManuscript_Conc.npy')
#  Load random singlet validation spectra
Singlet_Spec = np.load(f'Singlet_44met_{base_name}_ForManuscript_Spec.npy')
Singlet_Conc = np.load(f'Singlet_44met_{base_name}_ForManuscript_Conc.npy')
#  Load random qref checker validation spectra
QrefSensSpec = np.load(f'QrefSensitivity_44met_{base_name}_ForManuscript_Spec.npy')
QrefSensConc = np.load(f'QrefSensitivity_44met_{base_name}_ForManuscript_Conc.npy')
#  Load other validation spectra
OtherValSpectra = np.load(f'OtherVal_44met_{base_name}_ForManuscript_Spec.npy')
OtherValConc = np.load(f'OtherVal_44met_{base_name}_ForManuscript_Conc.npy')




# Move the input data to the GPU device
spectraVal = torch.tensor(spectraVal).float().to(device)   
concVal = torch.tensor(concVal).float().to(device)
ConcSpec = torch.tensor(ConcSpec).float().to(device)   
ConcConc = torch.tensor(ConcConc).float().to(device)
UniformSpec = torch.tensor(UniformSpec).float().to(device)   
UniformConc = torch.tensor(UniformConc).float().to(device)
LowUniformSpec = torch.tensor(LowUniformSpec).float().to(device)   
LowUniformConc = torch.tensor(LowUniformConc).float().to(device)
MimicTissueRangeSpec = torch.tensor(MimicTissueRangeSpec).float().to(device)   
MimicTissueRangeConc = torch.tensor(MimicTissueRangeConc).float().to(device)
MimicTissueRangeGlucSpec = torch.tensor(MimicTissueRangeGlucSpec).float().to(device)   
MimicTissueRangeGlucConc = torch.tensor(MimicTissueRangeGlucConc).float().to(device)
HighDynamicRange2Spec = torch.tensor(HighDynamicRange2Spec).float().to(device)   
HighDynamicRange2Conc = torch.tensor(HighDynamicRange2Conc).float().to(device)
SNR_Spec = torch.tensor(SNR_Spec).float().to(device)   
SNR_Conc = torch.tensor(SNR_Conc).float().to(device)
Singlet_Spec = torch.tensor(Singlet_Spec).float().to(device)   
Singlet_Conc = torch.tensor(Singlet_Conc).float().to(device)
QrefSensSpec = torch.tensor(QrefSensSpec).float().to(device)   
QrefSensConc = torch.tensor(QrefSensConc).float().to(device)
OtherValSpectra = torch.tensor(OtherValSpectra).float().to(device)   
OtherValConc = torch.tensor(OtherValConc).float().to(device)

# %%
## Make sure best parameters are being utilized

# Switch to directory for saving model parameters
os.chdir(base_dir+'/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Define the path where you saved your model parameters
save_path = ModelName + '_Params.pt'

# Load the entire dictionary from the saved file
checkpoint = torch.load(save_path)

# Instantiate the model
model_aq = NMR_Model_Aq()

# Load the model's state dictionary from the loaded dictionary
model_aq.load_state_dict(checkpoint['model_state_dict'])

# Move the model to the GPU 
model_aq.to(device)
# Out:
# NMR_Model_Aq(
#   (conv1): Conv1d(1, 42, kernel_size=(6,), stride=(1,), padding=(1,))
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(42, 42, kernel_size=(6,), stride=(1,), padding=(1,))
#   (pool2): MaxPool1d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(42, 42, kernel_size=(6,), stride=(1,), padding=(1,))
#   (pool3): MaxPool1d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(42, 42, kernel_size=(6,), stride=(1,), padding=(1,))
#   (pool4): MaxPool1d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=120708, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=44, bias=True)
# )

# %%
## Compute absolute percent error statistics on validation set

APEs = []
MAPEs = []

for i in np.arange(5000):
    GroundTruth = concVal[i].cpu().numpy()
    model_aq.eval()
    Prediction = model_aq(spectraVal[i].unsqueeze(0).unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ValExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ValExamples_MAPEs.npy", np.array(MAPEs))



print('Overall MAPE: ',np.array(MAPEs).mean())
# Out:
# Overall MAPE:  1474.5047312366048

# %%
## Compute absolute percent error statistics on concentration varied validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = ConcConc[i]
    model_aq.eval()
    Prediction = model_aq(ConcSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ConcExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ConcExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Concentrations:",ConcConc[i][0].item())
# Out:
# Overall MAPE:  inf
# --------------------
# inf  - Concentrations: 0.0
# 8188.81  - Concentrations: 0.004999999888241291
# 1470.66  - Concentrations: 0.02500000037252903
# 352.64  - Concentrations: 0.10000000149011612
# 164.71  - Concentrations: 0.25
# 94.06  - Concentrations: 0.5
# 61.71  - Concentrations: 1.0
# 42.59  - Concentrations: 2.5
# 32.14  - Concentrations: 10.0
# 30.31  - Concentrations: 20.0

# %%
## Compute absolute percent error statistics on uniform distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = UniformConc[i]
    model_aq.eval()
    Prediction = model_aq(UniformSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "UniformExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "UniformExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(UniformConc[i].min().item(),4), " - Mean Value:", np.round(UniformConc[i].mean().item(),1))
# Out:
# Overall MAPE:  3304.3777
# --------------------
# 45.31  - Min Value: 0.6783  - Mean Value: 9.2
# 32453.96  - Min Value: 0.0096  - Mean Value: 10.3
# 58.03  - Min Value: 0.147  - Mean Value: 10.5
# 67.25  - Min Value: 0.5572  - Mean Value: 8.5
# 71.72  - Min Value: 1.3567  - Mean Value: 10.6
# 25.23  - Min Value: 0.6332  - Mean Value: 10.9
# 37.7  - Min Value: 0.7017  - Mean Value: 11.0
# 92.37  - Min Value: 0.3674  - Mean Value: 8.9
# 21.93  - Min Value: 0.8387  - Mean Value: 9.8
# 170.27  - Min Value: 1.0913  - Mean Value: 11.1

# %%
## Compute absolute percent error statistics on low concentration uniform distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = LowUniformConc[i]
    model_aq.eval()
    Prediction = model_aq(LowUniformSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "LowUniformExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "LowUniformExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(LowUniformConc[i].min().item(),4), " - Mean Value:", np.round(LowUniformConc[i].mean().item(),1))
# Out:
# Overall MAPE:  341.42938
# --------------------
# 203.55  - Min Value: 0.0111  - Mean Value: 0.1
# 191.31  - Min Value: 0.0103  - Mean Value: 0.1
# 285.6  - Min Value: 0.0153  - Mean Value: 0.1
# 175.63  - Min Value: 0.0117  - Mean Value: 0.1
# 195.16  - Min Value: 0.0089  - Mean Value: 0.1
# 227.63  - Min Value: 0.0075  - Mean Value: 0.1
# 312.01  - Min Value: 0.0117  - Mean Value: 0.1
# 339.06  - Min Value: 0.0052  - Mean Value: 0.1
# 1297.87  - Min Value: 0.008  - Mean Value: 0.1
# 186.48  - Min Value: 0.0134  - Mean Value: 0.1

# %%
## Compute absolute percent error statistics on tissue mimicking distribution validation spectra

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = MimicTissueRangeConc[i]
    model_aq.eval()
    Prediction = model_aq(MimicTissueRangeSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "MimicTissueRangeExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "MimicTissueRangeExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(MimicTissueRangeConc[i].min().item(),4), " - Mean Value:", np.round(MimicTissueRangeConc[i].mean().item(),1))
# Out:
# Overall MAPE:  496.0687
# --------------------
# 160.6  - Min Value: 0.008  - Mean Value: 0.8
# 105.61  - Min Value: 0.009  - Mean Value: 0.9
# 799.08  - Min Value: 0.0138  - Mean Value: 1.5
# 200.56  - Min Value: 0.0107  - Mean Value: 0.7
# 319.96  - Min Value: 0.0191  - Mean Value: 0.7
# 308.86  - Min Value: 0.0186  - Mean Value: 0.8
# 81.81  - Min Value: 0.0175  - Mean Value: 0.8
# 2071.57  - Min Value: 0.0238  - Mean Value: 1.3
# 131.36  - Min Value: 0.0168  - Mean Value: 0.7
# 781.29  - Min Value: 0.0171  - Mean Value: 0.9

# %%
## Compute absolute percent error statistics on tissue mimicking distribution validation spectra (high relative glucose concentration)

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = MimicTissueRangeGlucConc[i]
    model_aq.eval()
    Prediction = model_aq(MimicTissueRangeGlucSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "MimicTissueRangeGlucExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "MimicTissueRangeGlucExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(MimicTissueRangeGlucConc[i].min().item(),4), " - Mean Value:", np.round(MimicTissueRangeGlucConc[i].mean().item(),1))
# Out:
# Overall MAPE:  1463.6385
# --------------------
# 78.48  - Min Value: 0.013  - Mean Value: 0.6
# 3405.44  - Min Value: 0.0115  - Mean Value: 0.4
# 122.2  - Min Value: 0.0115  - Mean Value: 0.4
# 121.57  - Min Value: 0.0115  - Mean Value: 0.6
# 3293.06  - Min Value: 0.0115  - Mean Value: 1.0
# 315.2  - Min Value: 0.0115  - Mean Value: 1.1
# 291.2  - Min Value: 0.0115  - Mean Value: 0.8
# 1816.5  - Min Value: 0.0115  - Mean Value: 0.5
# 1273.21  - Min Value: 0.0115  - Mean Value: 0.5
# 3919.53  - Min Value: 0.0115  - Mean Value: 1.1

# %%
## Compute absolute percent error statistics on a further high dynamic range dataset

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = HighDynamicRange2Conc[i]
    model_aq.eval()
    Prediction = model_aq(HighDynamicRange2Spec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "HighDynamicRange2Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "HighDynamicRange2Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - Min Value:", np.round(HighDynamicRange2Conc[i].min().item(),4), " - Mean Value:", np.round(HighDynamicRange2Conc[i].mean().item(),1))
# Out:
# Overall MAPE:  4468.85
# --------------------
# 626.07  - Min Value: 0.0062  - Mean Value: 2.1
# 419.2  - Min Value: 0.006  - Mean Value: 3.7
# 22231.2  - Min Value: 0.0066  - Mean Value: 4.3
# 1142.47  - Min Value: 0.0094  - Mean Value: 4.3
# 1311.1  - Min Value: 0.0068  - Mean Value: 4.9
# 12940.78  - Min Value: 0.005  - Mean Value: 3.8
# 1476.65  - Min Value: 0.0101  - Mean Value: 3.2
# 512.45  - Min Value: 0.0062  - Mean Value: 3.2
# 2240.66  - Min Value: 0.0053  - Mean Value: 5.3
# 1787.92  - Min Value: 0.0054  - Mean Value: 2.5

# %%
## Compute absolute percent error statistics on a examples of varying SNR

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(SNR_Spec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "SNR_Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "SNR_Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  105.02389443538155
# --------------------
# 105.25
# 105.32
# 104.87
# 105.49
# 105.24
# 104.63
# 105.01
# 104.73
# 104.75
# 104.95

# %%
## Compute absolute percent error statistics on a dataset with singlets added at random

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(Singlet_Spec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "SingletExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "SingletExamples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  111.26300833441994
# --------------------
# 105.29
# 106.54
# 107.67
# 107.92
# 112.26
# 111.65
# 111.21
# 115.92
# 115.62
# 118.55

# %%
## Compute absolute percent error statistics on a examples of varying SNR

APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = 0.43
    model_aq.eval()
    Prediction = model_aq(QrefSensSpec[i].unsqueeze(2))

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth - Prediction_cpu[0][metabolite]) / GroundTruth
        APE.append(abs(per_err))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "QrefSensitivity_Examples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "QrefSensitivity_Examples_MAPEs.npy", np.array(MAPEs))



## Output metrics
print('Overall MAPE: ',np.array(MAPEs).mean())
print("--------------------")
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2))
# Out:
# Overall MAPE:  139.96633520759408
# --------------------
# 99.77
# 99.4
# 108.61
# 120.66
# 132.71
# 144.79
# 156.56
# 168.07
# 179.19
# 189.9

# %%
Pred = model_aq(OtherValSpectra[0].unsqueeze(2))
Pred[0][Pred[0] < 0] = 0
print("Sinusoidal Baseline 1")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(OtherValSpectra[1].unsqueeze(2))
Pred[0][Pred[0] < 0] = 0
print("Sinusoidal Baseline 2")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(OtherValSpectra[2].unsqueeze(2))
Pred[0][Pred[0] < 0] = 0
print("HD-Range 1 - 1s and 20s")
print(Pred[0])

Pred = model_aq(OtherValSpectra[3].unsqueeze(2))
Pred[0][Pred[0] < 0] = 0
print("HD-Range 2 - 0s and 20s")
print(Pred[0])
# Out:
# Sinusoidal Baseline 1
# tensor([0.4249, 0.5101, 0.4507, 0.5566, 0.5379, 0.4778, 0.4719, 0.5858, 0.7321,
#         0.3822, 0.0000, 0.4922, 0.5168, 0.8763, 0.5026, 0.7028, 0.6640, 0.5026,
#         0.5011, 0.4194, 0.3971, 0.8780, 0.2464, 0.4800, 0.6810, 0.4954, 0.5478,
#         0.5323, 0.5202, 0.4480, 0.4160, 0.7939, 0.4508, 0.3393, 0.4066, 0.4286,
#         0.3926, 0.4668, 0.4630, 0.4169, 0.4194, 0.4874, 0.4483, 0.4818],
#        device='cuda:0', grad_fn=<SelectBackward0>)
# ___________
# ___________
# Sinusoidal Baseline 2
# tensor([0.3506, 0.6052, 0.1605, 0.5933, 0.5478, 0.5110, 0.5739, 0.3603, 0.5473,
#         0.6501, 0.0000, 0.6977, 0.9452, 0.4601, 0.5788, 0.3354, 0.8711, 0.5432,
#         0.5767, 0.5304, 0.3817, 0.4333, 0.6324, 0.6304, 0.5585, 0.5325, 0.3215,
#         0.2743, 0.6161, 0.4073, 0.4476, 0.4903, 0.2739, 0.5124, 0.4924, 0.4731,
#         0.6957, 0.8319, 0.4850, 0.5020, 0.4975, 0.8041, 0.3487, 0.2666],
#        device='cuda:0', grad_fn=<SelectBackward0>)
# ___________
# ___________
# HD-Range 1 - 1s and 20s
# tensor([ 0.0000, 16.4049,  0.0000, 17.7529,  0.0000, 18.3305,  0.0000, 17.9348,
#          0.0000, 18.5428,  0.0000, 18.7445,  0.0000, 18.5003,  0.0000, 18.1760,
#          0.0000, 17.9388,  0.0000, 18.4551,  0.0000, 17.3399,  0.0000, 17.1721,
#          0.0000, 19.2204,  0.0000, 17.9620,  0.0000, 17.8145,  0.0000, 18.3925,
#          0.0000, 18.1619,  0.0000, 19.5686,  0.0000, 19.1753,  0.0000, 17.5526,
#          0.0000, 17.4487,  0.0000, 19.2851], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# HD-Range 2 - 0s and 20s
# tensor([ 0.0000, 16.4025,  0.0000, 17.7526,  0.0000, 18.3268,  0.0000, 17.9323,
#          0.0000, 18.5405,  0.0000, 18.7458,  0.0000, 18.4968,  0.0000, 18.1753,
#          0.0000, 17.9361,  0.0000, 18.4540,  0.0000, 17.3398,  0.0000, 17.1698,
#          0.0000, 19.2180,  0.0000, 17.9597,  0.0000, 17.8114,  0.0000, 18.3888,
#          0.0000, 18.1590,  0.0000, 19.5655,  0.0000, 19.1755,  0.0000, 17.5507,
#          0.0000, 17.4472,  0.0000, 19.2842], device='cuda:0',
#        grad_fn=<SelectBackward0>)
