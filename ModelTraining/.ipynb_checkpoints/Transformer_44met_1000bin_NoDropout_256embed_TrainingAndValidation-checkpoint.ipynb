# Epoch [113/1000], Train Loss: 2024432.2607, Test Loss: 692652.0723
# Epoch [114/1000], Train Loss: 2015487.4692, Test Loss: 699475.9966
# Epoch [115/1000], Train Loss: 2004445.1311, Test Loss: 696989.8428
# Epoch [116/1000], Train Loss: 1996963.5229, Test Loss: 695706.5864
# Epoch [117/1000], Train Loss: 1991057.2583, Test Loss: 696136.2603
# Epoch [118/1000], Train Loss: 1986512.3188, Test Loss: 700804.2764
# Epoch [119/1000], Train Loss: 1976792.8574, Test Loss: 700976.9482
# Epoch [120/1000], Train Loss: 1973476.7290, Test Loss: 699004.7231
# Epoch [121/1000], Train Loss: 1966359.2571, Test Loss: 698705.8579
# Epoch [122/1000], Train Loss: 1960346.1345, Test Loss: 700838.9141
# Epoch [123/1000], Train Loss: 1956729.6257, Test Loss: 705682.8086
# Epoch [124/1000], Train Loss: 1947533.6565, Test Loss: 700714.4946
# Epoch [125/1000], Train Loss: 1944722.7700, Test Loss: 700588.1592
# Epoch [126/1000], Train Loss: 1936963.3711, Test Loss: 711528.5581
# Epoch [127/1000], Train Loss: 1941579.6064, Test Loss: 699386.9341
# Epoch [128/1000], Train Loss: 1926714.7280, Test Loss: 706296.2744
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 21
#      18 save_path = ModelName + '_Params.pt'
#      20 # Call the function
# ---> 21 train_losses, test_losses, is_model_trained = train_or_load_model(model_aq, train_iter, test_iter, num_epochs, save_path)
#      24 # Finish timing cell run time
#      25 end_time = time.time()
#
# Cell In[8], line 63, in train_or_load_model(model, train_loader, test_loader, num_epochs, save_path)
#      61 print("No pretrained model found. Training from scratch.")
#      62 #optimizer = optim.Adam(model.parameters())
# ---> 63 train_losses, test_losses = train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
#      64 is_model_trained = True  # Set flag to True after training
#      65 # Save losses per epoch
#
# Cell In[8], line 14, in train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
#      12 for inputs, targets in train_loader:
#      13     optimizer.zero_grad()
# ---> 14     outputs = model(inputs)
#      15     loss = criterion(outputs, targets)
#      16     loss.backward()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[7], line 41, in Transformer.forward(self, x)
#      39 # Transformer Encoder
#      40 x = x.permute(1, 0, 2)  # (num_bins, batch_size, d_model)
# ---> 41 x = self.transformer_encoder(x)  # (num_bins, batch_size, d_model)
#      42 x = x.permute(1, 0, 2)  # (batch_size, num_bins, d_model)
#      44 # Reconstruct original sequence
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:391, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     388 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     390 for mod in self.layers:
# --> 391     output = mod(output, src_mask=mask, is_causal=is_causal, src_key_padding_mask=src_key_padding_mask_for_layers)
#     393 if convert_to_nested:
#     394     output = output.to_padded_tensor(0., src.size())
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:714, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     712     x = x + self._ff_block(self.norm2(x))
#     713 else:
# --> 714     x = self.norm1(x + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal))
#     715     x = self.norm2(x + self._ff_block(x))
#     717 return x
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:722, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     720 def _sa_block(self, x: Tensor,
#     721               attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor], is_causal: bool = False) -> Tensor:
# --> 722     x = self.self_attn(x, x, x,
#     723                        attn_mask=attn_mask,
#     724                        key_padding_mask=key_padding_mask,
#     725                        need_weights=False, is_causal=is_causal)[0]
#     726     return self.dropout1(x)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1507, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1504             tracing_state.pop_scope()
#    1505     return result
# -> 1507 def _wrapped_call_impl(self, *args, **kwargs):
#    1508     if self._compiled_call_impl is not None:
#    1509         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load validation dataset
spectraVal = np.load('Dataset44_Val_Spec.npy')
concVal = np.load('Dataset44_Val_Conc.npy')

# Load representative validation spectra
ValSpectra = np.load("Dataset44_RepresentativeExamples_Spectra.npy")
ValConc = np.load("Dataset44_RepresentativeExamples_Concentrations.npy")
ValSpecNames = np.load("Dataset44_RepresentativeExamples_VariableNames.npy")



# Move the input data to the GPU device
spectraVal = torch.tensor(spectraVal).float().to(device)   # Confusing names, these spectra are the 5000 spectra generated like the training dataset
ValSpectra = torch.tensor(ValSpectra).float().to(device)   # Confusing names, these spectra are the 10 representative example spectra
concVal = torch.tensor(concVal).float().to(device)
ValConc = torch.tensor(ValConc).float().to(device)

# %%
## Make sure best parameters are being utilized

# Switch to directory for saving model parameters
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Define the path where you saved your model parameters
save_path = ModelName + '_Params.pt'

# Load the entire dictionary from the saved file
checkpoint = torch.load(save_path)

# Instantiate the model
model_aq = Transformer(input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout)

# Load the model's state dictionary from the loaded dictionary
model_aq.load_state_dict(checkpoint['model_state_dict'])

# Move the model to the GPU 
model_aq.to(device)
# Out:
# Transformer(
#   (embedding): Linear(in_features=1000, out_features=512, bias=True)
#   (positional_encoding): PositionalEncoding()
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=23552, out_features=44, bias=True)
# )

# %%
APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = ValConc[i]
    Prediction = model_aq(ValSpectra[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()

    APE = []

    for metabolite in range(21):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ValExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ValExamples_MAPEs.npy", np.array(MAPEs))

# %%
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - ",ValSpecNames[i])
# Out:
# 15.83  -  AllAq1
# 1.85  -  AllAq5
# 0.37  -  AllAq25
# 2.6  -  AllAq50
# 0.57  -  ThreeAddedSinglets
# 13.64  -  ThirtyAddedSinglets
# 75.61  -  ShiftedSpec
# 27.68  -  SineBase
# 187.91  -  HighDynamicRange
# inf  -  HalfZeros
