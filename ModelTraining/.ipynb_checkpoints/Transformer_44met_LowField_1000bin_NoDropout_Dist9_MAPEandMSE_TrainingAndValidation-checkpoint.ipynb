# %%
## Import dependencies

import numpy as np
from os import path
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import time


# Set default plot size
plt.rcParams["figure.figsize"] = (30,20)

# Define number of epochs used later in training
num_epochs = 1000

# %% [markdown]
# ## Train Transformer Encoder on dataset of 44 metabolites

# %%
# Name variable used for saving model metrics, name should reflect model used, dataset used, and other information such as # of epochs
ModelName = "Transformer_44met_LowField_TrainingAndValidation_1000bin_NoDropout_Dist9_MAPEandMSE_" + str(num_epochs) +"ep"

# Set the random seed
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/ModelPerformanceMetrics/') 
seed = 1
torch.manual_seed(seed)
np.save(ModelName + "_Seed.npy", seed)

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load training data and max value from testing and training datasets
spectra = np.load('Dataset44_LowField_Dist9_Spec.npy')
conc1 = np.load('Dataset44_LowField_Dist9_Conc.npy')

# Load validation dataset
#spectraVal = np.load('Dataset44_LowField_Dist9_Val_Spec.npy')
#concVal = np.load('Dataset44_LowField_Dist9_Val_Conc.npy')

# Load representative validation spectra
#ValSpectra = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_Spectra.npy")
#ValConc = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_Concentrations.npy")
#ValSpecNames = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_VariableNames.npy")

# %%
## Prepare to switch data from CPU to GPU

# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    device = torch.device("cuda")          # A CUDA device object
    print("Using GPU for training.")
else:
    device = torch.device("cpu")           # A CPU object
    print("CUDA is not available. Using CPU for training.")
# Out:
# Using GPU for training.

# %%
## Set up data for testing and training

# Split into testing and training data
X_train, X_test, y_train, y_test = train_test_split(spectra, conc1, test_size = 0.2, random_state = 1)

# Tensorize and prepare datasets
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()


# Move the input data to the GPU device
X_train = X_train.to(device)
X_test = X_test.to(device)
#spectraVal = torch.tensor(spectraVal).float().to(device)   # Confusing names, these spectra are the 5000 spectra generated like the training dataset
#ValSpectra = torch.tensor(ValSpectra).float().to(device)   # Confusing names, these spectra are the 10 representative example spectra

# Move the target data to the GPU device
y_train = y_train.to(device)
y_test = y_test.to(device)
#concVal = torch.tensor(concVal).float().to(device)
#ValConc = torch.tensor(ValConc).float().to(device)

# More data prep?
datasets = torch.utils.data.TensorDataset(X_train, y_train)
Test_datasets = torch.utils.data.TensorDataset(X_test, y_test)
train_iter = torch.utils.data.DataLoader(datasets, batch_size = 32, shuffle=True)
test_iter = torch.utils.data.DataLoader(Test_datasets, batch_size = 32, shuffle=True)

# %%
del X_train
del X_test
del y_train
del y_test
del spectra
del conc1
del datasets
del Test_datasets

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.d_model = d_model
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]

class Transformer(nn.Module):
    def __init__(self, input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout=0.1):
        super(Transformer, self).__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        self.embedding = nn.Linear(input_dim, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        self.decoder = nn.Linear(23552, 44)

    def forward(self, x):
        # Binning
        batch_size, seq_length = x.size()
        num_bins = seq_length // self.input_dim
        x = x.view(batch_size, num_bins, self.input_dim)  # (batch_size, num_bins, input_dim)
        
        # Embedding
        x = self.embedding(x)  # (batch_size, num_bins, d_model)
        
        # Add positional encoding
        x = self.positional_encoding(x)
        
        # Transformer Encoder
        x = x.permute(1, 0, 2)  # (num_bins, batch_size, d_model)
        x = self.transformer_encoder(x)  # (num_bins, batch_size, d_model)
        x = x.permute(1, 0, 2)  # (batch_size, num_bins, d_model)
        
        # Reconstruct original sequence
        x = x.reshape(batch_size, num_bins * d_model)
        
        # Decoding
        x = self.decoder(x)  # (batch_size, output_dim)
        
        return x

# Parameters
input_dim = 1000  # Size of each bin
d_model = 512     # Embedding dimension
nhead = 1         # Number of attention heads
num_encoder_layers = 1  # Number of transformer encoder layers
dim_feedforward = 2048  # Feedforward dimension
dropout = 0.0     # Dropout rate

# %%
class MAPEAndMSELoss(nn.Module):
    def __init__(self):
        super(MAPEAndMSELoss, self).__init__()

    def forward(self, y_pred, y_true):
        # Mean Squared Error
        mse_loss = torch.mean((y_pred - y_true) ** 2)
        
        # Mean Absolute Percentage Error
        mape_loss = torch.mean(torch.abs((y_true - y_pred) / y_true))
        
        # Combine the losses 50/50
        loss = 0.5 * mse_loss + 0.5 * mape_loss
        
        return loss

# %%
def train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path):
    criterion = MAPEAndMSELoss()
    criterion2 = nn.MSELoss()
    optimizer = optim.Adam(model.parameters())

    train_losses = []
    test_losses = []
    test_losses2 = []
    best_test_loss = float('inf')

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
        train_losses.append(train_loss)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                test_loss += loss.item() * inputs.size(0)
            test_losses.append(test_loss)
            
            
        ## Also compute just MSE loss for more direct comparison with previous models
        test_loss2 = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss2 = criterion2(outputs, targets)
                test_loss2 += loss2.item() * inputs.size(0)
            test_losses2.append(test_loss2)
            
            
            
        if (epoch + 1) % 1 == 0:  # The last number here denotes how often to print loss metrics in terms of epochs
            print(f'Epoch [{epoch + 1}/{num_epochs}], '
                  f'Train Loss: {train_loss:.4f}, '
                  f'Test Loss: {test_loss:.4f}, '
                  f'Test Loss (MSE only): {test_loss2:.4f}')
       
        if test_loss < best_test_loss:
            best_test_loss = test_loss
            # Save model when test loss improves
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
            }, save_path)

    return train_losses, test_losses, test_losses2


def train_or_load_model(model, train_loader, test_loader, num_epochs, save_path):
    train_losses = []
    test_losses = []
    is_model_trained = False  # Initialize flag

    if os.path.isfile(save_path):
        print("Loading pretrained model from {}".format(save_path))
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer = optim.Adam(model.parameters())  
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        
    
    else:
        print("No pretrained model found. Training from scratch.")
        #optimizer = optim.Adam(model.parameters())  
        train_losses, test_losses = train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
        is_model_trained = True  # Set flag to True after training
        # Save losses per epoch
        np.save(ModelName + "_TrainLoss.npy", train_losses)
        np.save(ModelName + "_TestLoss.npy", test_losses)
    
    return train_losses, test_losses, test_losses2, is_model_trained  # Return the losses and flag

# %%
## Instantiate model and train

# For timing cell run time
start_time = time.time()


# Switch to directory for saving model parameters
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Create model
model_aq = Transformer(input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout)


# Move the model to the GPU device
model_aq.to(device)

# Define the path to save and load the model parameter weights
save_path = ModelName + '_Params.pt'

# Call the function
train_losses, test_losses, is_model_trained = train_or_load_model(model_aq, train_iter, test_iter, num_epochs, save_path)


# Finish timing cell run time
end_time = time.time()
execution_time = end_time - start_time
if is_model_trained:
    np.save(ModelName + "_ExecutionTime.npy", execution_time)
    print("Execution time:", execution_time, "seconds")
# Out:
# /home/htjhnson/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# No pretrained model found. Training from scratch.
# Epoch [1/1000], Train Loss: 1206774.4957, Test Loss: 59680.0019, Test Loss (MSE only): 113311.8105
# Epoch [2/1000], Train Loss: 124716.8234, Test Loss: 19501.7514, Test Loss (MSE only): 35942.0331
# Epoch [3/1000], Train Loss: 64374.4764, Test Loss: 13673.4770, Test Loss (MSE only): 24571.1469
# Epoch [4/1000], Train Loss: 47039.2440, Test Loss: 12530.5260, Test Loss (MSE only): 22822.3323
# Epoch [5/1000], Train Loss: 38508.8893, Test Loss: 9542.6133, Test Loss (MSE only): 17076.3926
# Epoch [6/1000], Train Loss: 33426.0148, Test Loss: 8524.1568, Test Loss (MSE only): 15139.7987
# Epoch [7/1000], Train Loss: 29687.5495, Test Loss: 8087.6501, Test Loss (MSE only): 14245.2952
# Epoch [8/1000], Train Loss: 27634.9200, Test Loss: 7815.9037, Test Loss (MSE only): 13964.9278
# Epoch [9/1000], Train Loss: 25275.5066, Test Loss: 5413.6914, Test Loss (MSE only): 9468.6370
# Epoch [10/1000], Train Loss: 23862.9681, Test Loss: 5653.9491, Test Loss (MSE only): 9883.3168
# Epoch [11/1000], Train Loss: 22288.5369, Test Loss: 5613.3594, Test Loss (MSE only): 9817.8433
# Epoch [12/1000], Train Loss: 21200.1698, Test Loss: 6216.0995, Test Loss (MSE only): 11046.3238
# Epoch [13/1000], Train Loss: 20245.5037, Test Loss: 5102.7002, Test Loss (MSE only): 8843.7840
# Epoch [14/1000], Train Loss: 20020.7071, Test Loss: 4756.5919, Test Loss (MSE only): 8289.0930
# Epoch [15/1000], Train Loss: 18618.3657, Test Loss: 6589.8119, Test Loss (MSE only): 11748.1908
# Epoch [16/1000], Train Loss: 18262.7694, Test Loss: 4475.2674, Test Loss (MSE only): 7720.1104
# Epoch [17/1000], Train Loss: 17250.2273, Test Loss: 6989.4289, Test Loss (MSE only): 12559.8960
# Epoch [18/1000], Train Loss: 17071.3984, Test Loss: 4287.1203, Test Loss (MSE only): 7432.4633
# Epoch [19/1000], Train Loss: 16428.4120, Test Loss: 4410.0833, Test Loss (MSE only): 7573.9913
# Epoch [20/1000], Train Loss: 15933.9872, Test Loss: 3979.6373, Test Loss (MSE only): 6891.0611
# Epoch [21/1000], Train Loss: 15390.2736, Test Loss: 3891.6167, Test Loss (MSE only): 6704.5447
# Epoch [22/1000], Train Loss: 14986.1141, Test Loss: 4464.4339, Test Loss (MSE only): 7687.3075
# Epoch [23/1000], Train Loss: 14848.3812, Test Loss: 4209.9945, Test Loss (MSE only): 7309.7461
# Epoch [24/1000], Train Loss: 14197.5584, Test Loss: 4064.9220, Test Loss (MSE only): 7059.1000
# Epoch [25/1000], Train Loss: 13969.6975, Test Loss: 4951.0366, Test Loss (MSE only): 8586.4453
# Epoch [26/1000], Train Loss: 14036.2937, Test Loss: 3618.0448, Test Loss (MSE only): 6224.1916
# Epoch [27/1000], Train Loss: 13116.6149, Test Loss: 3667.3564, Test Loss (MSE only): 6362.1471
# Epoch [28/1000], Train Loss: 12969.1928, Test Loss: 3446.0968, Test Loss (MSE only): 5873.4844
# Epoch [29/1000], Train Loss: 12778.2190, Test Loss: 3454.1952, Test Loss (MSE only): 5951.9933
# Epoch [30/1000], Train Loss: 12521.9678, Test Loss: 3690.8344, Test Loss (MSE only): 6368.6577
# Epoch [31/1000], Train Loss: 12598.6714, Test Loss: 3497.6551, Test Loss (MSE only): 6005.5046
# Epoch [32/1000], Train Loss: 12129.7194, Test Loss: 3363.4201, Test Loss (MSE only): 5733.0675
# Epoch [33/1000], Train Loss: 11920.9727, Test Loss: 3137.4804, Test Loss (MSE only): 5366.5088
# Epoch [34/1000], Train Loss: 11650.5971, Test Loss: 4138.2826, Test Loss (MSE only): 7225.3116
# Epoch [35/1000], Train Loss: 11659.0684, Test Loss: 4042.2843, Test Loss (MSE only): 6926.3304
# Epoch [36/1000], Train Loss: 11618.0979, Test Loss: 3519.0252, Test Loss (MSE only): 5983.8532
# Epoch [37/1000], Train Loss: 11169.0092, Test Loss: 3136.6890, Test Loss (MSE only): 5364.5541
# Epoch [38/1000], Train Loss: 10793.9420, Test Loss: 3308.9091, Test Loss (MSE only): 5715.3810
# Epoch [39/1000], Train Loss: 11055.3818, Test Loss: 3327.3910, Test Loss (MSE only): 5667.9365
# Epoch [40/1000], Train Loss: 10712.3524, Test Loss: 4334.0932, Test Loss (MSE only): 7542.7578
# Epoch [41/1000], Train Loss: 10875.8503, Test Loss: 3181.6266, Test Loss (MSE only): 5411.2575
# Epoch [42/1000], Train Loss: 10412.0299, Test Loss: 2838.7156, Test Loss (MSE only): 4800.9212
# Epoch [43/1000], Train Loss: 10306.0481, Test Loss: 2885.5284, Test Loss (MSE only): 4919.8119
# Epoch [44/1000], Train Loss: 10187.0542, Test Loss: 3142.3327, Test Loss (MSE only): 5360.4726
# Epoch [45/1000], Train Loss: 45234.2284, Test Loss: 6428.7380, Test Loss (MSE only): 11191.3268
# Epoch [46/1000], Train Loss: 13070.5226, Test Loss: 3137.0794, Test Loss (MSE only): 5355.9942
# Epoch [47/1000], Train Loss: 9765.2618, Test Loss: 2809.4533, Test Loss (MSE only): 4792.8573
# Epoch [48/1000], Train Loss: 8970.0205, Test Loss: 2552.9000, Test Loss (MSE only): 4339.4885
# Epoch [49/1000], Train Loss: 8871.2889, Test Loss: 2597.3596, Test Loss (MSE only): 4384.9931
# Epoch [50/1000], Train Loss: 8771.7110, Test Loss: 2705.4166, Test Loss (MSE only): 4584.8880
# Epoch [51/1000], Train Loss: 8780.9783, Test Loss: 2664.6382, Test Loss (MSE only): 4509.1916
# Epoch [52/1000], Train Loss: 8683.6916, Test Loss: 2672.1859, Test Loss (MSE only): 4516.7808
# Epoch [53/1000], Train Loss: 8735.6070, Test Loss: 2727.5109, Test Loss (MSE only): 4688.5700
# Epoch [54/1000], Train Loss: 8938.8063, Test Loss: 3308.6497, Test Loss (MSE only): 5685.8861
# Epoch [55/1000], Train Loss: 8939.7878, Test Loss: 2822.8756, Test Loss (MSE only): 4809.9993
# Epoch [56/1000], Train Loss: 8793.6288, Test Loss: 2702.9927, Test Loss (MSE only): 4557.8470
# Epoch [57/1000], Train Loss: 8939.8510, Test Loss: 2744.2088, Test Loss (MSE only): 4673.8348
# Epoch [58/1000], Train Loss: 8930.0947, Test Loss: 3230.4594, Test Loss (MSE only): 5492.1756
# Epoch [59/1000], Train Loss: 9200.5643, Test Loss: 2614.1835, Test Loss (MSE only): 4428.9164
# Epoch [60/1000], Train Loss: 8849.4605, Test Loss: 2530.3131, Test Loss (MSE only): 4303.2164
# Epoch [61/1000], Train Loss: 8813.7187, Test Loss: 2606.6667, Test Loss (MSE only): 4456.6790
# Epoch [62/1000], Train Loss: 8651.4239, Test Loss: 2993.4194, Test Loss (MSE only): 5118.6469
# Epoch [63/1000], Train Loss: 8609.7624, Test Loss: 2974.4019, Test Loss (MSE only): 5069.4122
# Epoch [64/1000], Train Loss: 28790.3004, Test Loss: 2611.4666, Test Loss (MSE only): 4419.3911
# Epoch [65/1000], Train Loss: 8208.3565, Test Loss: 2469.8357, Test Loss (MSE only): 4165.5258
# Epoch [66/1000], Train Loss: 7649.0141, Test Loss: 2482.9378, Test Loss (MSE only): 4129.5965
# Epoch [67/1000], Train Loss: 7443.2795, Test Loss: 2483.2576, Test Loss (MSE only): 4216.4898
# Epoch [68/1000], Train Loss: 7571.7568, Test Loss: 2271.2156, Test Loss (MSE only): 3823.7698
# Epoch [69/1000], Train Loss: 7487.3510, Test Loss: 2664.6596, Test Loss (MSE only): 4496.9247
# Epoch [70/1000], Train Loss: 7755.8242, Test Loss: 2521.3082, Test Loss (MSE only): 4273.1567
# Epoch [71/1000], Train Loss: 7676.5718, Test Loss: 2438.8027, Test Loss (MSE only): 4134.6968
# Epoch [72/1000], Train Loss: 7661.0368, Test Loss: 2531.9075, Test Loss (MSE only): 4251.2290
# Epoch [73/1000], Train Loss: 7767.2103, Test Loss: 3358.7354, Test Loss (MSE only): 5777.0766
# Epoch [74/1000], Train Loss: 7945.7095, Test Loss: 2581.0207, Test Loss (MSE only): 4352.4751
# Epoch [75/1000], Train Loss: 7871.8944, Test Loss: 3187.8822, Test Loss (MSE only): 5510.6853
# Epoch [76/1000], Train Loss: 7772.7475, Test Loss: 2479.1350, Test Loss (MSE only): 4176.2543
# Epoch [77/1000], Train Loss: 7879.4483, Test Loss: 2271.8786, Test Loss (MSE only): 3832.9716
# Epoch [78/1000], Train Loss: 7850.2725, Test Loss: 2353.1389, Test Loss (MSE only): 3947.9371
# Epoch [79/1000], Train Loss: 7531.3221, Test Loss: 4282.9243, Test Loss (MSE only): 7647.1508
# Epoch [80/1000], Train Loss: 7795.1947, Test Loss: 2279.9307, Test Loss (MSE only): 3833.9185
# Epoch [81/1000], Train Loss: 7673.1945, Test Loss: 2319.1582, Test Loss (MSE only): 3920.9282
# Epoch [82/1000], Train Loss: 7731.7323, Test Loss: 2508.3421, Test Loss (MSE only): 4215.6868
# Epoch [83/1000], Train Loss: 7362.3150, Test Loss: 2380.6872, Test Loss (MSE only): 3958.0596
# Epoch [84/1000], Train Loss: 7497.1230, Test Loss: 2564.0413, Test Loss (MSE only): 4350.6346
# Epoch [85/1000], Train Loss: 7280.9076, Test Loss: 2504.4662, Test Loss (MSE only): 4219.3551
# Epoch [86/1000], Train Loss: 7276.4718, Test Loss: 2987.1769, Test Loss (MSE only): 5119.3652
# Epoch [87/1000], Train Loss: 7301.8149, Test Loss: 2789.8398, Test Loss (MSE only): 4750.2653
# Epoch [88/1000], Train Loss: 7389.8158, Test Loss: 2570.5602, Test Loss (MSE only): 4390.6620
# Epoch [89/1000], Train Loss: 7304.5773, Test Loss: 2409.4482, Test Loss (MSE only): 4070.2746
# Epoch [90/1000], Train Loss: 7250.5403, Test Loss: 2426.0824, Test Loss (MSE only): 4083.4506
# Epoch [91/1000], Train Loss: 7149.1787, Test Loss: 2411.6953, Test Loss (MSE only): 4052.3664
# Epoch [92/1000], Train Loss: 7053.1548, Test Loss: 2366.1793, Test Loss (MSE only): 3962.3417
# Epoch [93/1000], Train Loss: 7007.6022, Test Loss: 2319.0972, Test Loss (MSE only): 3871.8494
# Epoch [94/1000], Train Loss: 7063.8278, Test Loss: 2372.4366, Test Loss (MSE only): 3965.9695
# Epoch [95/1000], Train Loss: 6752.8713, Test Loss: 2896.6230, Test Loss (MSE only): 4977.8713
# Epoch [96/1000], Train Loss: 7066.1984, Test Loss: 2219.4520, Test Loss (MSE only): 3736.0695
# Epoch [97/1000], Train Loss: 6765.4295, Test Loss: 2408.3834, Test Loss (MSE only): 4044.8510
# Epoch [98/1000], Train Loss: 6829.4332, Test Loss: 2352.3331, Test Loss (MSE only): 3995.0255
# Epoch [99/1000], Train Loss: 6727.7836, Test Loss: 2426.7238, Test Loss (MSE only): 4065.4942
# Epoch [100/1000], Train Loss: 6854.4851, Test Loss: 2079.4116, Test Loss (MSE only): 3488.2253
# Epoch [101/1000], Train Loss: 6701.3404, Test Loss: 2471.7559, Test Loss (MSE only): 4223.6767
# Epoch [102/1000], Train Loss: 6637.1538, Test Loss: 2271.3025, Test Loss (MSE only): 3828.3260
# Epoch [103/1000], Train Loss: 6602.0786, Test Loss: 2432.2368, Test Loss (MSE only): 4140.3174
# Epoch [104/1000], Train Loss: 6581.3913, Test Loss: 2311.9623, Test Loss (MSE only): 3855.0972
# Epoch [105/1000], Train Loss: 6467.4821, Test Loss: 2320.0325, Test Loss (MSE only): 3937.1128
# Epoch [106/1000], Train Loss: 6605.7029, Test Loss: 2185.8188, Test Loss (MSE only): 3648.7920
# Epoch [107/1000], Train Loss: 6476.1196, Test Loss: 2103.1158, Test Loss (MSE only): 3546.8166
# Epoch [108/1000], Train Loss: 6469.9799, Test Loss: 2297.7598, Test Loss (MSE only): 3899.5190
# Epoch [109/1000], Train Loss: 6369.0671, Test Loss: 2129.6131, Test Loss (MSE only): 3561.5200
# Epoch [110/1000], Train Loss: 8361.8722, Test Loss: 2148.8100, Test Loss (MSE only): 3617.9891
# Epoch [111/1000], Train Loss: 5840.2755, Test Loss: 2150.0853, Test Loss (MSE only): 3625.4663
# Epoch [112/1000], Train Loss: 5682.2899, Test Loss: 2435.3052, Test Loss (MSE only): 4143.6629
# Epoch [113/1000], Train Loss: 5980.2943, Test Loss: 2113.4995, Test Loss (MSE only): 3554.5396
# Epoch [114/1000], Train Loss: 6014.3493, Test Loss: 2102.1330, Test Loss (MSE only): 3535.0759
# Epoch [115/1000], Train Loss: 6469.9369, Test Loss: 2278.5211, Test Loss (MSE only): 3805.4205
# Epoch [116/1000], Train Loss: 6164.2598, Test Loss: 2089.8745, Test Loss (MSE only): 3515.5372
# Epoch [117/1000], Train Loss: 6037.7627, Test Loss: 2189.6943, Test Loss (MSE only): 3714.7120
# Epoch [118/1000], Train Loss: 6162.4218, Test Loss: 1998.5674, Test Loss (MSE only): 3353.6527
# Epoch [119/1000], Train Loss: 6039.6838, Test Loss: 2217.6752, Test Loss (MSE only): 3711.7801
# Epoch [120/1000], Train Loss: 6007.7850, Test Loss: 2153.7518, Test Loss (MSE only): 3580.4170
# Epoch [121/1000], Train Loss: 5953.4636, Test Loss: 2164.5045, Test Loss (MSE only): 3649.0920
# Epoch [122/1000], Train Loss: 6115.1792, Test Loss: 1972.9881, Test Loss (MSE only): 3297.2750
# Epoch [123/1000], Train Loss: 6003.7347, Test Loss: 2144.2675, Test Loss (MSE only): 3605.3236
# Epoch [124/1000], Train Loss: 5892.4844, Test Loss: 2672.4659, Test Loss (MSE only): 4547.4531
# Epoch [125/1000], Train Loss: 5956.8196, Test Loss: 2254.8240, Test Loss (MSE only): 3769.4651
# Epoch [126/1000], Train Loss: 5856.3612, Test Loss: 2031.5397, Test Loss (MSE only): 3392.9248
# Epoch [127/1000], Train Loss: 5816.1234, Test Loss: 2262.8972, Test Loss (MSE only): 3843.7664
# Epoch [128/1000], Train Loss: 5870.7573, Test Loss: 2071.2325, Test Loss (MSE only): 3480.5237
# Epoch [129/1000], Train Loss: 5808.8668, Test Loss: 2212.6204, Test Loss (MSE only): 3707.1026
# Epoch [130/1000], Train Loss: 5836.4425, Test Loss: 2221.3173, Test Loss (MSE only): 3732.1670
# Epoch [131/1000], Train Loss: 5732.5975, Test Loss: 2247.4053, Test Loss (MSE only): 3784.2439
# Epoch [132/1000], Train Loss: 5796.5331, Test Loss: 2439.1674, Test Loss (MSE only): 4175.1989
# Epoch [133/1000], Train Loss: 5832.7288, Test Loss: 2073.8855, Test Loss (MSE only): 3469.4413
# Epoch [134/1000], Train Loss: 5578.4380, Test Loss: 2231.0998, Test Loss (MSE only): 3705.7756
# Epoch [135/1000], Train Loss: 5529.7499, Test Loss: 2132.8017, Test Loss (MSE only): 3613.5477
# Epoch [136/1000], Train Loss: 5687.6404, Test Loss: 2230.7018, Test Loss (MSE only): 3733.5208
# Epoch [137/1000], Train Loss: 5544.0837, Test Loss: 2192.4119, Test Loss (MSE only): 3660.4429
# Epoch [138/1000], Train Loss: 5693.6577, Test Loss: 1959.9941, Test Loss (MSE only): 3270.7631
# Epoch [139/1000], Train Loss: 5538.1293, Test Loss: 2407.7606, Test Loss (MSE only): 4079.6021
# Epoch [140/1000], Train Loss: 5609.0588, Test Loss: 1985.2685, Test Loss (MSE only): 3325.2930
# Epoch [141/1000], Train Loss: 5428.1466, Test Loss: 1972.6816, Test Loss (MSE only): 3311.4903
# Epoch [142/1000], Train Loss: 5388.5865, Test Loss: 2284.2648, Test Loss (MSE only): 3813.0846
# Epoch [143/1000], Train Loss: 5564.4180, Test Loss: 2023.6306, Test Loss (MSE only): 3397.9792
# Epoch [144/1000], Train Loss: 5526.2262, Test Loss: 2118.1913, Test Loss (MSE only): 3535.4265
# Epoch [145/1000], Train Loss: 5450.7233, Test Loss: 2126.3434, Test Loss (MSE only): 3544.2004
# Epoch [146/1000], Train Loss: 5357.1101, Test Loss: 1921.9157, Test Loss (MSE only): 3217.1264
# Epoch [147/1000], Train Loss: 5429.7882, Test Loss: 2093.8493, Test Loss (MSE only): 3541.2123
# Epoch [148/1000], Train Loss: 5351.5389, Test Loss: 2241.5502, Test Loss (MSE only): 3741.5115
# Epoch [149/1000], Train Loss: 5479.7513, Test Loss: 2015.1335, Test Loss (MSE only): 3379.7265
# Epoch [150/1000], Train Loss: 5366.8308, Test Loss: 2069.1813, Test Loss (MSE only): 3488.9217
# Epoch [151/1000], Train Loss: 5391.2820, Test Loss: 2061.5535, Test Loss (MSE only): 3483.1068
# Epoch [152/1000], Train Loss: 5399.9902, Test Loss: 2063.8467, Test Loss (MSE only): 3453.0618
# Epoch [153/1000], Train Loss: 5180.9657, Test Loss: 1972.6455, Test Loss (MSE only): 3287.3255
# Epoch [154/1000], Train Loss: 5210.8767, Test Loss: 2083.4949, Test Loss (MSE only): 3490.2176
# Epoch [155/1000], Train Loss: 5255.9393, Test Loss: 2051.4087, Test Loss (MSE only): 3430.5550
# Epoch [156/1000], Train Loss: 5126.9737, Test Loss: 2396.0239, Test Loss (MSE only): 4023.9070
# Epoch [157/1000], Train Loss: 5295.1196, Test Loss: 2059.0465, Test Loss (MSE only): 3472.0263
# Epoch [158/1000], Train Loss: 5139.4603, Test Loss: 2131.6887, Test Loss (MSE only): 3586.4889
# Epoch [159/1000], Train Loss: 5149.7148, Test Loss: 2604.5897, Test Loss (MSE only): 4452.0360
# Epoch [160/1000], Train Loss: 5175.3562, Test Loss: 1918.9197, Test Loss (MSE only): 3189.1826
# Epoch [161/1000], Train Loss: 5132.3491, Test Loss: 2214.3122, Test Loss (MSE only): 3715.2098
# Epoch [162/1000], Train Loss: 5248.1258, Test Loss: 2011.0275, Test Loss (MSE only): 3377.4370
# Epoch [163/1000], Train Loss: 5054.3960, Test Loss: 2031.7342, Test Loss (MSE only): 3407.7001
# Epoch [164/1000], Train Loss: 5105.3094, Test Loss: 1862.1005, Test Loss (MSE only): 3143.2469
# Epoch [165/1000], Train Loss: 5079.4250, Test Loss: 1855.3683, Test Loss (MSE only): 3082.7441
# Epoch [166/1000], Train Loss: 4978.1933, Test Loss: 1945.1471, Test Loss (MSE only): 3248.2611
# Epoch [167/1000], Train Loss: 4975.3671, Test Loss: 2005.0149, Test Loss (MSE only): 3359.8840
# Epoch [168/1000], Train Loss: 5153.6366, Test Loss: 2693.7649, Test Loss (MSE only): 4580.8006
# Epoch [169/1000], Train Loss: 5007.3527, Test Loss: 2290.1976, Test Loss (MSE only): 3858.7086
# Epoch [170/1000], Train Loss: 5133.3166, Test Loss: 1939.8797, Test Loss (MSE only): 3238.9902
# Epoch [171/1000], Train Loss: 4927.8557, Test Loss: 1995.0414, Test Loss (MSE only): 3349.3115
# Epoch [172/1000], Train Loss: 4953.3275, Test Loss: 2110.2914, Test Loss (MSE only): 3577.5842
# Epoch [173/1000], Train Loss: 4923.0115, Test Loss: 1968.3611, Test Loss (MSE only): 3283.2547
# Epoch [174/1000], Train Loss: 5021.6424, Test Loss: 1920.0381, Test Loss (MSE only): 3195.6462
# Epoch [175/1000], Train Loss: 4813.9783, Test Loss: 2003.0006, Test Loss (MSE only): 3362.3576
# Epoch [176/1000], Train Loss: 4725.6540, Test Loss: 2401.3703, Test Loss (MSE only): 4032.9834
# Epoch [177/1000], Train Loss: 4908.1471, Test Loss: 3180.4764, Test Loss (MSE only): 5628.1878
# Epoch [178/1000], Train Loss: 4969.6859, Test Loss: 1993.0192, Test Loss (MSE only): 3329.4448
# Epoch [179/1000], Train Loss: 4882.6377, Test Loss: 1891.7259, Test Loss (MSE only): 3169.7682
# Epoch [180/1000], Train Loss: 4831.6447, Test Loss: 2091.2472, Test Loss (MSE only): 3490.5689
# Epoch [181/1000], Train Loss: 4810.5317, Test Loss: 2314.4526, Test Loss (MSE only): 3912.1950
# Epoch [182/1000], Train Loss: 4825.4437, Test Loss: 1913.4918, Test Loss (MSE only): 3195.4829
# Epoch [183/1000], Train Loss: 4750.4628, Test Loss: 1940.1321, Test Loss (MSE only): 3256.9797
# Epoch [184/1000], Train Loss: 4716.0906, Test Loss: 1980.4942, Test Loss (MSE only): 3294.1100
# Epoch [185/1000], Train Loss: 4768.6894, Test Loss: 1982.8358, Test Loss (MSE only): 3315.2895
# Epoch [186/1000], Train Loss: 4777.5478, Test Loss: 1962.1905, Test Loss (MSE only): 3270.6916
# Epoch [187/1000], Train Loss: 4654.1621, Test Loss: 1944.9238, Test Loss (MSE only): 3263.9695
# Epoch [188/1000], Train Loss: 4722.9358, Test Loss: 1968.8217, Test Loss (MSE only): 3291.3348
# Epoch [189/1000], Train Loss: 4742.3384, Test Loss: 1940.2485, Test Loss (MSE only): 3257.3736
# Epoch [190/1000], Train Loss: 4851.5720, Test Loss: 1902.7709, Test Loss (MSE only): 3157.1990
# Epoch [191/1000], Train Loss: 6415.8857, Test Loss: 1995.4463, Test Loss (MSE only): 3331.3972
# Epoch [192/1000], Train Loss: 4499.4788, Test Loss: 1797.0842, Test Loss (MSE only): 3019.5111
# Epoch [193/1000], Train Loss: 4263.9539, Test Loss: 1951.5585, Test Loss (MSE only): 3287.6792
# Epoch [194/1000], Train Loss: 4455.8921, Test Loss: 1981.3697, Test Loss (MSE only): 3299.4284
# Epoch [195/1000], Train Loss: 4500.7483, Test Loss: 1904.2486, Test Loss (MSE only): 3188.9404
# Epoch [196/1000], Train Loss: 4511.9540, Test Loss: 2008.8695, Test Loss (MSE only): 3347.0047
# Epoch [197/1000], Train Loss: 4573.4072, Test Loss: 1842.5863, Test Loss (MSE only): 3085.1136
# Epoch [198/1000], Train Loss: 4493.5974, Test Loss: 1923.9899, Test Loss (MSE only): 3196.5793
# Epoch [199/1000], Train Loss: 4604.2355, Test Loss: 1811.9658, Test Loss (MSE only): 3014.9017
# Epoch [200/1000], Train Loss: 4509.3543, Test Loss: 1938.1982, Test Loss (MSE only): 3243.5059
# Epoch [201/1000], Train Loss: 4561.4665, Test Loss: 2076.6660, Test Loss (MSE only): 3526.3630
# Epoch [202/1000], Train Loss: 4521.0696, Test Loss: 1806.8143, Test Loss (MSE only): 3013.3293
# Epoch [203/1000], Train Loss: 4504.6005, Test Loss: 1970.1052, Test Loss (MSE only): 3295.1244
# Epoch [204/1000], Train Loss: 4512.4688, Test Loss: 2787.8803, Test Loss (MSE only): 4837.9618
# Epoch [205/1000], Train Loss: 4547.7200, Test Loss: 1877.4006, Test Loss (MSE only): 3157.4987
# Epoch [206/1000], Train Loss: 4507.1194, Test Loss: 1881.2208, Test Loss (MSE only): 3125.6217
# Epoch [207/1000], Train Loss: 4488.4128, Test Loss: 1999.5893, Test Loss (MSE only): 3363.2073
# Epoch [208/1000], Train Loss: 4460.5042, Test Loss: 1862.2972, Test Loss (MSE only): 3097.7648
# Epoch [209/1000], Train Loss: 4576.0507, Test Loss: 2018.8797, Test Loss (MSE only): 3362.1366
# Epoch [210/1000], Train Loss: 4387.9724, Test Loss: 1941.3596, Test Loss (MSE only): 3232.9900
# Epoch [211/1000], Train Loss: 4375.7380, Test Loss: 1951.4673, Test Loss (MSE only): 3280.6757
# Epoch [212/1000], Train Loss: 4424.7254, Test Loss: 1864.0790, Test Loss (MSE only): 3096.7731
# Epoch [213/1000], Train Loss: 4434.9914, Test Loss: 1879.9838, Test Loss (MSE only): 3102.3483
# Epoch [214/1000], Train Loss: 4400.3688, Test Loss: 1942.9688, Test Loss (MSE only): 3265.9862
# Epoch [215/1000], Train Loss: 4362.9171, Test Loss: 2472.6606, Test Loss (MSE only): 4245.5235
# Epoch [216/1000], Train Loss: 4571.2052, Test Loss: 1826.2198, Test Loss (MSE only): 3080.8324
# Epoch [217/1000], Train Loss: 4268.6985, Test Loss: 1836.1537, Test Loss (MSE only): 3102.8064
# Epoch [218/1000], Train Loss: 4322.7884, Test Loss: 1927.1408, Test Loss (MSE only): 3249.0115
# Epoch [219/1000], Train Loss: 4442.1812, Test Loss: 1911.2244, Test Loss (MSE only): 3210.5187
# Epoch [220/1000], Train Loss: 4204.1698, Test Loss: 1801.9754, Test Loss (MSE only): 3024.7871
# Epoch [221/1000], Train Loss: 4446.3309, Test Loss: 1873.7104, Test Loss (MSE only): 3115.7140
# Epoch [222/1000], Train Loss: 4125.6455, Test Loss: 2802.3813, Test Loss (MSE only): 4806.8398
# Epoch [223/1000], Train Loss: 4423.1348, Test Loss: 1887.6744, Test Loss (MSE only): 3200.6625
# Epoch [224/1000], Train Loss: 4323.5542, Test Loss: 1812.2763, Test Loss (MSE only): 3033.1609
# Epoch [225/1000], Train Loss: 4243.6677, Test Loss: 2065.5544, Test Loss (MSE only): 3341.1217
# Epoch [226/1000], Train Loss: 4465.0300, Test Loss: 1841.9661, Test Loss (MSE only): 3103.5848
# Epoch [227/1000], Train Loss: 4212.7558, Test Loss: 1882.6024, Test Loss (MSE only): 3172.8723
# Epoch [228/1000], Train Loss: 4141.7154, Test Loss: 1911.1910, Test Loss (MSE only): 3195.4053
# Epoch [229/1000], Train Loss: 4229.3000, Test Loss: 1809.8180, Test Loss (MSE only): 3024.4896
# Epoch [230/1000], Train Loss: 4313.8720, Test Loss: 1857.4057, Test Loss (MSE only): 3122.9210
# Epoch [231/1000], Train Loss: 4176.2082, Test Loss: 1753.5487, Test Loss (MSE only): 2954.5907
# Epoch [232/1000], Train Loss: 4210.6722, Test Loss: 1855.7597, Test Loss (MSE only): 3120.3161
# Epoch [233/1000], Train Loss: 4224.0953, Test Loss: 1843.6972, Test Loss (MSE only): 3047.4435
# Epoch [234/1000], Train Loss: 4278.0619, Test Loss: 1996.1166, Test Loss (MSE only): 3335.3887
# Epoch [235/1000], Train Loss: 4252.8349, Test Loss: 1854.2524, Test Loss (MSE only): 3119.1160
# Epoch [236/1000], Train Loss: 4113.7880, Test Loss: 1795.4711, Test Loss (MSE only): 3008.4710
# Epoch [237/1000], Train Loss: 4132.7023, Test Loss: 1803.0191, Test Loss (MSE only): 3009.9922
# Epoch [238/1000], Train Loss: 4119.7641, Test Loss: 1856.3407, Test Loss (MSE only): 3115.6366
# Epoch [239/1000], Train Loss: 4281.6409, Test Loss: 2012.0158, Test Loss (MSE only): 3350.0794
# Epoch [240/1000], Train Loss: 3938.8664, Test Loss: 2299.0003, Test Loss (MSE only): 3884.7839
# Epoch [241/1000], Train Loss: 4272.2448, Test Loss: 1775.6099, Test Loss (MSE only): 2978.4413
# Epoch [242/1000], Train Loss: 4005.1453, Test Loss: 1900.8181, Test Loss (MSE only): 3198.9380
# Epoch [243/1000], Train Loss: 4131.6170, Test Loss: 1792.3504, Test Loss (MSE only): 3011.6476
# Epoch [244/1000], Train Loss: 4076.3763, Test Loss: 1786.8353, Test Loss (MSE only): 2966.6181
# Epoch [245/1000], Train Loss: 4261.7275, Test Loss: 2388.7757, Test Loss (MSE only): 4001.6266
# Epoch [246/1000], Train Loss: 4123.9355, Test Loss: 1840.8355, Test Loss (MSE only): 3076.2252
# Epoch [247/1000], Train Loss: 4025.7818, Test Loss: 1771.2769, Test Loss (MSE only): 2968.5317
# Epoch [248/1000], Train Loss: 3976.8360, Test Loss: 1797.9658, Test Loss (MSE only): 3001.7282
# Epoch [249/1000], Train Loss: 3968.3829, Test Loss: 1911.6446, Test Loss (MSE only): 3218.8026
# Epoch [250/1000], Train Loss: 3990.8099, Test Loss: 1768.1324, Test Loss (MSE only): 2957.1520
# Epoch [251/1000], Train Loss: 4101.5825, Test Loss: 1782.7061, Test Loss (MSE only): 2948.2397
# Epoch [252/1000], Train Loss: 3916.2509, Test Loss: 1874.7829, Test Loss (MSE only): 3170.0174
# Epoch [253/1000], Train Loss: 4034.7183, Test Loss: 1809.1202, Test Loss (MSE only): 3028.6165
# Epoch [254/1000], Train Loss: 3975.0322, Test Loss: 1854.7018, Test Loss (MSE only): 3094.7375
# Epoch [255/1000], Train Loss: 5986.3363, Test Loss: 1771.0152, Test Loss (MSE only): 2992.4186
# Epoch [256/1000], Train Loss: 3845.7325, Test Loss: 1736.8936, Test Loss (MSE only): 2932.7523
# Epoch [257/1000], Train Loss: 3788.8975, Test Loss: 1719.1320, Test Loss (MSE only): 2894.3829
# Epoch [258/1000], Train Loss: 3791.2476, Test Loss: 1747.9628, Test Loss (MSE only): 2932.3622
# Epoch [259/1000], Train Loss: 3831.8353, Test Loss: 1853.6908, Test Loss (MSE only): 3119.1364
# Epoch [260/1000], Train Loss: 3893.8432, Test Loss: 1753.0553, Test Loss (MSE only): 2928.8046
# Epoch [261/1000], Train Loss: 3922.0630, Test Loss: 1724.0256, Test Loss (MSE only): 2881.6217
# Epoch [262/1000], Train Loss: 3817.7723, Test Loss: 1792.2555, Test Loss (MSE only): 2982.7309
# Epoch [263/1000], Train Loss: 3967.2820, Test Loss: 1849.3258, Test Loss (MSE only): 3108.6619
# Epoch [264/1000], Train Loss: 3869.4771, Test Loss: 1833.0342, Test Loss (MSE only): 3062.0872
# Epoch [265/1000], Train Loss: 3910.3070, Test Loss: 1798.6618, Test Loss (MSE only): 3040.0771
# Epoch [266/1000], Train Loss: 3873.5339, Test Loss: 1881.4216, Test Loss (MSE only): 3165.9354
# Epoch [267/1000], Train Loss: 3967.4018, Test Loss: 1731.8429, Test Loss (MSE only): 2881.5679
# Epoch [268/1000], Train Loss: 3933.1796, Test Loss: 1761.6715, Test Loss (MSE only): 2974.0388
# Epoch [269/1000], Train Loss: 3963.8596, Test Loss: 1729.8814, Test Loss (MSE only): 2903.7866
# Epoch [270/1000], Train Loss: 3832.2009, Test Loss: 1952.1432, Test Loss (MSE only): 3305.5163
# Epoch [271/1000], Train Loss: 3907.2241, Test Loss: 1757.3673, Test Loss (MSE only): 2930.5316
# Epoch [272/1000], Train Loss: 3814.9452, Test Loss: 1732.8753, Test Loss (MSE only): 2923.7230
# Epoch [273/1000], Train Loss: 3780.1237, Test Loss: 1867.1430, Test Loss (MSE only): 3146.1576
# Epoch [274/1000], Train Loss: 3874.9177, Test Loss: 1723.2186, Test Loss (MSE only): 2890.4754
# Epoch [275/1000], Train Loss: 3774.2977, Test Loss: 1987.7832, Test Loss (MSE only): 3361.3927
# Epoch [276/1000], Train Loss: 3957.9704, Test Loss: 1886.2725, Test Loss (MSE only): 3176.3249
# Epoch [277/1000], Train Loss: 3757.4103, Test Loss: 1863.1332, Test Loss (MSE only): 3130.8813
# Epoch [278/1000], Train Loss: 3834.4234, Test Loss: 1857.2213, Test Loss (MSE only): 3147.9387
# Epoch [279/1000], Train Loss: 3803.3178, Test Loss: 1887.9746, Test Loss (MSE only): 3167.8241
# Epoch [280/1000], Train Loss: 3900.5404, Test Loss: 1793.4086, Test Loss (MSE only): 3012.0254
# Epoch [281/1000], Train Loss: 3742.8131, Test Loss: 1760.6748, Test Loss (MSE only): 2954.6310
# Epoch [282/1000], Train Loss: 3820.6113, Test Loss: 1732.1415, Test Loss (MSE only): 2900.5203
# Epoch [283/1000], Train Loss: 3807.0106, Test Loss: 1728.9436, Test Loss (MSE only): 2875.9104
# Epoch [284/1000], Train Loss: 3732.5901, Test Loss: 1811.7735, Test Loss (MSE only): 3036.8086
# Epoch [285/1000], Train Loss: 3747.3639, Test Loss: 1847.5867, Test Loss (MSE only): 3091.3296
# Epoch [286/1000], Train Loss: 3726.8615, Test Loss: 1827.5329, Test Loss (MSE only): 3051.0306
# Epoch [287/1000], Train Loss: 3800.1510, Test Loss: 1777.4304, Test Loss (MSE only): 2976.9555
# Epoch [288/1000], Train Loss: 3812.6140, Test Loss: 1810.2842, Test Loss (MSE only): 3042.3018
# Epoch [289/1000], Train Loss: 3732.6500, Test Loss: 1734.9775, Test Loss (MSE only): 2902.8596
# Epoch [290/1000], Train Loss: 3691.0843, Test Loss: 1957.2833, Test Loss (MSE only): 3293.1206
# Epoch [291/1000], Train Loss: 3832.0381, Test Loss: 1844.1914, Test Loss (MSE only): 3094.1973
# Epoch [292/1000], Train Loss: 3597.6809, Test Loss: 1983.9633, Test Loss (MSE only): 3332.1815
# Epoch [293/1000], Train Loss: 3724.2944, Test Loss: 1823.3042, Test Loss (MSE only): 3044.4868
# Epoch [294/1000], Train Loss: 3670.8943, Test Loss: 1977.5985, Test Loss (MSE only): 3351.1155
# Epoch [295/1000], Train Loss: 3770.8910, Test Loss: 1785.2309, Test Loss (MSE only): 2988.2605
# Epoch [296/1000], Train Loss: 3735.5075, Test Loss: 1757.4095, Test Loss (MSE only): 2940.8633
# Epoch [297/1000], Train Loss: 3678.0176, Test Loss: 1736.3375, Test Loss (MSE only): 2908.9275
# Epoch [298/1000], Train Loss: 3620.2966, Test Loss: 1803.5396, Test Loss (MSE only): 3013.4578
# Epoch [299/1000], Train Loss: 3669.4068, Test Loss: 1776.1442, Test Loss (MSE only): 2966.5977
# Epoch [300/1000], Train Loss: 3741.0570, Test Loss: 1847.1329, Test Loss (MSE only): 3133.8357
# Epoch [301/1000], Train Loss: 3598.9015, Test Loss: 1776.7447, Test Loss (MSE only): 2973.8750
# Epoch [302/1000], Train Loss: 3593.0285, Test Loss: 1857.0578, Test Loss (MSE only): 3117.8479
# Epoch [303/1000], Train Loss: 3689.8694, Test Loss: 1975.4402, Test Loss (MSE only): 3299.6681
# Epoch [304/1000], Train Loss: 3685.2383, Test Loss: 1765.0461, Test Loss (MSE only): 2976.8874
# Epoch [305/1000], Train Loss: 3556.8962, Test Loss: 1789.9852, Test Loss (MSE only): 3001.5084
# Epoch [306/1000], Train Loss: 3687.2432, Test Loss: 1769.1432, Test Loss (MSE only): 2963.6486
# Epoch [307/1000], Train Loss: 4085.0352, Test Loss: 1951.9848, Test Loss (MSE only): 3274.4334
# Epoch [308/1000], Train Loss: 3570.9631, Test Loss: 1709.7279, Test Loss (MSE only): 2852.7503
# Epoch [309/1000], Train Loss: 3511.5327, Test Loss: 1743.9087, Test Loss (MSE only): 2925.7259
# Epoch [310/1000], Train Loss: 3403.0590, Test Loss: 2034.1921, Test Loss (MSE only): 3438.0690
# Epoch [311/1000], Train Loss: 3601.7944, Test Loss: 1931.7417, Test Loss (MSE only): 3279.0692
# Epoch [312/1000], Train Loss: 3528.5571, Test Loss: 1851.9730, Test Loss (MSE only): 3092.7450
# Epoch [313/1000], Train Loss: 3592.2249, Test Loss: 1826.8707, Test Loss (MSE only): 3061.2968
# Epoch [314/1000], Train Loss: 3506.3658, Test Loss: 1944.4628, Test Loss (MSE only): 3261.9104
# Epoch [315/1000], Train Loss: 3537.6101, Test Loss: 1780.3162, Test Loss (MSE only): 2974.4163
# Epoch [316/1000], Train Loss: 3646.6404, Test Loss: 1802.2020, Test Loss (MSE only): 3022.0640
# Epoch [317/1000], Train Loss: 3546.1489, Test Loss: 1738.1194, Test Loss (MSE only): 2899.8170
# Epoch [318/1000], Train Loss: 3490.3219, Test Loss: 1802.4347, Test Loss (MSE only): 3023.6677
# Epoch [319/1000], Train Loss: 3510.4359, Test Loss: 1819.6899, Test Loss (MSE only): 3056.2199
# Epoch [320/1000], Train Loss: 3607.6014, Test Loss: 1747.0756, Test Loss (MSE only): 2936.0625
# Epoch [321/1000], Train Loss: 3525.6286, Test Loss: 1694.6766, Test Loss (MSE only): 2843.1317
# Epoch [322/1000], Train Loss: 3501.7755, Test Loss: 1791.1042, Test Loss (MSE only): 3006.5009
# Epoch [323/1000], Train Loss: 3544.3820, Test Loss: 1787.1289, Test Loss (MSE only): 2990.4597
# Epoch [324/1000], Train Loss: 3470.6541, Test Loss: 1716.1301, Test Loss (MSE only): 2874.6416
# Epoch [325/1000], Train Loss: 3406.2866, Test Loss: 2076.3655, Test Loss (MSE only): 3495.5169
# Epoch [326/1000], Train Loss: 3609.5833, Test Loss: 1803.5272, Test Loss (MSE only): 3039.9770
# Epoch [327/1000], Train Loss: 3493.1617, Test Loss: 1893.9393, Test Loss (MSE only): 3154.9075
# Epoch [328/1000], Train Loss: 3499.2353, Test Loss: 1762.3488, Test Loss (MSE only): 2957.4682
# Epoch [329/1000], Train Loss: 3533.2604, Test Loss: 1809.0499, Test Loss (MSE only): 3031.6717
# Epoch [330/1000], Train Loss: 3461.4256, Test Loss: 1776.7827, Test Loss (MSE only): 2955.4175
# Epoch [331/1000], Train Loss: 3454.1066, Test Loss: 1740.0630, Test Loss (MSE only): 2918.0575
# Epoch [332/1000], Train Loss: 3428.0239, Test Loss: 1729.6483, Test Loss (MSE only): 2897.1398
# Epoch [333/1000], Train Loss: 3468.5564, Test Loss: 1835.7458, Test Loss (MSE only): 3097.4711
# Epoch [334/1000], Train Loss: 3479.0007, Test Loss: 1810.6992, Test Loss (MSE only): 3002.5200
# Epoch [335/1000], Train Loss: 3578.6850, Test Loss: 1954.2948, Test Loss (MSE only): 3284.4226
# Epoch [336/1000], Train Loss: 3521.5393, Test Loss: 1785.5508, Test Loss (MSE only): 2985.7749
# Epoch [337/1000], Train Loss: 3344.9092, Test Loss: 1736.4973, Test Loss (MSE only): 2904.1918
# Epoch [338/1000], Train Loss: 3400.1117, Test Loss: 1777.3978, Test Loss (MSE only): 2986.7082
# Epoch [339/1000], Train Loss: 3431.0992, Test Loss: 2043.1510, Test Loss (MSE only): 3456.3732
# Epoch [340/1000], Train Loss: 3457.9130, Test Loss: 1853.0005, Test Loss (MSE only): 3123.3021
# Epoch [341/1000], Train Loss: 3429.7770, Test Loss: 1843.2169, Test Loss (MSE only): 3089.8290
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 21
#      18 save_path = ModelName + '_Params.pt'
#      20 # Call the function
# ---> 21 train_losses, test_losses, is_model_trained = train_or_load_model(model_aq, train_iter, test_iter, num_epochs, save_path)
#      24 # Finish timing cell run time
#      25 end_time = time.time()
#
# Cell In[12], line 77, in train_or_load_model(model, train_loader, test_loader, num_epochs, save_path)
#      75 print("No pretrained model found. Training from scratch.")
#      76 #optimizer = optim.Adam(model.parameters())
# ---> 77 train_losses, test_losses = train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
#      78 is_model_trained = True  # Set flag to True after training
#      79 # Save losses per epoch
#
# Cell In[12], line 20, in train_and_save_best_model(model, train_loader, test_loader, num_epochs, save_path)
#      18     loss.backward()
#      19     optimizer.step()
# ---> 20     train_loss += loss.item() * inputs.size(0)
#      21 train_losses.append(train_loss)
#      23 model.eval()
#
# KeyboardInterrupt:

# %%
np.array(test_losses).min()

# %%
## Load training and testing datasets, validation datasets, and representative example spectra 

# Switch to directory containing datasets
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/GeneratedDataAndVariables')

# Load validation dataset
spectraVal = np.load('Dataset44_LowField_Dist9_Val_Spec.npy')
concVal = np.load('Dataset44_LowField_Dist9_Val_Conc.npy')

# Load representative validation spectra
ValSpectra = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_Spectra.npy")
ValConc = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_Concentrations.npy")
ValSpecNames = np.load("Dataset44_LowField_Dist9_RepresentativeExamples_VariableNames.npy")


# Move the input data to the GPU device
spectraVal = torch.tensor(spectraVal).float().to(device)   # Confusing names, these spectra are the 5000 spectra generated like the training dataset
ValSpectra = torch.tensor(ValSpectra).float().to(device)   # Confusing names, these spectra are the 10 representative example spectra
concVal = torch.tensor(concVal).float().to(device)
ValConc = torch.tensor(ValConc).float().to(device)

# %%
## Make sure best parameters are being utilized

# Switch to directory for saving model parameters
os.chdir('/home/htjhnson/Desktop/DL-NMR-Optimization/SavedParamsAndTrainingMetrics')

# Define the path where you saved your model parameters
save_path = ModelName + '_Params.pt'

# Load the entire dictionary from the saved file
checkpoint = torch.load(save_path)

# Instantiate the model
model_aq = Transformer(input_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout)

# Load the model's state dictionary from the loaded dictionary
model_aq.load_state_dict(checkpoint['model_state_dict'])

# Move the model to the GPU 
model_aq.to(device)
# Out:
# /home/htjhnson/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Transformer(
#   (embedding): Linear(in_features=1000, out_features=512, bias=True)
#   (positional_encoding): PositionalEncoding()
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=23552, out_features=44, bias=True)
# )

# %%
APEs = []
MAPEs = []

for i in np.arange(10):
    GroundTruth = ValConc[i]
    Prediction = model_aq(ValSpectra[i])

    # Move Prediction tensor to CPU and detach from computation graph
    Prediction_cpu = Prediction.detach().cpu().numpy()
    Prediction_cpu[0][Prediction_cpu[0] < 0] = 0
    

    APE = []

    for metabolite in range(44):
        per_err = 100*(GroundTruth[metabolite] - Prediction_cpu[0][metabolite]) / GroundTruth[metabolite]
        APE.append(abs(per_err.cpu()))

    MAPE = sum(APE) / len(APE)

    APEs.append(APE)
    MAPEs.append(MAPE)


# Convert lists to numpy arrays and save
np.save(ModelName + "_" + "ValExamples_APEs.npy", np.array(APEs))
np.save(ModelName + "_" + "ValExamples_MAPEs.npy", np.array(MAPEs))

# %%
for i in np.arange(10):
    print(round(MAPEs[i].item(), 2), " - ",ValSpecNames[i])
# Out:
# 4.74  -  AllAq1
# 2.16  -  AllAq5
# 0.81  -  AllAq25
# 1.41  -  AllAq50
# 2.04  -  ThreeAddedSinglets
# 5.56  -  ThirtyAddedSinglets
# 65.27  -  ShiftedSpec
# 19.15  -  SineBase
# 40.32  -  HighDynamicRange
# nan  -  HalfZeros

# %%
Pred = model_aq(ValSpectra[8])
Pred[0][Pred[0] < 0] = 0
print("Dist9 - HD-Range w/ 1's")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(ValSpectra[9])
Pred[0][Pred[0] < 0] = 0
print("Dist9 - HD-Range w/ 0's")
print(Pred[0])
print("___________")
print("___________")

Pred = model_aq(ValSpectra[10])
Pred[0][Pred[0] < 0] = 0
print("Dist9 - Blank")
print(Pred[0])
# Out:
# Dist9 - HD-Range w/ 1's
# tensor([0.0000e+00, 4.9710e+01, 0.0000e+00, 5.2160e+01, 4.1840e-01, 4.9801e+01,
#         0.0000e+00, 5.1313e+01, 0.0000e+00, 4.8650e+01, 7.7259e-01, 4.8989e+01,
#         1.6412e+00, 4.8815e+01, 1.7335e+00, 4.8652e+01, 7.9638e-01, 5.0229e+01,
#         0.0000e+00, 5.2126e+01, 7.2353e-01, 4.8697e+01, 0.0000e+00, 4.8655e+01,
#         6.7508e-01, 4.6905e+01, 0.0000e+00, 4.8958e+01, 2.1723e+00, 4.8635e+01,
#         4.3230e-02, 4.8628e+01, 0.0000e+00, 4.8710e+01, 6.2836e-01, 4.8760e+01,
#         2.7275e-01, 5.0663e+01, 0.0000e+00, 4.8980e+01, 0.0000e+00, 4.9325e+01,
#         0.0000e+00, 4.9325e+01], device='cuda:0', grad_fn=<SelectBackward0>)
# ___________
# ___________
# Dist9 - HD-Range w/ 0's
# tensor([ 0.0000, 49.6871,  0.0000, 52.1453,  0.0000, 49.7156,  0.0000, 51.2810,
#          0.0000, 48.4532,  0.0000, 48.9008,  0.7127, 48.6894,  0.7637, 48.3184,
#          0.0000, 50.2338,  0.0000, 52.1557,  0.0000, 48.7057,  0.0000, 48.6327,
#          0.0000, 46.7475,  0.0000, 48.9456,  1.2430, 48.5760,  0.0000, 48.5722,
#          0.0000, 48.6784,  0.0000, 48.6751,  0.0000, 50.4576,  0.0000, 48.8520,
#          0.0000, 49.2845,  0.0000, 49.3507], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# ___________
# ___________
# Dist9 - Blank
# tensor([0.0935, 0.0000, 0.0000, 0.0000, 0.0535, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0021, 0.1012, 0.0787, 0.0784, 0.0526, 0.1707, 0.0049, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0215, 0.0367, 0.0410, 0.0000, 0.0706,
#         0.0000, 0.2166, 0.0811, 0.0000, 0.2363, 0.1168, 0.0759, 0.0963, 0.0000,
#         0.0000, 0.0559, 0.0629, 0.0984, 0.0000, 0.0000, 0.0000, 0.0693],
#        device='cuda:0', grad_fn=<SelectBackward0>)
